# %%
######## snakemake preamble start (automatically inserted, do not edit) ########
import sys; sys.path.extend(['/home/lmf/anaconda3/envs/Mosaic_workflow/lib/python3.9/site-packages', '/home/lmf/.cache/snakemake/snakemake/source-cache/runtime-cache/tmpfoxbczqf/file/home/lmf/apps/MOSAIC/mosaic/rules/../notebooks', '/home/lmf/apps/MOSAIC/mosaic/rules/../notebooks']); import pickle; snakemake = pickle.loads(b'\x80\x04\x95\xeeA\x00\x00\x00\x00\x00\x00\x8c\x10snakemake.script\x94\x8c\tSnakemake\x94\x93\x94)\x81\x94}\x94(\x8c\x05input\x94\x8c\x0csnakemake.io\x94\x8c\nInputFiles\x94\x93\x94)\x81\x94(\x8cV/home/lmf/DANIEL/VIRAL_METAGENOMES/FIGURES_AND_TABLES/01_qc_read_counts_paired.tot.csv\x94\x8cR/home/lmf/DANIEL/VIRAL_METAGENOMES/05_vOTUs/95-85_positive_viral_contigs.tot.fasta\x94\x8cQ/home/lmf/DANIEL/VIRAL_METAGENOMES/05_vOTUs/checkV_merged_quality_summary.tot.txt\x94\x8ca/home/lmf/DANIEL/VIRAL_METAGENOMES/05_vOTUs/VIBRANT_95-85_positive_viral_contigs_circular.tot.csv\x94\x8cf/home/lmf/DANIEL/VIRAL_METAGENOMES/05_vOTUs/VIBRANT_95-85_positive_viral_contigs_positive_list.tot.csv\x94\x8ci/home/lmf/DANIEL/VIRAL_METAGENOMES/05_vOTUs/VIBRANT_95-85_positive_viral_contigs_positive_quality.tot.csv\x94\x8ch/home/lmf/DANIEL/VIRAL_METAGENOMES/05_vOTUs/VIBRANT_95-85_positive_viral_contigs_summary_results.tot.csv\x94\x8cm/home/lmf/DANIEL/VIRAL_METAGENOMES/05_vOTUs/VirSorter2_95-85_positive_viral_contigs_tot/final-viral-score.tsv\x94\x8cp/home/lmf/DANIEL/VIRAL_METAGENOMES/05_vOTUs/VirSorter2_95-85_positive_viral_contigs_tot/positive_VS_list_tot.txt\x94\x8c\xb0/home/lmf/DANIEL/VIRAL_METAGENOMES/05_vOTUs/geNomad_95-85_positive_viral_contigs_tot/95-85_positive_viral_contigs.tot_summary/95-85_positive_viral_contigs.tot_virus_summary.tsv\x94\x8c\xb2/home/lmf/DANIEL/VIRAL_METAGENOMES/05_vOTUs/geNomad_95-85_positive_viral_contigs_tot/95-85_positive_viral_contigs.tot_summary/95-85_positive_viral_contigs.tot_plasmid_summary.tsv\x94\x8c\xb4/home/lmf/DANIEL/VIRAL_METAGENOMES/05_vOTUs/geNomad_95-85_positive_viral_contigs_tot/95-85_positive_viral_contigs.tot_summary/formatted_viral_95-85_positive_viral_contigs.tot.fasta\x94\x8c\xc1/home/lmf/DANIEL/VIRAL_METAGENOMES/05_vOTUs/geNomad_95-85_positive_viral_contigs_tot/95-85_positive_viral_contigs.tot_summary/formatted_viral_95-85_positive_viral_contigs_conservative.tot.fasta\x94\x8cv/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_B_C1_V_unfiltered_contigs.tot.txt\x94\x8cv/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_B_C2_V_unfiltered_contigs.tot.txt\x94\x8cv/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_B_C3_V_unfiltered_contigs.tot.txt\x94\x8cv/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_B_C4_V_unfiltered_contigs.tot.txt\x94\x8cy/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_B_CIT1B_V_unfiltered_contigs.tot.txt\x94\x8cy/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_B_CIT1F_V_unfiltered_contigs.tot.txt\x94\x8cy/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_B_CIT2B_V_unfiltered_contigs.tot.txt\x94\x8cy/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_B_CIT2F_V_unfiltered_contigs.tot.txt\x94\x8cy/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_B_CIT3B_V_unfiltered_contigs.tot.txt\x94\x8cy/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_B_CIT3F_V_unfiltered_contigs.tot.txt\x94\x8cy/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_B_CIT4B_V_unfiltered_contigs.tot.txt\x94\x8cy/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_B_CIT4F_V_unfiltered_contigs.tot.txt\x94\x8cy/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_B_CNT1B_V_unfiltered_contigs.tot.txt\x94\x8cy/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_B_CNT1F_V_unfiltered_contigs.tot.txt\x94\x8cy/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_B_CNT2B_V_unfiltered_contigs.tot.txt\x94\x8cy/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_B_CNT2F_V_unfiltered_contigs.tot.txt\x94\x8cy/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_B_CNT3B_V_unfiltered_contigs.tot.txt\x94\x8cy/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_B_CNT3F_V_unfiltered_contigs.tot.txt\x94\x8cy/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_B_CNT4B_V_unfiltered_contigs.tot.txt\x94\x8cy/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_B_CNT4F_V_unfiltered_contigs.tot.txt\x94\x8cy/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_B_OIT1B_V_unfiltered_contigs.tot.txt\x94\x8cy/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_B_OIT1F_V_unfiltered_contigs.tot.txt\x94\x8cy/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_B_OIT2B_V_unfiltered_contigs.tot.txt\x94\x8cy/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_B_OIT2F_V_unfiltered_contigs.tot.txt\x94\x8cy/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_B_OIT3B_V_unfiltered_contigs.tot.txt\x94\x8cy/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_B_OIT3F_V_unfiltered_contigs.tot.txt\x94\x8cy/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_B_OIT4B_V_unfiltered_contigs.tot.txt\x94\x8cy/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_B_OIT4F_V_unfiltered_contigs.tot.txt\x94\x8cy/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_B_ORT1B_V_unfiltered_contigs.tot.txt\x94\x8cy/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_B_ORT1F_V_unfiltered_contigs.tot.txt\x94\x8cy/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_B_ORT2B_V_unfiltered_contigs.tot.txt\x94\x8cy/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_B_ORT2F_V_unfiltered_contigs.tot.txt\x94\x8cy/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_B_ORT3B_V_unfiltered_contigs.tot.txt\x94\x8cy/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_B_ORT3F_V_unfiltered_contigs.tot.txt\x94\x8cy/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_B_ORT4B_V_unfiltered_contigs.tot.txt\x94\x8cy/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_B_ORT4F_V_unfiltered_contigs.tot.txt\x94\x8cw/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_RS_C1_V_unfiltered_contigs.tot.txt\x94\x8cw/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_RS_C2_V_unfiltered_contigs.tot.txt\x94\x8cw/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_RS_C3_V_unfiltered_contigs.tot.txt\x94\x8cw/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_RS_C4_V_unfiltered_contigs.tot.txt\x94\x8cz/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_RS_CIT1B_V_unfiltered_contigs.tot.txt\x94\x8cz/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_RS_CIT1F_V_unfiltered_contigs.tot.txt\x94\x8cz/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_RS_CIT2B_V_unfiltered_contigs.tot.txt\x94\x8cz/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_RS_CIT2F_V_unfiltered_contigs.tot.txt\x94\x8cz/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_RS_CIT3B_V_unfiltered_contigs.tot.txt\x94\x8cz/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_RS_CIT3F_V_unfiltered_contigs.tot.txt\x94\x8cz/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_RS_CIT4B_V_unfiltered_contigs.tot.txt\x94\x8cz/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_RS_CIT4F_V_unfiltered_contigs.tot.txt\x94\x8cz/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_RS_CNT1B_V_unfiltered_contigs.tot.txt\x94\x8cz/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_RS_CNT1F_V_unfiltered_contigs.tot.txt\x94\x8cz/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_RS_CNT2B_V_unfiltered_contigs.tot.txt\x94\x8cz/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_RS_CNT2F_V_unfiltered_contigs.tot.txt\x94\x8cz/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_RS_CNT3B_V_unfiltered_contigs.tot.txt\x94\x8cz/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_RS_CNT3F_V_unfiltered_contigs.tot.txt\x94\x8cz/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_RS_CNT4B_V_unfiltered_contigs.tot.txt\x94\x8cz/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_RS_CNT4F_V_unfiltered_contigs.tot.txt\x94\x8cz/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_RS_OIT1B_V_unfiltered_contigs.tot.txt\x94\x8cz/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_RS_OIT1F_V_unfiltered_contigs.tot.txt\x94\x8cz/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_RS_OIT2B_V_unfiltered_contigs.tot.txt\x94\x8cz/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_RS_OIT2F_V_unfiltered_contigs.tot.txt\x94\x8cz/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_RS_OIT3B_V_unfiltered_contigs.tot.txt\x94\x8cz/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_RS_OIT3F_V_unfiltered_contigs.tot.txt\x94\x8cz/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_RS_OIT4B_V_unfiltered_contigs.tot.txt\x94\x8cz/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_RS_OIT4F_V_unfiltered_contigs.tot.txt\x94\x8cz/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_RS_ORT1B_V_unfiltered_contigs.tot.txt\x94\x8cz/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_RS_ORT1F_V_unfiltered_contigs.tot.txt\x94\x8cz/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_RS_ORT2B_V_unfiltered_contigs.tot.txt\x94\x8cz/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_RS_ORT2F_V_unfiltered_contigs.tot.txt\x94\x8cz/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_RS_ORT3B_V_unfiltered_contigs.tot.txt\x94\x8cz/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_RS_ORT3F_V_unfiltered_contigs.tot.txt\x94\x8cz/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_RS_ORT4B_V_unfiltered_contigs.tot.txt\x94\x8cz/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_RS_ORT4F_V_unfiltered_contigs.tot.txt\x94e}\x94(\x8c\x06_names\x94}\x94(\x8c\x10df_counts_paired\x94K\x00N\x86\x94\x8c\x11vOTUs_prefiltered\x94K\x01N\x86\x94\x8c\x0emerged_summary\x94K\x02N\x86\x94\x8c\x10vibrant_circular\x94K\x03N\x86\x94\x8c\x10vibrant_positive\x94K\x04N\x86\x94\x8c\x0fvibrant_quality\x94K\x05N\x86\x94\x8c\x0fvibrant_summary\x94K\x06N\x86\x94\x8c\x0fvirsorter_table\x94K\x07N\x86\x94\x8c\x17virsorter_positive_list\x94K\x08N\x86\x94\x8c\x15genomad_virus_summary\x94K\tN\x86\x94\x8c\x17genomad_plasmid_summary\x94K\nN\x86\x94\x8c\x13genomad_viral_fasta\x94K\x0bN\x86\x94\x8c genomad_viral_fasta_conservative\x94K\x0cN\x86\x94\x8c\x0emap_unfiltered\x94K\rKU\x86\x94u\x8c\x12_allowed_overrides\x94]\x94(\x8c\x05index\x94\x8c\x04sort\x94eh\x80\x8c\tfunctools\x94\x8c\x07partial\x94\x93\x94h\x06\x8c\x19Namedlist._used_attribute\x94\x93\x94\x85\x94R\x94(h\x86)}\x94\x8c\x05_name\x94h\x80sNt\x94bh\x81h\x84h\x86\x85\x94R\x94(h\x86)}\x94h\x8ah\x81sNt\x94bhbh\nhdh\x0bhfh\x0chhh\rhjh\x0ehlh\x0fhnh\x10hph\x11hrh\x12hth\x13hvh\x14hxh\x15hzh\x16h|h\x06\x8c\tNamedlist\x94\x93\x94)\x81\x94(h\x17h\x18h\x19h\x1ah\x1bh\x1ch\x1dh\x1eh\x1fh h!h"h#h$h%h&h\'h(h)h*h+h,h-h.h/h0h1h2h3h4h5h6h7h8h9h:h;h<h=h>h?h@hAhBhChDhEhFhGhHhIhJhKhLhMhNhOhPhQhRhShThUhVhWhXhYhZh[h\\h]h^e}\x94(h`}\x94h~]\x94(h\x80h\x81eh\x80h\x84h\x86\x85\x94R\x94(h\x86)}\x94h\x8ah\x80sNt\x94bh\x81h\x84h\x86\x85\x94R\x94(h\x86)}\x94h\x8ah\x81sNt\x94bubub\x8c\x06output\x94h\x06\x8c\x0bOutputFiles\x94\x93\x94)\x81\x94(\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/05_vOTUs/vOTU_clustering_summary.tot.csv\x94\x8c^/home/lmf/DANIEL/VIRAL_METAGENOMES/05_vOTUs/filtered_95-85_positive_viral_contigs_list.tot.txt\x94e}\x94(h`}\x94(\x8c\x07summary\x94K\x00N\x86\x94\x8c\rfiltered_list\x94K\x01N\x86\x94uh~]\x94(h\x80h\x81eh\x80h\x84h\x86\x85\x94R\x94(h\x86)}\x94h\x8ah\x80sNt\x94bh\x81h\x84h\x86\x85\x94R\x94(h\x86)}\x94h\x8ah\x81sNt\x94bh\xa6h\xa2h\xa8h\xa3ub\x8c\x06params\x94h\x06\x8c\x06Params\x94\x93\x94)\x81\x94(]\x94(\x8c\x06B_C1_V\x94\x8c\x06B_C2_V\x94\x8c\x06B_C3_V\x94\x8c\x06B_C4_V\x94\x8c\tB_CIT1B_V\x94\x8c\tB_CIT1F_V\x94\x8c\tB_CIT2B_V\x94\x8c\tB_CIT2F_V\x94\x8c\tB_CIT3B_V\x94\x8c\tB_CIT3F_V\x94\x8c\tB_CIT4B_V\x94\x8c\tB_CIT4F_V\x94\x8c\tB_CNT1B_V\x94\x8c\tB_CNT1F_V\x94\x8c\tB_CNT2B_V\x94\x8c\tB_CNT2F_V\x94\x8c\tB_CNT3B_V\x94\x8c\tB_CNT3F_V\x94\x8c\tB_CNT4B_V\x94\x8c\tB_CNT4F_V\x94\x8c\tB_OIT1B_V\x94\x8c\tB_OIT1F_V\x94\x8c\tB_OIT2B_V\x94\x8c\tB_OIT2F_V\x94\x8c\tB_OIT3B_V\x94\x8c\tB_OIT3F_V\x94\x8c\tB_OIT4B_V\x94\x8c\tB_OIT4F_V\x94\x8c\tB_ORT1B_V\x94\x8c\tB_ORT1F_V\x94\x8c\tB_ORT2B_V\x94\x8c\tB_ORT2F_V\x94\x8c\tB_ORT3B_V\x94\x8c\tB_ORT3F_V\x94\x8c\tB_ORT4B_V\x94\x8c\tB_ORT4F_V\x94\x8c\x07RS_C1_V\x94\x8c\x07RS_C2_V\x94\x8c\x07RS_C3_V\x94\x8c\x07RS_C4_V\x94\x8c\nRS_CIT1B_V\x94\x8c\nRS_CIT1F_V\x94\x8c\nRS_CIT2B_V\x94\x8c\nRS_CIT2F_V\x94\x8c\nRS_CIT3B_V\x94\x8c\nRS_CIT3F_V\x94\x8c\nRS_CIT4B_V\x94\x8c\nRS_CIT4F_V\x94\x8c\nRS_CNT1B_V\x94\x8c\nRS_CNT1F_V\x94\x8c\nRS_CNT2B_V\x94\x8c\nRS_CNT2F_V\x94\x8c\nRS_CNT3B_V\x94\x8c\nRS_CNT3F_V\x94\x8c\nRS_CNT4B_V\x94\x8c\nRS_CNT4F_V\x94\x8c\nRS_OIT1B_V\x94\x8c\nRS_OIT1F_V\x94\x8c\nRS_OIT2B_V\x94\x8c\nRS_OIT2F_V\x94\x8c\nRS_OIT3B_V\x94\x8c\nRS_OIT3F_V\x94\x8c\nRS_OIT4B_V\x94\x8c\nRS_OIT4F_V\x94\x8c\nRS_ORT1B_V\x94\x8c\nRS_ORT1F_V\x94\x8c\nRS_ORT2B_V\x94\x8c\nRS_ORT2F_V\x94\x8c\nRS_ORT3B_V\x94\x8c\nRS_ORT3F_V\x94\x8c\nRS_ORT4B_V\x94\x8c\nRS_ORT4F_V\x94e\x8c-/home/lmf/DANIEL/VIRAL_METAGENOMES/03_CONTIGS\x94\x8c./home/lmf/DANIEL/VIRAL_METAGENOMES/04_VIRAL_ID\x94\x8c-/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING\x94\x88\x89M\x10\']\x94(h\xb8h\xb9h\xbah\xbbh\xbch\xbdh\xbeh\xbfh\xc0h\xc1h\xc2h\xc3h\xc4h\xc5h\xc6h\xc7h\xc8h\xc9h\xcah\xcbh\xcch\xcdh\xceh\xcfh\xd0h\xd1h\xd2h\xd3h\xd4h\xd5h\xd6h\xd7h\xd8h\xd9h\xdah\xdbh\xdch\xddh\xdeh\xdfh\xe0h\xe1h\xe2h\xe3h\xe4h\xe5h\xe6h\xe7h\xe8h\xe9h\xeah\xebh\xech\xedh\xeeh\xefh\xf0h\xf1h\xf2h\xf3h\xf4h\xf5h\xf6h\xf7h\xf8h\xf9h\xfah\xfbh\xfch\xfdh\xfeh\xffee}\x94(h`}\x94(\x8c\x07samples\x94K\x00N\x86\x94\x8c\ncontig_dir\x94K\x01N\x86\x94\x8c\tviral_dir\x94K\x02N\x86\x94\x8c\x0bmapping_dir\x94K\x03N\x86\x94\x8c\x0bsubassembly\x94K\x04N\x86\x94\x8c\x0ecross_assembly\x94K\x05N\x86\x94\x8c\x0cmin_votu_len\x94K\x06N\x86\x94\x8c\x0bkey_samples\x94K\x07N\x86\x94uh~]\x94(h\x80h\x81eh\x80h\x84h\x86\x85\x94R\x94(h\x86)}\x94h\x8ah\x80sNt\x94bh\x81h\x84h\x86\x85\x94R\x94(h\x86)}\x94h\x8ah\x81sNt\x94bj\x06\x01\x00\x00h\xb7j\x08\x01\x00\x00j\x00\x01\x00\x00j\n\x01\x00\x00j\x01\x01\x00\x00j\x0c\x01\x00\x00j\x02\x01\x00\x00j\x0e\x01\x00\x00\x88j\x10\x01\x00\x00\x89j\x12\x01\x00\x00M\x10\'j\x14\x01\x00\x00j\x03\x01\x00\x00ub\x8c\twildcards\x94h\x06\x8c\tWildcards\x94\x93\x94)\x81\x94\x8c\x03tot\x94a}\x94(h`}\x94\x8c\x08sampling\x94K\x00N\x86\x94sh~]\x94(h\x80h\x81eh\x80h\x84h\x86\x85\x94R\x94(h\x86)}\x94h\x8ah\x80sNt\x94bh\x81h\x84h\x86\x85\x94R\x94(h\x86)}\x94h\x8ah\x81sNt\x94b\x8c\x08sampling\x94j#\x01\x00\x00ub\x8c\x07threads\x94K\x01\x8c\tresources\x94h\x06\x8c\tResources\x94\x93\x94)\x81\x94(K\x01K\x01\x8c\x04/tmp\x94e}\x94(h`}\x94(\x8c\x06_cores\x94K\x00N\x86\x94\x8c\x06_nodes\x94K\x01N\x86\x94\x8c\x06tmpdir\x94K\x02N\x86\x94uh~]\x94(h\x80h\x81eh\x80h\x84h\x86\x85\x94R\x94(h\x86)}\x94h\x8ah\x80sNt\x94bh\x81h\x84h\x86\x85\x94R\x94(h\x86)}\x94h\x8ah\x81sNt\x94bj:\x01\x00\x00K\x01j<\x01\x00\x00K\x01j>\x01\x00\x00j7\x01\x00\x00ub\x8c\x03log\x94h\x06\x8c\x03Log\x94\x93\x94)\x81\x94\x8cH/home/lmf/DANIEL/VIRAL_METAGENOMES/NOTEBOOKS/05_vOTU_filtering.tot.ipynb\x94a}\x94(h`}\x94\x8c\x08notebook\x94K\x00N\x86\x94sh~]\x94(h\x80h\x81eh\x80h\x84h\x86\x85\x94R\x94(h\x86)}\x94h\x8ah\x80sNt\x94bh\x81h\x84h\x86\x85\x94R\x94(h\x86)}\x94h\x8ah\x81sNt\x94bjP\x01\x00\x00jM\x01\x00\x00ub\x8c\x06config\x94}\x94(\x8c\tinput_dir\x94\x8c./home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA\x94\x8c\tkraken_db\x94\x8c\x1b/home/lmf/db/KRAKEN/kraken/\x94\x8c\rkrakenUniq_db\x94\x8c\x1e/home/lmf/db/KRAKEN/KrakenUniq\x94\x8c\necc_memory\x94M\x80>\x8c\x0bsubassembly\x94\x88\x8c\x1cadditional_reference_contigs\x94\x8c7/home/lmf/DANIEL/VIRAL_METAGENOMES/WRB_75_contigs.fasta\x94\x8c\x0eassembly_stats\x94\x88\x8c\x0bsubsampling\x94\x88\x8c\x0fmin_votu_length\x94M\x10\'\x8c\x0crun_vcontact\x94\x88\x8c\x0bimgvr_blast\x94\x88\x8c\x08run_DRAM\x94\x88\x8c\x11microbial_spacers\x94\x8c\\/home/lmf/DANIEL/MG-Assembly/ALL_MG_megahit_2000bp_derreplicated_minced_predicted_spacers.fa\x94\x8c\x0bresults_dir\x94\x8c\x00\x94\x8c\nmetagenome\x94\x88\x8c\tmicrobial\x94\x89\x8c\x08sourmash\x94\x89\x8c\x0bkey_samples\x94\x8c\x14key_samples_list.csv\x94\x8c\x10operating_system\x94\x8c\x05linux\x94\x8c\x0bforward_tag\x94\x8c\x02R1\x94\x8c\x0breverse_tag\x94\x8c\x02R2\x94\x8c\x0cnanopore_tag\x94\x8c\x08nanopore\x94\x8c\x0fnanopore_pooled\x94\x89\x8c\x14nanopore_pooled_name\x94\x8c\x03raw\x94\x8c\x0elong_assembler\x94\x8c\x04canu\x94\x8c\x0bgenome_size\x94\x8c\x0320m\x94\x8c\x13trimmomatic_leading\x94\x8c\x0220\x94\x8c\x14trimmomatic_trailing\x94\x8c\x0220\x94\x8c\x17trimmomatic_window_size\x94\x8c\x014\x94\x8c\x1atrimmomatic_window_quality\x94\x8c\x0220\x94\x8c\x12trimmomatic_minlen\x94\x8c\x0250\x94\x8c\x10nanopore_quality\x94\x8c\x0210\x94\x8c\x0fnanopore_minlen\x94M\xe8\x03\x8c\x0fnanopore_maxlen\x94J\x80\x96\x98\x00\x8c\tVirSorter\x94\x89\x8c\x0ecross_assembly\x94\x89\x8c\nlong_index\x94\x89\x8c\x16representative_contigs\x94jp\x01\x00\x00\x8c\x08sra_list\x94jp\x01\x00\x00\x8c\x0eextract_mapped\x94\x89\x8c\x07p_ident\x94\x8c\x0295\x94\x8c\x0bkmer_window\x94\x8c\x0525000\x94\x8c\x08min_norm\x94\x8c\x010\x94\x8c\x08max_norm\x94\x8c\x03100\x94\x8c\rmax_subsample\x94\x8c\x0850000000\x94\x8c\x07min_len\x94\x8c\x041000\x94\x8c\x07min_cov\x94\x8c\x012\x94\x8c\x11contaminants_list\x94jp\x01\x00\x00\x8c\radapters_file\x94\x8c\x0badapters.fa\x94\x8c\x11ambiguous_mapping\x94\x8c\x03all\x94\x8c\x0ebasecalled_dir\x94\x8c\x10data/basecalled/\x94\x8c\x13reference_databases\x94\x8c\x1eIMGVR GenBankViral RefSeqViral\x94\x8c\x08IMGVR_db\x94\x8c!/home/lmf/db/IMG_VR_2022-12-19_7/\x94\x8c\x0eRefSeqViral_db\x94\x8c6/home/lmf/db/RefSeqViral/RefSeq_viral_2024_09_03.fasta\x94\x8c\x0bpharokka_db\x94N\x8c\x08blast_db\x94\x8c\x1fdb/ncbi/NCBI_viral_proteins.faa\x94\x8c\x0cvirSorter_db\x94\x8c\x1bdb/VirSorter/virsorter-data\x94\x8c\x0ckraken_db_nt\x94\x8c\x17/home/lmf/db/KRAKEN/nt/\x94\x8c\x0fkraken_db_human\x94\x8c\x13db/kraken2_human_db\x94\x8c\x0ckraken_tools\x94\x8c\x11tools/KrakenTools\x94\x8c\x0bbracken_dir\x94\x8c\rtools/Bracken\x94\x8c\nweesam_dir\x94\x8c\x0ctools/weeSAM\x94\x8c\tcheckv_db\x94\x8c\x11db/checkv-db-v1.5\x94\x8c\tcheckm_db\x94\x8c\x0cdb/checkm-db\x94\x8c\x08iphop_db\x94\x8c\x0bdb/iphop_db\x94\x8c\rtaxmyphage_db\x94\x8c\x10db/taxmyphage_db\x94\x8c\x0csourmash_sig\x94\x8c7/home/lmf/db/SOURMASH/matrix_09_42_sourmash_k31.sig.zip\x94\x8c\x10sourmash_rocksdb\x94\x8c;/home/lmf/db/SOURMASH/matrix_09_42_sourmash_k31.sig.rocksdb\x94\x8c\x0csourmash_tax\x94\x8c9/home/lmf/db/SOURMASH/taxonomy/taxonomy_matrix_strain.csv\x94\x8c\x08canu_dir\x94\x8c\x1etools/canu-2.0/Linux-amd64/bin\x94\x8c\x12PhaGCN_newICTV_dir\x94\x8c\x14tools/PhaGCN_newICTV\x94\x8c\tquast_dir\x94\x8c\x11tools/quast-5.0.2\x94\x8c\rvirSorter_dir\x94\x8c\x0ftools/VirSorter\x94\x8c\x07WTP_dir\x94\x8c\ttools/WTP\x94\x8c\rvirFinder_dir\x94\x8c\x0ftools/VirFinder\x94\x8c\x0eclusterONE_dir\x94\x8c\x10tools/clusterONE\x94\x8c\x0cvcontact_dir\x94\x8c\x0ftools/vcontact2\x94\x8c\x1areference_genomes_vcontact\x94\x8c\x04None\x94\x8c\rtaxonomy_file\x94\x8c1db/vcontact2/formatting_taxonomy_affiliations.csv\x94\x8c\ngenomad_db\x94\x8c\rdb/genomad_db\x94\x8c\x07DRAM_db\x94\x8c\ndb/DRAM_db\x94\x8c\tgtdbtk_db\x94\x8c\ndb/GTDB-Tk\x94\x8c\nmmseqs_dir\x94\x8c\rtools/MMseqs2\x94\x8c\x08viga_dir\x94\x8c\ntools/viga\x94\x8c\tpiler_dir\x94\x8c\x11tools/pilercr1.06\x94\x8c\x07trf_dir\x94\x8c\ttools/TRF\x94\x8c\x0bvibrant_dir\x94\x8c\rtools/VIBRANT\x94\x8c\x0eviridic_folder\x94\x8c\x17tools/viridic_v1.0_r3.6\x94\x8c\x0fsra_toolkit_dir\x94\x8c tools/sratoolkit.2.10.0-ubuntu64\x94\x8c\x07ALE_dir\x94\x8c\ttools/ALE\x94\x8c\x08wish_dir\x94\x8c\ntools/WIsH\x94\x8c\nminced_dir\x94\x8c\x0ctools/minced\x94\x8c\x07dion_db\x94\x8c\x0cdb/dionSetDB\x94u\x8c\x04rule\x94\x8c\x17get_list_filtered_vOTUs\x94\x8c\x0fbench_iteration\x94N\x8c\tscriptdir\x94\x8c//home/lmf/apps/MOSAIC/mosaic/rules/../notebooks\x94ub.'); from snakemake.logging import logger; logger.printshellcmds = True; import os; os.chdir(r'/home/lmf/apps/MOSAIC/mosaic');
######## snakemake preamble end #########

# %% [markdown]
# # FILTER

# %%
import pandas as pd
from Bio import SeqIO   
import matplotlib.pyplot as plt
from matplotlib_venn import venn3
import numpy as np 
import seaborn as sns

# %%
input_df_counts_paired=snakemake.input.df_counts_paired
input_merged_summary=snakemake.input.merged_summary
input_vOTUs_prefiltered=snakemake.input.vOTUs_prefiltered
input_vibrant_circular=snakemake.input.vibrant_circular
input_vibrant_positive=snakemake.input.vibrant_positive
input_vibrant_quality=snakemake.input.vibrant_quality
input_vibrant_summary=snakemake.input.vibrant_summary
input_virsorter_table=snakemake.input.virsorter_table
input_virsorter_positive_list=snakemake.input.virsorter_positive_list
input_genomad_virus_summary=snakemake.input.genomad_virus_summary
input_genomad_plasmid_summary=snakemake.input.genomad_plasmid_summary
input_genomad_viral_fasta=snakemake.input.genomad_viral_fasta
input_genomad_viral_fasta_conservative=snakemake.input.genomad_viral_fasta_conservative
#________
output_summary=snakemake.output.summary
output_filtered_list=snakemake.output.filtered_list

SAMPLES=snakemake.params.samples
min_votu_len=snakemake.params.min_votu_len
SAMPLES_key=snakemake.params.key_samples
input_mapping_dir=snakemake.params.mapping_dir

# %%
# Initialize an empty list to hold individual DataFrames
df_list = []

# Loop over each sample and process data
for sample in SAMPLES_key:
    # Load unfiltered coverage stats
    print(sample)
    covstats_unf = pd.read_csv(f"{input_mapping_dir}/STATS_FILES/bowtie2_{sample}_unfiltered_contigs.tot_covstats.txt", sep="\t", index_col=0)
    covstats_unf = covstats_unf[[f"bowtie2_{sample}_unfiltered_contigs_tot_filtered Read Count"]]
    
    covstats_unf.columns = [sample]
    df_list.append(covstats_unf)

# Concatenate all DataFrames at once along the columns axis
combined_reads_u = pd.concat(df_list, axis=1)

# Display or use the combined DataFrame
combined_reads_u.head()

# Calculate count DataFrame as before
count_df = (combined_reads_u > 1).sum(axis=1).to_frame()
mapped_contigs = list(count_df[count_df[0] > 0].index)
# Out:
# B_C1_V
# B_C2_V
# B_C3_V
# B_C4_V
# B_CIT1B_V
# B_CIT1F_V
# B_CIT2B_V
# B_CIT2F_V
# B_CIT3B_V
# B_CIT3F_V
# B_CIT4B_V
# B_CIT4F_V
# B_CNT1B_V
# B_CNT1F_V
# B_CNT2B_V
# B_CNT2F_V
# B_CNT3B_V
# B_CNT3F_V
# B_CNT4B_V
# B_CNT4F_V
# B_OIT1B_V
# B_OIT1F_V
# B_OIT2B_V
# B_OIT2F_V
# B_OIT3B_V
# B_OIT3F_V
# B_OIT4B_V
# B_OIT4F_V
# B_ORT1B_V
# B_ORT1F_V
# B_ORT2B_V
# B_ORT2F_V
# B_ORT3B_V
# B_ORT3F_V
# B_ORT4B_V
# B_ORT4F_V
# RS_C1_V
# RS_C2_V
# RS_C3_V
# RS_C4_V
# RS_CIT1B_V
# RS_CIT1F_V
# RS_CIT2B_V
# RS_CIT2F_V
# RS_CIT3B_V
# RS_CIT3F_V
# RS_CIT4B_V
# RS_CIT4F_V
# RS_CNT1B_V
# RS_CNT1F_V
# RS_CNT2B_V
# RS_CNT2F_V
# RS_CNT3B_V
# RS_CNT3F_V
# RS_CNT4B_V
# RS_CNT4F_V
# RS_OIT1B_V
# RS_OIT1F_V
# RS_OIT2B_V
# RS_OIT2F_V
# RS_OIT3B_V
# RS_OIT3F_V
# RS_OIT4B_V
# RS_OIT4F_V
# RS_ORT1B_V
# RS_ORT1F_V
# RS_ORT2B_V
# RS_ORT2F_V
# RS_ORT3B_V
# RS_ORT3F_V
# RS_ORT4B_V
# RS_ORT4F_V

# %%
# Create an empty list to store vOTU names
vOTU_list = []

# Iterate over records in input_vOTUs_prefiltered file and append record IDs to the list
for record in SeqIO.parse(input_vOTUs_prefiltered, "fasta"):
    vOTU_list.append(record.id)

# Create a DataFrame with vOTU names
vOTU_prefiltered = pd.DataFrame(vOTU_list, columns=["vOTU_name"])

# Read data from input_merged_summary file into checkv_df DataFrame with specified column names
checkv_df = pd.read_csv(input_merged_summary, sep="\t", names=["checkV_contig_id", "checkV_contig_length", "checkV_provirus",
                                                                "checkV_proviral_length", "checkV_gene_count", "checkV_viral_genes",
                                                                "checkV_host_genes", "checkv_quality", "checkV_miuvig_quality",
                                                                "checkV_completeness", "checkV_completeness_method", "checkV_contamination",
                                                                "checkV_kmer_freq", "checkV_warnings"])
checkv_df=checkv_df.groupby(["checkV_contig_id"]).first().reset_index()

# Read data from input_vibrant_circular file into vibrant_circular_df DataFrame with a single column name
vibrant_circular_df = pd.read_csv(input_vibrant_circular, names=["VIBRANT_circular_name"])
vibrant_circular_df["VIBRANT_circular"] = "Y"

# Read data from input_vibrant_positive file into vibrant_positive_df DataFrame with a single column name
vibrant_positive_df = pd.read_csv(input_vibrant_positive, names=["VIBRANT_positive_name"])
vibrant_positive_df["VIBRANT_positive"] = "Y"

# Read data from input_vibrant_quality file into vibrant_quality_df DataFrame with specific column names
vibrant_quality_df = pd.read_csv(input_vibrant_quality, sep="\t")
vibrant_quality_df.columns = ["VIBRANT_scaffold", "VIBRANT_lifecycle", "VIBRANT_quality"]
vibrant_quality_df = vibrant_quality_df.groupby("VIBRANT_scaffold").first()

# Read data from input_vibrant_summary file into vibrant_summary_df DataFrame with modified column names
vibrant_summary_df = pd.read_csv(input_vibrant_summary, sep="\t")
vibrant_summary_df.columns = ['VIBRANT_' + str(col).replace(" ", "_") for col in vibrant_summary_df.columns]

# Read data from input_virsorter_table file into virsorter_summary_df DataFrame with modified column names
virsorter_summary_df = pd.read_csv(input_virsorter_table, sep="\t")
virsorter_summary_df.columns = ['VirSorter2_' + str(col).replace(" ", "_") for col in virsorter_summary_df.columns]
virsorter_summary_df["VirSorter2_positive"] = "Y"

# Read data from input_genomad_virus_summary file into genomad_summary_df DataFrame with modified column names
genomad_summary_df = pd.read_csv(input_genomad_virus_summary, sep="\t")
genomad_summary_df.columns = ['geNomad_' + str(col).replace(" ", "_") for col in genomad_summary_df.columns]

# Create an empty list to store viral names
viral_list = []

# Iterate over records in input_genomad_viral_fasta file and append record IDs to the list
for record in SeqIO.parse(input_genomad_viral_fasta, "fasta"):
    viral_list.append(record.id)

# Create a DataFrame with viral names
geNomad_viral = pd.DataFrame(viral_list, columns=["geNomad_viral_name"])
geNomad_viral["geNomad_viral"] = "Y"

# Create an empty list to store conservative viral names
viral_list_conservative = []

# Iterate over records in input_genomad_viral_fasta_conservative file and append record IDs to the list
for record in SeqIO.parse(input_genomad_viral_fasta_conservative, "fasta"):
    viral_list_conservative.append(record.id)

# Create a DataFrame with conservative viral names
geNomad_viral_conservative = pd.DataFrame(viral_list_conservative, columns=["geNomad_viral_conservative_name"])
geNomad_viral_conservative["geNomad_viral_conservative"] = "Y"
# Out:
# /home/lmf/anaconda3/envs/Mosaic_workflow/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3135: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
# Merge vOTU_prefiltered with vibrant_circular_df based on vOTU_name and VIBRANT_circular_name columns
df_temp1 = vOTU_prefiltered.merge(vibrant_circular_df, left_on="vOTU_name", right_on="VIBRANT_circular_name", how="left")

# Merge df_temp1 with vibrant_positive_df based on vOTU_name and VIBRANT_positive_name columns
df_temp2 = df_temp1.merge(vibrant_positive_df, left_on="vOTU_name", right_on="VIBRANT_positive_name", how="left")

# Merge df_temp2 with vibrant_quality_df based on vOTU_name and VIBRANT_scaffold columns
df_temp3 = df_temp2.merge(vibrant_quality_df, left_on="vOTU_name", right_on="VIBRANT_scaffold", how="left")

# Merge df_temp3 with vibrant_summary_df based on vOTU_name and VIBRANT_scaffold columns
df_temp4 = df_temp3.merge(vibrant_summary_df, left_on="vOTU_name", right_on="VIBRANT_scaffold", how="left")

# Merge df_temp4 with virsorter_summary_df based on vOTU_name and VirSorter2_seqname columns
df_temp5 = df_temp4.merge(virsorter_summary_df, left_on="vOTU_name", right_on="VirSorter2_seqname", how="left")

# Merge df_temp5 with genomad_summary_df based on vOTU_name and geNomad_seq_name columns
df_temp6 = df_temp5.merge(genomad_summary_df, left_on="vOTU_name", right_on="geNomad_seq_name", how="left")

# Merge df_temp6 with geNomad_viral based on vOTU_name and geNomad_viral_name columns
df_temp7 = df_temp6.merge(geNomad_viral, left_on="vOTU_name", right_on="geNomad_viral_name", how="left")

# Merge df_temp7 with geNomad_viral_conservative based on vOTU_name and geNomad_viral_conservative_name columns
df_temp8 = df_temp7.merge(geNomad_viral_conservative, left_on="vOTU_name", right_on="geNomad_viral_conservative_name", how="left")

# Merge df_temp8 with checkv_df based on vOTU_name and checkV_contig_id columns
df_merged = df_temp8.merge(checkv_df, left_on="vOTU_name", right_on="checkV_contig_id", how="left")

# Drop unnecessary columns from df_merged
df_merged = df_merged.drop(["VIBRANT_circular_name", "VIBRANT_positive_name", "VIBRANT_scaffold", "checkV_contig_id"], axis=1)

# Return the merged DataFrame
df_merged
# Out:
#                                           vOTU_name VIBRANT_circular  \
# 0          B_C1_V_NODE_2_length_50422_cov_10.106280              NaN
# 1           B_C1_V_NODE_3_length_40525_cov_8.997628              NaN
# 2          B_C1_V_NODE_4_length_36900_cov_10.401628              NaN
# 3           B_C1_V_NODE_5_length_33518_cov_9.610555              NaN
# 4          B_C1_V_NODE_7_length_27820_cov_10.734342              NaN
# ...                                             ...              ...
# 229674  WRB_70_NODE_2006_length_22953_cov_10.209189              NaN
# 229675   WRB_60_NODE_4083_length_12207_cov_7.069124              NaN
# 229676  WRB_70_NODE_5237_length_11300_cov_12.237617              NaN
# 229677  WRB_90_NODE_5267_length_13400_cov_14.925365              NaN
# 229678   WRB_90_NODE_7328_length_10601_cov_5.561635              NaN
#
#        VIBRANT_positive VIBRANT_lifecycle       VIBRANT_quality  \
# 0                     Y             lytic    high quality draft
# ...

# %%
df=df_merged[["VirSorter2_positive","VIBRANT_positive","geNomad_viral","geNomad_viral_conservative"]]

# Get the counts for each category
a_count = df['VirSorter2_positive'].value_counts()['Y']
b_count = df['VIBRANT_positive'].value_counts()['Y']
c_count = df['geNomad_viral'].value_counts()['Y']
ab_count = df[df['VirSorter2_positive'] == 'Y']['VIBRANT_positive'].value_counts()['Y']
ac_count = df[df['VirSorter2_positive'] == 'Y']['geNomad_viral'].value_counts()['Y']
bc_count = df[(df['VIBRANT_positive'] == 'Y') & (df['geNomad_viral'] == 'Y')]['VIBRANT_positive'].value_counts()['Y']
abc_count = df[(df['VirSorter2_positive'] == 'Y') & (df['VIBRANT_positive'] == 'Y') & (df['geNomad_viral'] == 'Y')]['VIBRANT_positive'].value_counts()['Y']

# Create the Venn diagram
venn_labels = {'100': a_count - ab_count - ac_count + abc_count,
               '010': b_count - ab_count - bc_count + abc_count,
               '001': c_count - ac_count - bc_count + abc_count,
               '110': ab_count - abc_count,
               '101': ac_count - abc_count,
               '011': bc_count - abc_count,
               '111': abc_count}

plt.figure(figsize=(8, 6))
venn_diagram = venn3(subsets=venn_labels, set_labels=('VirSorter2', 'VIBRANT', 'geNomad'))

# Add the counts to the Venn diagram
for text in venn_diagram.set_labels:
    text.set_fontsize(14)
for text in venn_diagram.subset_labels:
    if text:
        text.set_fontsize(12)

# Show the Venn diagram
# plt.title("Venn Diagram of Categories 'VirSorter2_positive', 'VIBRANT_positive', and 'geNomad_viral'")
plt.show()

# %%
# Define columns to count
columns_to_count = ["VirSorter2_positive", "VIBRANT_positive", "geNomad_viral"]

# Count the number of 'Y' occurrences in columns specified in columns_to_count and store the result in a new column 'count_Y'
df_merged['count_Y'] = df_merged[columns_to_count].eq('Y').sum(axis=1)

# Define the desired column order in the DataFrame
move_cols = ["vOTU_name", "count_Y", "checkV_contig_length", "VirSorter2_positive", "VIBRANT_positive", "geNomad_viral", "geNomad_viral_conservative"]

# Reorder the columns in df_merged according to move_cols and keep the remaining columns in their original order
df_merged = df_merged[move_cols + [col for col in df_merged.columns if col not in move_cols]]

# Create a filtered DataFrame by applying conditions on count_Y and checkV_contig_length columns
df_merged_filtered =df_merged[
    ((df_merged["count_Y"] == 3) | (df_merged["geNomad_viral_conservative"] == "Y")) & 
    ((df_merged["checkV_contig_length"] >= min_votu_len) | (df_merged["checkV_miuvig_quality"] == "High-quality")) ]

df_merged_filtered_abundance=df_merged_filtered[(df_merged_filtered.vOTU_name.isin(mapped_contigs))]

df_merged_removed=df_merged[
    ((df_merged["count_Y"] != 3) & (df_merged["geNomad_viral_conservative"] != "Y")) |
    ((df_merged["checkV_contig_length"] < min_votu_len) & (df_merged["checkV_miuvig_quality"] != "High-quality"))]

df_merged_removed_abundance=df_merged_filtered[~(df_merged_filtered.vOTU_name.isin(mapped_contigs))]

df_merged_removed=pd.concat([df_merged_removed,df_merged_removed_abundance])

# Write the values in the 'vOTU_name' column to output_filtered_list file without the index and header
df_merged_filtered_abundance["vOTU_name"].to_csv(output_filtered_list, index=False, header=False)

# Write df_merged_filtered_abundance to output_summary file
df_merged_filtered_abundance.to_csv(output_summary)

# df_merged_removed
print("all\t\t", len(df_merged))
print("selected\t",len(df_merged_filtered_abundance))
print("removed\t\t",len(df_merged_removed))

print("sum\t\t",len(df_merged_filtered_abundance)+len(df_merged_removed) )
# Out:
# all		 229679
# selected	 2840
# removed		 226785
# sum		 229625

# %%
category_colors = ["red", "blue", "green", "orange", "purple"]

df_merged_removed["checkV_contig_length_log"]=np.log10(df_merged_removed["checkV_contig_length"])


# Plot the data as a distribution plot
ax = sns.jointplot(data=df_merged_removed,x="checkV_contig_length_log",y="checkV_completeness", hue="checkv_quality", alpha=1,height=6,palette=category_colors, marker="+")
ax.plot_joint(sns.kdeplot)

# Set x- and y-axis labels  
ax.ax_joint.set_xlabel('Contig length')
ax.ax_joint.set_ylabel('CheckV completness')
ax.ax_joint.set_ylim(0,100)
ax.ax_joint.set_xlim(3,5)

# Set the x-ticks and y-ticks to powers of 10
# x-ticks
xticks = ax.ax_joint.get_xticks()
xticklabels = [int(10**x) for x in xticks]
ax.ax_joint.set_xticklabels(xticklabels)

# Set legend
sns.move_legend(ax.ax_joint, title='Checkv quality',  markerscale=1, loc="lower right",fontsize=10,title_fontsize=12)

# # Save the figure as png and svg files
# ax.figure.savefig(output_filtered_vOTUs_png, format="png", bbox_inches = "tight",transparent=True)
# ax.figure.savefig(output_filtered_vOTUs_svg, format="svg", bbox_inches = "tight",transparent=True)
# plt.setp(ax.get_legend().get_texts(), fontsize='22') # for legend text
# plt.setp(ax.get_legend().get_title(), fontsize='32') # for legend title
# Show the plot
plt.show()
# Out:
# /home/lmf/anaconda3/envs/Mosaic_workflow/lib/python3.9/site-packages/seaborn/axisgrid.py:1826: UserWarning: KDE cannot be estimated (0 variance or perfect covariance). Pass `warn_singular=False` to disable this warning.
#   func(x=self.x, y=self.y, **kwargs)
# /tmp/ipykernel_432590/1046397985.py:20: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.ax_joint.set_xticklabels(xticklabels)

# %%
df_merged_filtered_abundance.groupby("checkv_quality").size().to_frame()
# Out:
#                    0
# checkv_quality
# Complete          30
# High-quality      25
# Low-quality     2296
# Medium-quality   339
# Not-determined   150

# %%
fig, ax = plt.subplots(figsize=(8,8))

df_quality_counts=df_merged_filtered_abundance.groupby('checkv_quality').size()
df_quality_counts=df_quality_counts.reindex(['Complete','High-quality', 'Medium-quality','Low-quality','Not-determined'])

def make_autopct(values):
    def my_autopct(pct):
        total = sum(values)
        val = int(round(pct*total/100.0))
        return '{p:.2f}%  ({v:d})'.format(p=pct,v=val)
    return my_autopct


explode = (0.3, 0.2, 0.1, 0, 0)


mycolors=["#d4dbba","#ebeddd","#372f69","#efeff7","#e0cf94"]

plt.pie(df_quality_counts, labels=df_quality_counts.index, autopct=make_autopct(df_quality_counts), explode=explode, textprops={'fontsize': 12}, colors=mycolors)

plt.show()
