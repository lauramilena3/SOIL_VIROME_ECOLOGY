# %%
######## snakemake preamble start (automatically inserted, do not edit) ########
import sys; sys.path.extend(['/home/lmf/anaconda3/envs/Mosaic_workflow/lib/python3.9/site-packages', '/home/lmf/.cache/snakemake/snakemake/source-cache/runtime-cache/tmpfoxbczqf/file/home/lmf/apps/MOSAIC/mosaic/rules/../notebooks', '/home/lmf/apps/MOSAIC/mosaic/rules/../notebooks']); import pickle; snakemake = pickle.loads(b'\x80\x04\x95\x8aL\x00\x00\x00\x00\x00\x00\x8c\x10snakemake.script\x94\x8c\tSnakemake\x94\x93\x94)\x81\x94}\x94(\x8c\x05input\x94\x8c\x0csnakemake.io\x94\x8c\nInputFiles\x94\x93\x94)\x81\x94(\x8cW/home/lmf/DANIEL/VIRAL_METAGENOMES/01_QC/postQC_illumina_report_data/multiqc_fastqc.txt\x94\x8cM/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/bowtie2_B_C1_V_tot_covstats.txt\x94\x8cM/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/bowtie2_B_C2_V_tot_covstats.txt\x94\x8cM/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/bowtie2_B_C3_V_tot_covstats.txt\x94\x8cM/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/bowtie2_B_C4_V_tot_covstats.txt\x94\x8cP/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/bowtie2_B_CIT1B_V_tot_covstats.txt\x94\x8cP/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/bowtie2_B_CIT1F_V_tot_covstats.txt\x94\x8cP/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/bowtie2_B_CIT2B_V_tot_covstats.txt\x94\x8cP/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/bowtie2_B_CIT2F_V_tot_covstats.txt\x94\x8cP/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/bowtie2_B_CIT3B_V_tot_covstats.txt\x94\x8cP/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/bowtie2_B_CIT3F_V_tot_covstats.txt\x94\x8cP/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/bowtie2_B_CIT4B_V_tot_covstats.txt\x94\x8cP/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/bowtie2_B_CIT4F_V_tot_covstats.txt\x94\x8cP/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/bowtie2_B_CNT1B_V_tot_covstats.txt\x94\x8cP/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/bowtie2_B_CNT1F_V_tot_covstats.txt\x94\x8cP/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/bowtie2_B_CNT2B_V_tot_covstats.txt\x94\x8cP/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/bowtie2_B_CNT2F_V_tot_covstats.txt\x94\x8cP/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/bowtie2_B_CNT3B_V_tot_covstats.txt\x94\x8cP/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/bowtie2_B_CNT3F_V_tot_covstats.txt\x94\x8cP/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/bowtie2_B_CNT4B_V_tot_covstats.txt\x94\x8cP/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/bowtie2_B_CNT4F_V_tot_covstats.txt\x94\x8cP/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/bowtie2_B_OIT1B_V_tot_covstats.txt\x94\x8cP/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/bowtie2_B_OIT1F_V_tot_covstats.txt\x94\x8cP/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/bowtie2_B_OIT2B_V_tot_covstats.txt\x94\x8cP/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/bowtie2_B_OIT2F_V_tot_covstats.txt\x94\x8cP/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/bowtie2_B_OIT3B_V_tot_covstats.txt\x94\x8cP/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/bowtie2_B_OIT3F_V_tot_covstats.txt\x94\x8cP/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/bowtie2_B_OIT4B_V_tot_covstats.txt\x94\x8cP/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/bowtie2_B_OIT4F_V_tot_covstats.txt\x94\x8cP/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/bowtie2_B_ORT1B_V_tot_covstats.txt\x94\x8cP/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/bowtie2_B_ORT1F_V_tot_covstats.txt\x94\x8cP/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/bowtie2_B_ORT2B_V_tot_covstats.txt\x94\x8cP/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/bowtie2_B_ORT2F_V_tot_covstats.txt\x94\x8cP/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/bowtie2_B_ORT3B_V_tot_covstats.txt\x94\x8cP/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/bowtie2_B_ORT3F_V_tot_covstats.txt\x94\x8cP/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/bowtie2_B_ORT4B_V_tot_covstats.txt\x94\x8cP/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/bowtie2_B_ORT4F_V_tot_covstats.txt\x94\x8cN/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/bowtie2_RS_C1_V_tot_covstats.txt\x94\x8cN/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/bowtie2_RS_C2_V_tot_covstats.txt\x94\x8cN/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/bowtie2_RS_C3_V_tot_covstats.txt\x94\x8cN/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/bowtie2_RS_C4_V_tot_covstats.txt\x94\x8cQ/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/bowtie2_RS_CIT1B_V_tot_covstats.txt\x94\x8cQ/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/bowtie2_RS_CIT1F_V_tot_covstats.txt\x94\x8cQ/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/bowtie2_RS_CIT2B_V_tot_covstats.txt\x94\x8cQ/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/bowtie2_RS_CIT2F_V_tot_covstats.txt\x94\x8cQ/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/bowtie2_RS_CIT3B_V_tot_covstats.txt\x94\x8cQ/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/bowtie2_RS_CIT3F_V_tot_covstats.txt\x94\x8cQ/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/bowtie2_RS_CIT4B_V_tot_covstats.txt\x94\x8cQ/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/bowtie2_RS_CIT4F_V_tot_covstats.txt\x94\x8cQ/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/bowtie2_RS_CNT1B_V_tot_covstats.txt\x94\x8cQ/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/bowtie2_RS_CNT1F_V_tot_covstats.txt\x94\x8cQ/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/bowtie2_RS_CNT2B_V_tot_covstats.txt\x94\x8cQ/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/bowtie2_RS_CNT2F_V_tot_covstats.txt\x94\x8cQ/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/bowtie2_RS_CNT3B_V_tot_covstats.txt\x94\x8cQ/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/bowtie2_RS_CNT3F_V_tot_covstats.txt\x94\x8cQ/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/bowtie2_RS_CNT4B_V_tot_covstats.txt\x94\x8cQ/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/bowtie2_RS_CNT4F_V_tot_covstats.txt\x94\x8cQ/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/bowtie2_RS_OIT1B_V_tot_covstats.txt\x94\x8cQ/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/bowtie2_RS_OIT1F_V_tot_covstats.txt\x94\x8cQ/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/bowtie2_RS_OIT2B_V_tot_covstats.txt\x94\x8cQ/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/bowtie2_RS_OIT2F_V_tot_covstats.txt\x94\x8cQ/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/bowtie2_RS_OIT3B_V_tot_covstats.txt\x94\x8cQ/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/bowtie2_RS_OIT3F_V_tot_covstats.txt\x94\x8cQ/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/bowtie2_RS_OIT4B_V_tot_covstats.txt\x94\x8cQ/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/bowtie2_RS_OIT4F_V_tot_covstats.txt\x94\x8cQ/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/bowtie2_RS_ORT1B_V_tot_covstats.txt\x94\x8cQ/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/bowtie2_RS_ORT1F_V_tot_covstats.txt\x94\x8cQ/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/bowtie2_RS_ORT2B_V_tot_covstats.txt\x94\x8cQ/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/bowtie2_RS_ORT2F_V_tot_covstats.txt\x94\x8cQ/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/bowtie2_RS_ORT3B_V_tot_covstats.txt\x94\x8cQ/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/bowtie2_RS_ORT3F_V_tot_covstats.txt\x94\x8cQ/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/bowtie2_RS_ORT4B_V_tot_covstats.txt\x94\x8cQ/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/bowtie2_RS_ORT4F_V_tot_covstats.txt\x94\x8cT/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/bowtie2_B_C1_V_tot_unique_covstats.txt\x94\x8cT/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/bowtie2_B_C2_V_tot_unique_covstats.txt\x94\x8cT/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/bowtie2_B_C3_V_tot_unique_covstats.txt\x94\x8cT/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/bowtie2_B_C4_V_tot_unique_covstats.txt\x94\x8cW/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/bowtie2_B_CIT1B_V_tot_unique_covstats.txt\x94\x8cW/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/bowtie2_B_CIT1F_V_tot_unique_covstats.txt\x94\x8cW/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/bowtie2_B_CIT2B_V_tot_unique_covstats.txt\x94\x8cW/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/bowtie2_B_CIT2F_V_tot_unique_covstats.txt\x94\x8cW/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/bowtie2_B_CIT3B_V_tot_unique_covstats.txt\x94\x8cW/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/bowtie2_B_CIT3F_V_tot_unique_covstats.txt\x94\x8cW/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/bowtie2_B_CIT4B_V_tot_unique_covstats.txt\x94\x8cW/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/bowtie2_B_CIT4F_V_tot_unique_covstats.txt\x94\x8cW/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/bowtie2_B_CNT1B_V_tot_unique_covstats.txt\x94\x8cW/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/bowtie2_B_CNT1F_V_tot_unique_covstats.txt\x94\x8cW/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/bowtie2_B_CNT2B_V_tot_unique_covstats.txt\x94\x8cW/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/bowtie2_B_CNT2F_V_tot_unique_covstats.txt\x94\x8cW/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/bowtie2_B_CNT3B_V_tot_unique_covstats.txt\x94\x8cW/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/bowtie2_B_CNT3F_V_tot_unique_covstats.txt\x94\x8cW/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/bowtie2_B_CNT4B_V_tot_unique_covstats.txt\x94\x8cW/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/bowtie2_B_CNT4F_V_tot_unique_covstats.txt\x94\x8cW/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/bowtie2_B_OIT1B_V_tot_unique_covstats.txt\x94\x8cW/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/bowtie2_B_OIT1F_V_tot_unique_covstats.txt\x94\x8cW/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/bowtie2_B_OIT2B_V_tot_unique_covstats.txt\x94\x8cW/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/bowtie2_B_OIT2F_V_tot_unique_covstats.txt\x94\x8cW/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/bowtie2_B_OIT3B_V_tot_unique_covstats.txt\x94\x8cW/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/bowtie2_B_OIT3F_V_tot_unique_covstats.txt\x94\x8cW/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/bowtie2_B_OIT4B_V_tot_unique_covstats.txt\x94\x8cW/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/bowtie2_B_OIT4F_V_tot_unique_covstats.txt\x94\x8cW/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/bowtie2_B_ORT1B_V_tot_unique_covstats.txt\x94\x8cW/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/bowtie2_B_ORT1F_V_tot_unique_covstats.txt\x94\x8cW/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/bowtie2_B_ORT2B_V_tot_unique_covstats.txt\x94\x8cW/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/bowtie2_B_ORT2F_V_tot_unique_covstats.txt\x94\x8cW/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/bowtie2_B_ORT3B_V_tot_unique_covstats.txt\x94\x8cW/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/bowtie2_B_ORT3F_V_tot_unique_covstats.txt\x94\x8cW/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/bowtie2_B_ORT4B_V_tot_unique_covstats.txt\x94\x8cW/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/bowtie2_B_ORT4F_V_tot_unique_covstats.txt\x94\x8cU/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/bowtie2_RS_C1_V_tot_unique_covstats.txt\x94\x8cU/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/bowtie2_RS_C2_V_tot_unique_covstats.txt\x94\x8cU/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/bowtie2_RS_C3_V_tot_unique_covstats.txt\x94\x8cU/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/bowtie2_RS_C4_V_tot_unique_covstats.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/bowtie2_RS_CIT1B_V_tot_unique_covstats.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/bowtie2_RS_CIT1F_V_tot_unique_covstats.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/bowtie2_RS_CIT2B_V_tot_unique_covstats.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/bowtie2_RS_CIT2F_V_tot_unique_covstats.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/bowtie2_RS_CIT3B_V_tot_unique_covstats.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/bowtie2_RS_CIT3F_V_tot_unique_covstats.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/bowtie2_RS_CIT4B_V_tot_unique_covstats.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/bowtie2_RS_CIT4F_V_tot_unique_covstats.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/bowtie2_RS_CNT1B_V_tot_unique_covstats.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/bowtie2_RS_CNT1F_V_tot_unique_covstats.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/bowtie2_RS_CNT2B_V_tot_unique_covstats.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/bowtie2_RS_CNT2F_V_tot_unique_covstats.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/bowtie2_RS_CNT3B_V_tot_unique_covstats.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/bowtie2_RS_CNT3F_V_tot_unique_covstats.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/bowtie2_RS_CNT4B_V_tot_unique_covstats.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/bowtie2_RS_CNT4F_V_tot_unique_covstats.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/bowtie2_RS_OIT1B_V_tot_unique_covstats.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/bowtie2_RS_OIT1F_V_tot_unique_covstats.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/bowtie2_RS_OIT2B_V_tot_unique_covstats.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/bowtie2_RS_OIT2F_V_tot_unique_covstats.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/bowtie2_RS_OIT3B_V_tot_unique_covstats.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/bowtie2_RS_OIT3F_V_tot_unique_covstats.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/bowtie2_RS_OIT4B_V_tot_unique_covstats.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/bowtie2_RS_OIT4F_V_tot_unique_covstats.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/bowtie2_RS_ORT1B_V_tot_unique_covstats.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/bowtie2_RS_ORT1F_V_tot_unique_covstats.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/bowtie2_RS_ORT2B_V_tot_unique_covstats.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/bowtie2_RS_ORT2F_V_tot_unique_covstats.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/bowtie2_RS_ORT3B_V_tot_unique_covstats.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/bowtie2_RS_ORT3F_V_tot_unique_covstats.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/bowtie2_RS_ORT4B_V_tot_unique_covstats.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/bowtie2_RS_ORT4F_V_tot_unique_covstats.txt\x94e}\x94(\x8c\x06_names\x94}\x94(\x8c\npostqc_txt\x94K\x00N\x86\x94\x8c\x08covstats\x94K\x01KI\x86\x94\x8c\x0fcovstats_unique\x94KIK\x91\x86\x94u\x8c\x12_allowed_overrides\x94]\x94(\x8c\x05index\x94\x8c\x04sort\x94eh\xa6\x8c\tfunctools\x94\x8c\x07partial\x94\x93\x94h\x06\x8c\x19Namedlist._used_attribute\x94\x93\x94\x85\x94R\x94(h\xac)}\x94\x8c\x05_name\x94h\xa6sNt\x94bh\xa7h\xaah\xac\x85\x94R\x94(h\xac)}\x94h\xb0h\xa7sNt\x94bh\x9eh\nh\xa0h\x06\x8c\tNamedlist\x94\x93\x94)\x81\x94(h\x0bh\x0ch\rh\x0eh\x0fh\x10h\x11h\x12h\x13h\x14h\x15h\x16h\x17h\x18h\x19h\x1ah\x1bh\x1ch\x1dh\x1eh\x1fh h!h"h#h$h%h&h\'h(h)h*h+h,h-h.h/h0h1h2h3h4h5h6h7h8h9h:h;h<h=h>h?h@hAhBhChDhEhFhGhHhIhJhKhLhMhNhOhPhQhRe}\x94(h\x9c}\x94h\xa4]\x94(h\xa6h\xa7eh\xa6h\xaah\xac\x85\x94R\x94(h\xac)}\x94h\xb0h\xa6sNt\x94bh\xa7h\xaah\xac\x85\x94R\x94(h\xac)}\x94h\xb0h\xa7sNt\x94bubh\xa2h\xb7)\x81\x94(hShThUhVhWhXhYhZh[h\\h]h^h_h`hahbhchdhehfhghhhihjhkhlhmhnhohphqhrhshthuhvhwhxhyhzh{h|h}h~h\x7fh\x80h\x81h\x82h\x83h\x84h\x85h\x86h\x87h\x88h\x89h\x8ah\x8bh\x8ch\x8dh\x8eh\x8fh\x90h\x91h\x92h\x93h\x94h\x95h\x96h\x97h\x98h\x99h\x9ae}\x94(h\x9c}\x94h\xa4]\x94(h\xa6h\xa7eh\xa6h\xaah\xac\x85\x94R\x94(h\xac)}\x94h\xb0h\xa6sNt\x94bh\xa7h\xaah\xac\x85\x94R\x94(h\xac)}\x94h\xb0h\xa7sNt\x94bubub\x8c\x06output\x94h\x06\x8c\x0bOutputFiles\x94\x93\x94)\x81\x94(\x8c>/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/RPKM_raw_tot.txt\x94\x8cE/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/RPKM_normalised_tot.txt\x94\x8c@/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/counts_raw_tot.txt\x94\x8cG/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/counts_normalised_tot.txt\x94\x8cN/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/breadth_coverage_percent_tot.txt\x94\x8cL/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/breadth_coverage_bases_tot.txt\x94\x8cG/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/filtered_RPKM_raw_tot.txt\x94\x8cN/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/filtered_RPKM_normalised_tot.txt\x94\x8cI/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/filtered_counts_raw_tot.txt\x94\x8cP/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/filtered_counts_normalised_tot.txt\x94\x8cJ/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/filtered_75_RPKM_raw_tot.txt\x94\x8cQ/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING/filtered_75_RPKM_normalised_tot.txt\x94e}\x94(h\x9c}\x94(\x8c\rraw_RPKM_file\x94K\x00N\x86\x94\x8c\x0enorm_RPKM_file\x94K\x01N\x86\x94\x8c\x0eraw_count_file\x94K\x02N\x86\x94\x8c\x0fnorm_count_file\x94K\x03N\x86\x94\x8c\x12coverage_RPKM_file\x94K\x04N\x86\x94\x8c\x18coverage_bases_RPKM_file\x94K\x05N\x86\x94\x8c\x16filtered_raw_RPKM_file\x94K\x06N\x86\x94\x8c\x17filtered_norm_RPKM_file\x94K\x07N\x86\x94\x8c\x17filtered_raw_count_file\x94K\x08N\x86\x94\x8c\x18filtered_norm_count_file\x94K\tN\x86\x94\x8c\x19filtered_75_raw_RPKM_file\x94K\nN\x86\x94\x8c\x1afiltered_75_norm_RPKM_file\x94K\x0bN\x86\x94uh\xa4]\x94(h\xa6h\xa7eh\xa6h\xaah\xac\x85\x94R\x94(h\xac)}\x94h\xb0h\xa6sNt\x94bh\xa7h\xaah\xac\x85\x94R\x94(h\xac)}\x94h\xb0h\xa7sNt\x94bh\xe2h\xd4h\xe4h\xd5h\xe6h\xd6h\xe8h\xd7h\xeah\xd8h\xech\xd9h\xeeh\xdah\xf0h\xdbh\xf2h\xdch\xf4h\xddh\xf6h\xdeh\xf8h\xdfub\x8c\x06params\x94h\x06\x8c\x06Params\x94\x93\x94)\x81\x94(]\x94(\x8c\x06B_C1_V\x94\x8c\x06B_C2_V\x94\x8c\x06B_C3_V\x94\x8c\x06B_C4_V\x94\x8c\tB_CIT1B_V\x94\x8c\tB_CIT1F_V\x94\x8c\tB_CIT2B_V\x94\x8c\tB_CIT2F_V\x94\x8c\tB_CIT3B_V\x94\x8c\tB_CIT3F_V\x94\x8c\tB_CIT4B_V\x94\x8c\tB_CIT4F_V\x94\x8c\tB_CNT1B_V\x94\x8c\tB_CNT1F_V\x94\x8c\tB_CNT2B_V\x94\x8c\tB_CNT2F_V\x94\x8c\tB_CNT3B_V\x94\x8c\tB_CNT3F_V\x94\x8c\tB_CNT4B_V\x94\x8c\tB_CNT4F_V\x94\x8c\tB_OIT1B_V\x94\x8c\tB_OIT1F_V\x94\x8c\tB_OIT2B_V\x94\x8c\tB_OIT2F_V\x94\x8c\tB_OIT3B_V\x94\x8c\tB_OIT3F_V\x94\x8c\tB_OIT4B_V\x94\x8c\tB_OIT4F_V\x94\x8c\tB_ORT1B_V\x94\x8c\tB_ORT1F_V\x94\x8c\tB_ORT2B_V\x94\x8c\tB_ORT2F_V\x94\x8c\tB_ORT3B_V\x94\x8c\tB_ORT3F_V\x94\x8c\tB_ORT4B_V\x94\x8c\tB_ORT4F_V\x94\x8c\x07RS_C1_V\x94\x8c\x07RS_C2_V\x94\x8c\x07RS_C3_V\x94\x8c\x07RS_C4_V\x94\x8c\nRS_CIT1B_V\x94\x8c\nRS_CIT1F_V\x94\x8c\nRS_CIT2B_V\x94\x8c\nRS_CIT2F_V\x94\x8c\nRS_CIT3B_V\x94\x8c\nRS_CIT3F_V\x94\x8c\nRS_CIT4B_V\x94\x8c\nRS_CIT4F_V\x94\x8c\nRS_CNT1B_V\x94\x8c\nRS_CNT1F_V\x94\x8c\nRS_CNT2B_V\x94\x8c\nRS_CNT2F_V\x94\x8c\nRS_CNT3B_V\x94\x8c\nRS_CNT3F_V\x94\x8c\nRS_CNT4B_V\x94\x8c\nRS_CNT4F_V\x94\x8c\nRS_OIT1B_V\x94\x8c\nRS_OIT1F_V\x94\x8c\nRS_OIT2B_V\x94\x8c\nRS_OIT2F_V\x94\x8c\nRS_OIT3B_V\x94\x8c\nRS_OIT3F_V\x94\x8c\nRS_OIT4B_V\x94\x8c\nRS_OIT4F_V\x94\x8c\nRS_ORT1B_V\x94\x8c\nRS_ORT1F_V\x94\x8c\nRS_ORT2B_V\x94\x8c\nRS_ORT2F_V\x94\x8c\nRS_ORT3B_V\x94\x8c\nRS_ORT3F_V\x94\x8c\nRS_ORT4B_V\x94\x8c\nRS_ORT4F_V\x94e\x8c-/home/lmf/DANIEL/VIRAL_METAGENOMES/06_MAPPING\x94\x8c0/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA\x94\x8c\x03tot\x94K\xc8G?\xb9\x99\x99\x99\x99\x99\x9a\x8c\x00\x94e}\x94(h\x9c}\x94(\x8c\x07samples\x94K\x00N\x86\x94\x8c\x0bmapping_dir\x94K\x01N\x86\x94\x8c\tclean_dir\x94K\x02N\x86\x94\x8c\x08sampling\x94K\x03N\x86\x94\x8c\x0fthreshold_bases\x94K\x04N\x86\x94\x8c\x0ethreshold_RPKM\x94K\x05N\x86\x94\x8c\treference\x94K\x06N\x86\x94uh\xa4]\x94(h\xa6h\xa7eh\xa6h\xaah\xac\x85\x94R\x94(h\xac)}\x94h\xb0h\xa6sNt\x94bh\xa7h\xaah\xac\x85\x94R\x94(h\xac)}\x94h\xb0h\xa7sNt\x94bjV\x01\x00\x00j\x07\x01\x00\x00jX\x01\x00\x00jP\x01\x00\x00jZ\x01\x00\x00jQ\x01\x00\x00j\\\x01\x00\x00jR\x01\x00\x00j^\x01\x00\x00K\xc8j`\x01\x00\x00G?\xb9\x99\x99\x99\x99\x99\x9ajb\x01\x00\x00jS\x01\x00\x00ub\x8c\twildcards\x94h\x06\x8c\tWildcards\x94\x93\x94)\x81\x94jR\x01\x00\x00a}\x94(h\x9c}\x94\x8c\x08sampling\x94K\x00N\x86\x94sh\xa4]\x94(h\xa6h\xa7eh\xa6h\xaah\xac\x85\x94R\x94(h\xac)}\x94h\xb0h\xa6sNt\x94bh\xa7h\xaah\xac\x85\x94R\x94(h\xac)}\x94h\xb0h\xa7sNt\x94bj\\\x01\x00\x00jR\x01\x00\x00ub\x8c\x07threads\x94K\x01\x8c\tresources\x94h\x06\x8c\tResources\x94\x93\x94)\x81\x94(K\x01K\x01\x8c\x04/tmp\x94e}\x94(h\x9c}\x94(\x8c\x06_cores\x94K\x00N\x86\x94\x8c\x06_nodes\x94K\x01N\x86\x94\x8c\x06tmpdir\x94K\x02N\x86\x94uh\xa4]\x94(h\xa6h\xa7eh\xa6h\xaah\xac\x85\x94R\x94(h\xac)}\x94h\xb0h\xa6sNt\x94bh\xa7h\xaah\xac\x85\x94R\x94(h\xac)}\x94h\xb0h\xa7sNt\x94bj\x86\x01\x00\x00K\x01j\x88\x01\x00\x00K\x01j\x8a\x01\x00\x00j\x83\x01\x00\x00ub\x8c\x03log\x94h\x06\x8c\x03Log\x94\x93\x94)\x81\x94\x8cC/home/lmf/DANIEL/VIRAL_METAGENOMES/NOTEBOOKS/07_Normalise.tot.ipynb\x94a}\x94(h\x9c}\x94\x8c\x08notebook\x94K\x00N\x86\x94sh\xa4]\x94(h\xa6h\xa7eh\xa6h\xaah\xac\x85\x94R\x94(h\xac)}\x94h\xb0h\xa6sNt\x94bh\xa7h\xaah\xac\x85\x94R\x94(h\xac)}\x94h\xb0h\xa7sNt\x94bj\x9c\x01\x00\x00j\x99\x01\x00\x00ub\x8c\x06config\x94}\x94(\x8c\tinput_dir\x94\x8c./home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA\x94\x8c\tkraken_db\x94\x8c\x1b/home/lmf/db/KRAKEN/kraken/\x94\x8c\rkrakenUniq_db\x94\x8c\x1e/home/lmf/db/KRAKEN/KrakenUniq\x94\x8c\necc_memory\x94M\x80>\x8c\x0bsubassembly\x94\x88\x8c\x1cadditional_reference_contigs\x94\x8c7/home/lmf/DANIEL/VIRAL_METAGENOMES/WRB_75_contigs.fasta\x94\x8c\x0eassembly_stats\x94\x88\x8c\x0bsubsampling\x94\x88\x8c\x0fmin_votu_length\x94M\x10\'\x8c\x0crun_vcontact\x94\x88\x8c\x0bimgvr_blast\x94\x88\x8c\x08run_DRAM\x94\x88\x8c\x11microbial_spacers\x94\x8c\\/home/lmf/DANIEL/MG-Assembly/ALL_MG_megahit_2000bp_derreplicated_minced_predicted_spacers.fa\x94\x8c\x0bresults_dir\x94jS\x01\x00\x00\x8c\nmetagenome\x94\x88\x8c\tmicrobial\x94\x89\x8c\x08sourmash\x94\x89\x8c\x0bkey_samples\x94\x8c\x14key_samples_list.csv\x94\x8c\x10operating_system\x94\x8c\x05linux\x94\x8c\x0bforward_tag\x94\x8c\x02R1\x94\x8c\x0breverse_tag\x94\x8c\x02R2\x94\x8c\x0cnanopore_tag\x94\x8c\x08nanopore\x94\x8c\x0fnanopore_pooled\x94\x89\x8c\x14nanopore_pooled_name\x94\x8c\x03raw\x94\x8c\x0elong_assembler\x94\x8c\x04canu\x94\x8c\x0bgenome_size\x94\x8c\x0320m\x94\x8c\x13trimmomatic_leading\x94\x8c\x0220\x94\x8c\x14trimmomatic_trailing\x94\x8c\x0220\x94\x8c\x17trimmomatic_window_size\x94\x8c\x014\x94\x8c\x1atrimmomatic_window_quality\x94\x8c\x0220\x94\x8c\x12trimmomatic_minlen\x94\x8c\x0250\x94\x8c\x10nanopore_quality\x94\x8c\x0210\x94\x8c\x0fnanopore_minlen\x94M\xe8\x03\x8c\x0fnanopore_maxlen\x94J\x80\x96\x98\x00\x8c\tVirSorter\x94\x89\x8c\x0ecross_assembly\x94\x89\x8c\nlong_index\x94\x89\x8c\x16representative_contigs\x94jS\x01\x00\x00\x8c\x08sra_list\x94jS\x01\x00\x00\x8c\x0eextract_mapped\x94\x89\x8c\x07p_ident\x94\x8c\x0295\x94\x8c\x0bkmer_window\x94\x8c\x0525000\x94\x8c\x08min_norm\x94\x8c\x010\x94\x8c\x08max_norm\x94\x8c\x03100\x94\x8c\rmax_subsample\x94\x8c\x0850000000\x94\x8c\x07min_len\x94\x8c\x041000\x94\x8c\x07min_cov\x94\x8c\x012\x94\x8c\x11contaminants_list\x94jS\x01\x00\x00\x8c\radapters_file\x94\x8c\x0badapters.fa\x94\x8c\x11ambiguous_mapping\x94\x8c\x03all\x94\x8c\x0ebasecalled_dir\x94\x8c\x10data/basecalled/\x94\x8c\x13reference_databases\x94\x8c\x1eIMGVR GenBankViral RefSeqViral\x94\x8c\x08IMGVR_db\x94\x8c!/home/lmf/db/IMG_VR_2022-12-19_7/\x94\x8c\x0eRefSeqViral_db\x94\x8c6/home/lmf/db/RefSeqViral/RefSeq_viral_2024_09_03.fasta\x94\x8c\x0bpharokka_db\x94N\x8c\x08blast_db\x94\x8c\x1fdb/ncbi/NCBI_viral_proteins.faa\x94\x8c\x0cvirSorter_db\x94\x8c\x1bdb/VirSorter/virsorter-data\x94\x8c\x0ckraken_db_nt\x94\x8c\x17/home/lmf/db/KRAKEN/nt/\x94\x8c\x0fkraken_db_human\x94\x8c\x13db/kraken2_human_db\x94\x8c\x0ckraken_tools\x94\x8c\x11tools/KrakenTools\x94\x8c\x0bbracken_dir\x94\x8c\rtools/Bracken\x94\x8c\nweesam_dir\x94\x8c\x0ctools/weeSAM\x94\x8c\tcheckv_db\x94\x8c\x11db/checkv-db-v1.5\x94\x8c\tcheckm_db\x94\x8c\x0cdb/checkm-db\x94\x8c\x08iphop_db\x94\x8c\x0bdb/iphop_db\x94\x8c\rtaxmyphage_db\x94\x8c\x10db/taxmyphage_db\x94\x8c\x0csourmash_sig\x94\x8c7/home/lmf/db/SOURMASH/matrix_09_42_sourmash_k31.sig.zip\x94\x8c\x10sourmash_rocksdb\x94\x8c;/home/lmf/db/SOURMASH/matrix_09_42_sourmash_k31.sig.rocksdb\x94\x8c\x0csourmash_tax\x94\x8c9/home/lmf/db/SOURMASH/taxonomy/taxonomy_matrix_strain.csv\x94\x8c\x08canu_dir\x94\x8c\x1etools/canu-2.0/Linux-amd64/bin\x94\x8c\x12PhaGCN_newICTV_dir\x94\x8c\x14tools/PhaGCN_newICTV\x94\x8c\tquast_dir\x94\x8c\x11tools/quast-5.0.2\x94\x8c\rvirSorter_dir\x94\x8c\x0ftools/VirSorter\x94\x8c\x07WTP_dir\x94\x8c\ttools/WTP\x94\x8c\rvirFinder_dir\x94\x8c\x0ftools/VirFinder\x94\x8c\x0eclusterONE_dir\x94\x8c\x10tools/clusterONE\x94\x8c\x0cvcontact_dir\x94\x8c\x0ftools/vcontact2\x94\x8c\x1areference_genomes_vcontact\x94\x8c\x04None\x94\x8c\rtaxonomy_file\x94\x8c1db/vcontact2/formatting_taxonomy_affiliations.csv\x94\x8c\ngenomad_db\x94\x8c\rdb/genomad_db\x94\x8c\x07DRAM_db\x94\x8c\ndb/DRAM_db\x94\x8c\tgtdbtk_db\x94\x8c\ndb/GTDB-Tk\x94\x8c\nmmseqs_dir\x94\x8c\rtools/MMseqs2\x94\x8c\x08viga_dir\x94\x8c\ntools/viga\x94\x8c\tpiler_dir\x94\x8c\x11tools/pilercr1.06\x94\x8c\x07trf_dir\x94\x8c\ttools/TRF\x94\x8c\x0bvibrant_dir\x94\x8c\rtools/VIBRANT\x94\x8c\x0eviridic_folder\x94\x8c\x17tools/viridic_v1.0_r3.6\x94\x8c\x0fsra_toolkit_dir\x94\x8c tools/sratoolkit.2.10.0-ubuntu64\x94\x8c\x07ALE_dir\x94\x8c\ttools/ALE\x94\x8c\x08wish_dir\x94\x8c\ntools/WIsH\x94\x8c\nminced_dir\x94\x8c\x0ctools/minced\x94\x8c\x07dion_db\x94\x8c\x0cdb/dionSetDB\x94u\x8c\x04rule\x94\x8c\x0fnormalise_reads\x94\x8c\x0fbench_iteration\x94N\x8c\tscriptdir\x94\x8c//home/lmf/apps/MOSAIC/mosaic/rules/../notebooks\x94ub.'); from snakemake.logging import logger; logger.printshellcmds = True; import os; os.chdir(r'/home/lmf/apps/MOSAIC/mosaic');
######## snakemake preamble end #########

# %%
# import necessary modules
import pandas as pd
import seaborn as sns; sns.set()
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap
import numpy as np
import math
from matplotlib import colors

#------------------------------------------
cmap1=LinearSegmentedColormap.from_list("my_colormap", sns.color_palette("colorblind", n_colors=5))


sns.set_style("ticks",{'axes.grid' : True})
sns.set_palette("colorblind")

plt.rcParams["axes.linewidth"] = 1.5
plt.rcParams["xtick.major.width"] = 1.5
plt.rcParams["ytick.major.width"] = 1.5
plt.rcParams["xtick.major.size"] = 8
plt.rcParams["ytick.major.size"] = 8
plt.rcParams["axes.titlepad"] = 20

plt.rcParams['svg.fonttype'] = 'none'
plt.rcParams["axes.titlesize"] = 30
plt.rcParams['axes.labelsize'] = 23.5
plt.rcParams['xtick.labelsize'] = 18
plt.rcParams['ytick.labelsize'] = 18
plt.rcParams['legend.fontsize'] = 18
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = ['Liberation Sans']
plt.rcParams['text.usetex'] = False

plt.rcParams['svg.fonttype'] = 'none'
plt.rcParams["savefig.dpi"]=300

# %%
SAMPLING=snakemake.params.sampling
illumina_postqc=snakemake.input.postqc_txt
mapping_dir=snakemake.params.mapping_dir
clean_dir=snakemake.params.clean_dir
threshold_bases=snakemake.params.threshold_bases
REFERENCE=snakemake.params.reference
THRESHOLD_RPKM=snakemake.params.threshold_RPKM

out_raw_RPKM_file=snakemake.output.raw_RPKM_file
out_norm_RPKM_file=snakemake.output.norm_RPKM_file
out_raw_count_file=snakemake.output.raw_count_file
out_norm_count_file=snakemake.output.norm_count_file
out_coverage_RPKM_file=snakemake.output.coverage_RPKM_file
out_coverage_bases_RPKM_file=snakemake.output.coverage_bases_RPKM_file

out_filtered_raw_RPKM_file=snakemake.output.filtered_raw_RPKM_file
out_filtered_norm_RPKM_file=snakemake.output.filtered_norm_RPKM_file
out_filtered_raw_count_file=snakemake.output.filtered_raw_count_file
out_filtered_norm_count_file=snakemake.output.filtered_norm_count_file
out_filtered_75_raw_RPKM_file=snakemake.output.filtered_75_raw_RPKM_file
out_filtered_75_norm_RPKM_file=snakemake.output.filtered_75_norm_RPKM_file

# %%
postqc = pd.read_csv(illumina_postqc, sep="\t")

# # create a new dataframe with columns for Filename, average sequence length, and total sequences from the postqc dataframe
read_stats_df2 = postqc[["Filename","avg_sequence_length"]]

# replace certain portions of the Filename column with standard suffixes (e.g. _forward -> _R1)
read_stats_df2.loc[:, "Filename"] = read_stats_df2["Filename"].str.replace("_forward", "_R1")
read_stats_df2.loc[:, "Filename"] = read_stats_df2["Filename"].str.replace("_reverse", "_R2")
read_stats_df2.loc[:, "Filename"] = read_stats_df2["Filename"].str.replace("_unpaired", "_U")
read_stats_df2.loc[:, "Filename"] = read_stats_df2["Filename"].str.split("_paired").str[0]
read_stats_df2.loc[:, "Filename"] = read_stats_df2["Filename"].str.split("_clean").str[0]

# create a new columns in read_stats_df2 for the sample name, based on the first part of the Filename (before the final underscore)
read_stats_df2.loc[:, "Sample"] = read_stats_df2["Filename"].str.rsplit("_",n=1).str[0]
read_stats_df2.loc[:, "Read_type"] = read_stats_df2["Filename"].str.rsplit("_",n=1).str[1]

# set the Filename column as the index of read_stats_df2
read_stats_df2 = read_stats_df2.set_index('Filename')

# rename the columns of read_stats_df2
read_stats_df2.columns=["length_post", "sample", "Read_type"]
read_stats_df2=read_stats_df2[read_stats_df2["Read_type"]!="U"]
read_length_paired=read_stats_df2.groupby("sample").mean(numeric_only=True)
read_length_paired.loc[:, "length_post"] = read_length_paired["length_post"].round(2)
read_length_paired
# Out:
# /home/lmf/anaconda3/envs/Mosaic_workflow/lib/python3.9/site-packages/pandas/core/indexing.py:1745: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(ilocs[0], value)
# /home/lmf/anaconda3/envs/Mosaic_workflow/lib/python3.9/site-packages/pandas/core/indexing.py:1596: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = _infer_fill_value(value)
#             length_post
# sample
# B_C1_V           144.10
# B_C2_V           144.40
# B_C3_V           143.69
# ...

# %%
SAMPLES=read_length_paired.index.to_list()
SAMPLES
# Out:
# ['B_C1_V',
#  'B_C2_V',
#  'B_C3_V',
#  'B_C4_V',
#  'B_CIT1B_V',
#  'B_CIT1F_V',
#  'B_CIT2B_V',
#  'B_CIT2F_V',
#  'B_CIT3B_V',
#  'B_CIT3F_V',
#  'B_CIT4B_V',
#  'B_CIT4F_V',
#  'B_CNT1B_V',
#  'B_CNT1F_V',
#  'B_CNT2B_V',
#  'B_CNT2F_V',
#  'B_CNT3B_V',
#  'B_CNT3F_V',
#  'B_CNT4B_V',
#  'B_CNT4F_V',
#  'B_OIT1B_V',
#  'B_OIT1F_V',
#  'B_OIT2B_V',
#  'B_OIT2F_V',
#  'B_OIT3B_V',
#  'B_OIT3F_V',
#  'B_OIT4B_V',
#  'B_OIT4F_V',
#  'B_ORT1B_V',
#  'B_ORT1F_V',
#  'B_ORT2B_V',
#  'B_ORT2F_V',
#  'B_ORT3B_V',
#  'B_ORT3F_V',
#  'B_ORT4B_V',
#  'B_ORT4F_V',
#  'RS_C1_V',
#  'RS_C2_V',
#  'RS_C3_V',
#  'RS_C4_V',
#  'RS_CIT1B_V',
#  'RS_CIT1F_V',
#  'RS_CIT2B_V',
#  'RS_CIT2F_V',
#  'RS_CIT3B_V',
#  'RS_CIT3F_V',
#  'RS_CIT4B_V',
#  'RS_CIT4F_V',
#  'RS_CNT1B_V',
#  'RS_CNT1F_V',
#  'RS_CNT2B_V',
#  'RS_CNT2F_V',
#  'RS_CNT3B_V',
#  'RS_CNT3F_V',
#  'RS_CNT4B_V',
#  'RS_CNT4F_V',
#  'RS_OIT1B_V',
#  'RS_OIT1F_V',
#  'RS_OIT2B_V',
#  'RS_OIT2F_V',
#  'RS_OIT3B_V',
#  'RS_OIT3F_V',
# ...

# %%
#!/usr/bin/env python3

# Written by Alejandro Reyes
# Reformatted & Edited Laura Forero

def normalise_rpkm_bt2(sample,all_file, toss_file, paired_len):
    all_df=pd.read_csv(all_file, sep="\t")
    toss_df=pd.read_csv(toss_file, sep="\t")

    all_df.columns=["ID", "Avg_fold", "Length", "Covered_bases", "Read_Count", "Variance", "Trimmed Mean", "RPKM_" + sample]
    all_df["Covered_percent"]=all_df["Covered_bases"]*100/all_df["Length"]
    all_df=all_df.drop(columns=["Avg_fold","Variance", "Trimmed Mean"])
    all_df=all_df.add_suffix('_all')

    toss_df.columns=["ID", "Avg_fold", "Length", "Covered_bases", "Read_Count", "Variance", "Trimmed Mean", "RPKM_" + sample]
    toss_df["Covered_percent"]=toss_df["Covered_bases"]*100/toss_df["Length"]
    toss_df=toss_df.drop(columns=[ "Avg_fold","Variance", "Trimmed Mean"])
    toss_df=toss_df.add_suffix('_toss')

    
    combined_df=all_df.merge(toss_df, left_on="ID_all", right_on="ID_toss")
    combined_df=combined_df.drop(columns=["ID_toss", "Length_toss"])
    
    combined_df["extra_reads"]=abs(combined_df["Read_Count_all"]-combined_df["Read_Count_toss"])
    combined_df["test"]= (combined_df["Read_Count_all"]* 1E6/((combined_df["Length_all"]/1000)*combined_df["Read_Count_all"].sum()))

    combined_df["toss_cov"] = combined_df.apply(lambda row: (row["Read_Count_toss"] / row["Covered_bases_toss"]) if row["Covered_bases_toss"] > 0 else 0, axis=1)
    combined_df["delta_map_base"] = abs(combined_df["Covered_bases_all"]-combined_df["Covered_bases_toss"])
    combined_df["needed_reads"] = round(combined_df["toss_cov"]*combined_df["delta_map_base"]*0.9)

    combined_df["extra"] = combined_df.apply(lambda row: min(abs(row["extra_reads"]), abs(row["needed_reads"])), axis=1)
    
    combined_df["cov_ratio"]=np.log10((combined_df["Covered_percent_all"]+1)/(combined_df["Covered_percent_toss"]+1))

    combined_df["needed_ratio"]=np.log10((combined_df["needed_reads"]+1)/(combined_df["extra_reads"]+1))
    combined_df["Read_count_norm_" + sample] = (combined_df["Read_Count_toss"]+combined_df["extra"]).astype('int')

    threshold = threshold_bases 
    combined_df.loc[(combined_df["Covered_bases_toss"] < threshold) & (combined_df["Read_count_norm_" + sample] > 0), ["Read_count_norm_" + sample]] = 0

    total_reads_map = combined_df["Read_Count_toss"].sum()
    total_reads_map=total_reads_map+combined_df["extra"].sum()
    combined_df["RPKM_norm_" + sample] = ((combined_df["Read_count_norm_" + sample])* 1E9)/(combined_df["Length_all"]*total_reads_map)
    
    combined_df["exp_ratio"] = combined_df.apply(lambda row: np.log10(100 * (1 - math.exp(-1 * ((row["Read_Count_toss"] + row["needed_reads"]) * paired_len) / row["Length_all"])) / row["Covered_percent_all"]) if (row["Read_Count_toss"] > 0) and (total_reads_map > 0) else 0, axis=1)
    
    combined_df=combined_df[['ID_all', 'Length_all', "Read_Count_all", "Read_Count_toss",'RPKM_'+ sample + '_all', 'Covered_percent_all' , 'RPKM_'+ sample + '_toss', 'Covered_percent_toss', "Read_count_norm_" + sample, 'RPKM_norm_'+ sample, "Covered_bases_all", "Covered_bases_toss"]]
    combined_df.columns=['Contig', 'Length_' + sample,"Count_" + sample, "Read_Count_toss_" + sample,'RPKM_'+ sample + '_all', 'Covered_percent_all_'+ sample , 'RPKM_'+ sample + '_toss', 'Covered_percent_toss_' + sample, "Count_norm_" + sample , 'RPKM_norm_'+ sample, "Covered_bases_all_" + sample, "Covered_bases_toss_" + sample ]
    return(combined_df)

# %%
def filter_abundances(RPKM, counts, coverage_bases, coverage_percent, contig_length):
    contig_lengths_6667 = contig_length >= 6667
    bases_covered_gt_5000 = coverage_bases > 5000
    percentage_covered_gt_75 = coverage_percent > 75

    # # Create a filtered abundance DataFrame with the same shape as RPKM_raw, initialized with zeros
    filtered_RPKM_df = pd.DataFrame(0, index=RPKM.index, columns=RPKM.columns)
    filtered_counts_df = pd.DataFrame(0, index=RPKM.index, columns=RPKM.columns)

    condition1 = contig_lengths_6667 & bases_covered_gt_5000
    condition2 = ~contig_lengths_6667 & percentage_covered_gt_75

    filtered_RPKM_df[condition1] = RPKM[condition1]
    filtered_RPKM_df[condition2] = RPKM[condition2]
    
    filtered_counts_df[condition1] = counts[condition1]
    filtered_counts_df[condition2] = counts[condition2]
    
    # threshold_RPKM=THRESHOLD_RPKM
    # filtered_RPKM_df[filtered_RPKM_df<threshold_RPKM]=0
    # filtered_counts_df[filtered_RPKM_df<threshold_RPKM]=0
    
    return(filtered_RPKM_df, filtered_counts_df)

def filter_abundances_75(RPKM, coverage_bases, coverage_percent, contig_length):
    percentage_covered_gt_75 = coverage_percent > 75

    # # Create a filtered abundance DataFrame with the same shape as RPKM_raw, initialized with zeros
    filtered_RPKM_df = pd.DataFrame(0, index=RPKM.index, columns=RPKM.columns)

    filtered_RPKM_df[percentage_covered_gt_75] = RPKM[percentage_covered_gt_75]

    return(filtered_RPKM_df)

# %%
print("NUMBER OF SAMPLES =" , len(SAMPLES))

n=0
for sample in SAMPLES:
    print(round(((n+1) * 100 / len(SAMPLES)),1), "%", end='\r')
    if len(REFERENCE)>0:
        all_file=mapping_dir + "/REFERENCES/bowtie2_" + REFERENCE + "_" + sample + "_" + SAMPLING + "_covstats.txt"
        toss_file=mapping_dir + "/REFERENCES/bowtie2_" + REFERENCE + "_" + sample + "_" + SAMPLING + "_unique_covstats.txt"
    else:
        all_file=mapping_dir + "/bowtie2_" + sample + "_" + SAMPLING + "_covstats.txt"
        toss_file=mapping_dir + "/bowtie2_" + sample + "_"+ SAMPLING + "_unique_covstats.txt"
    
    read_len=int(read_length_paired.loc[sample]["length_post"])
    count_df=normalise_rpkm_bt2(sample,all_file, toss_file, read_len)  

    if n == 0:
        df_RPKM_norm = count_df[["Contig", "RPKM_norm_" + sample]]
        df_RPKM_raw = count_df[["Contig", "RPKM_" + sample + "_all"]]
        df_count_raw = count_df[["Contig", "Count_" + sample ]]
        df_count_norm = count_df[["Contig", "Count_norm_" + sample ]]
        df_RPKM_cov = count_df[["Contig", "Covered_percent_all_"+ sample]]
        df_RPKM_cov_bases = count_df[["Contig", "Covered_bases_all_"+ sample]]
        df_RPKM_len = count_df[["Contig", "Length_" + sample]]
        
    else:
        df_RPKM_norm = df_RPKM_norm.merge(count_df[["Contig", "RPKM_norm_" + sample]], on="Contig")
        df_RPKM_raw = df_RPKM_raw.merge(count_df[["Contig", "RPKM_" + sample + "_all"]], on="Contig")
        df_count_raw = df_count_raw.merge(count_df[["Contig", "Count_" + sample]], on="Contig")
        df_count_norm = df_count_norm.merge(count_df[["Contig", "Count_norm_" + sample ]], on="Contig")
        df_RPKM_cov = df_RPKM_cov.merge(count_df[["Contig", "Covered_percent_all_"+ sample]], on="Contig")
        df_RPKM_cov_bases = df_RPKM_cov_bases.merge(count_df[["Contig", "Covered_bases_all_"+ sample]], on="Contig")
        df_RPKM_len = df_RPKM_len.merge(count_df[["Contig", "Length_" + sample]], on="Contig")
        
    n=n+1

df_RPKM_raw=df_RPKM_raw.rename(columns={"Contig": "vOTU"}).set_index('vOTU')
df_RPKM_norm=df_RPKM_norm.rename(columns={"Contig": "vOTU"}).set_index('vOTU')
df_count_raw=df_count_raw.rename(columns={"Contig": "vOTU"}).set_index('vOTU')
df_count_norm=df_count_norm.rename(columns={"Contig": "vOTU"}).set_index('vOTU')
df_RPKM_cov=df_RPKM_cov.rename(columns={"Contig": "vOTU"}).set_index('vOTU')
df_RPKM_cov_bases=df_RPKM_cov_bases.rename(columns={"Contig": "vOTU"}).set_index('vOTU')
df_RPKM_len=df_RPKM_len.rename(columns={"Contig": "vOTU"}).set_index('vOTU')

df_RPKM_raw.columns = df_RPKM_raw.columns.str.replace(r'^RPKM_', '', regex=True).str.replace(r'_all$', '', regex=True)
df_RPKM_norm.columns = df_RPKM_norm.columns.str.replace(r'^RPKM_norm_', '', regex=True)
df_count_raw.columns = df_count_raw.columns.str.replace(r'^Count_', '', regex=True)
df_count_norm.columns = df_count_norm.columns.str.replace(r'^Count_norm_', '', regex=True)
df_RPKM_cov.columns = df_RPKM_cov.columns.str.replace(r'^Covered_percent_all_', '', regex=True)
df_RPKM_cov_bases.columns = df_RPKM_cov_bases.columns.str.replace(r'^Covered_bases_all_', '', regex=True)
df_RPKM_len.columns = df_RPKM_len.columns.str.replace(r'^Length_', '', regex=True)

df_mean_coverage_raw=df_count_raw.div(df_RPKM_len)
df_mean_coverage_norm=df_count_norm.div(df_RPKM_len)

df_RPKM_raw.to_csv(out_raw_RPKM_file)
df_RPKM_norm.to_csv(out_norm_RPKM_file)
df_RPKM_cov.to_csv(out_coverage_RPKM_file)
df_RPKM_cov_bases.to_csv(out_coverage_bases_RPKM_file)
df_count_raw.to_csv(out_raw_count_file)
df_count_norm.to_csv(out_norm_count_file)
# Out:
# NUMBER OF SAMPLES = 72
# 100.0 %

# %% [markdown]
# ## Subsampled

# %%
df_mapped_sub=pd.DataFrame()

if SAMPLING=="sub":
    mapped_pair=[]
    sub_reads=[]
    for sample in SAMPLES:
        content = open(mapping_dir + "/bowtie2_flagstats_filtered_" + sample + "." +  "sub.txt").readlines()
        mapped_pair.append(int(content[1].split()[0]) / 2)
        content2 = open(clean_dir + "/" + sample + "_sub_sampling_reads_final.txt").readline()
        sub_reads.append(int(content2))

    df_mapped_sub["sample"]=SAMPLES
    df_mapped_sub["mapped"]=mapped_pair
    df_mapped_sub["sub_reads"]=sub_reads
    df_mapped_sub["viral_reads"]=df_mapped_sub["mapped"]

    df_mapped_sub["%mapped"]=df_mapped_sub["mapped"]*100/df_mapped_sub["sub_reads"]
    df_mapped_sub.loc['mean'] = df_mapped_sub.mean(numeric_only=True)
    df_mapped_sub=df_mapped_sub.sort_values(by="viral_reads")
    # df_mapped_sub.sort_values(by="viral_reads").style.set_precision(2).background_gradient(cmap="RdYlGn", vmin=0)
df_mapped_sub.style.background_gradient(cmap="RdYlGn", vmin=0)
# Out:
# <style  type="text/css" >
# </style><table id="T_46b0dbf6_040a_11f0_83d2_b88303891ffc" ><thead></thead><tbody>
#         </tbody></table>

# %% [markdown]
# ## RPKM normalised vs raw
# Percentage indicates the ammount of contigs that lost coverage (0 now)

# %%
import numpy as np
import matplotlib.pyplot as plt

df_RPKM_norm2=df_RPKM_norm.copy()
df_RPKM_raw2=df_RPKM_raw.copy()
df_RPKM_cov2=df_RPKM_cov.copy()

col_names_norm = [col + "_norm" for col in df_RPKM_norm.columns]
col_names_raw = [col + "_raw" for col in df_RPKM_raw.columns]
col_names_cov = [col + "_cov" for col in df_RPKM_cov.columns]

df_RPKM_norm2.columns = col_names_norm
df_RPKM_raw2.columns = col_names_raw
df_RPKM_cov2.columns = col_names_cov


max_val=max(df_RPKM_norm.select_dtypes(include=[float]).max().max(),df_RPKM_raw.select_dtypes(include=[float]).max().max())
min_val=min(df_RPKM_norm.select_dtypes(include=[float]).replace(0, np.nan).min().min(),df_RPKM_raw.select_dtypes(include=[float]).replace(0, np.nan).min().min())
merged_df = df_RPKM_norm2.merge(df_RPKM_raw2, left_index=True,right_index=True).merge(df_RPKM_cov2, left_index=True,right_index=True)


# Determine common axis limits for log scale
max_val = max(df_RPKM_norm.select_dtypes(include=[float]).max().max(),
              df_RPKM_raw.select_dtypes(include=[float]).max().max())
min_val = min(df_RPKM_norm.select_dtypes(include=[float]).replace(0, np.nan).min().min(),
              df_RPKM_raw.select_dtypes(include=[float]).replace(0, np.nan).min().min())

# Set the limits to be the same for x and y axis
axis_limits = [min_val, max_val]


n_columns=4
# Set up the subplots
len_samples=len(SAMPLES)
if len_samples == 1:
    len_samples = n_columns +1


fig, axes = plt.subplots(nrows=(len_samples + n_columns-1) // n_columns, ncols=n_columns, figsize=(n_columns*3.74, ((len_samples + n_columns -1) // n_columns)*4.5), sharey=True, sharex=False)

# Your existing loop for plotting...
for i, sample in enumerate(SAMPLES):
    row = i // n_columns
    col = i % n_columns
    ax = axes[row, col]
    print(round(((i+1) * 100 / len(SAMPLES)),1), "%", end='\r')
    percent_0=round((len(merged_df[merged_df[sample + "_raw"]==0])/len(merged_df)-len(merged_df[merged_df[sample + "_norm"]==0])/len(merged_df))*100,2)
    ax.plot([-2.5, max_val-0.5], [-2.5, max_val-0.5], 'r--')
    ax.scatter(x=merged_df[sample + "_raw"], y=merged_df[sample + "_norm"], s=2, alpha=0.3)

    ax.set_xlim(axis_limits)
    ax.set_ylim(axis_limits)
    ax.set_title(sample)
    ax.set_xlabel("RPKM raw")
    ax.set_ylabel("RPKM normalised")

    ax.text(0.95, 0.05, str(percent_0) + '%', transform=ax.transAxes, ha='right', va='bottom',fontsize=20, color="firebrick")

    
    # Set the same ticks for both axes
    ax.set_xticklabels(ax.get_xticks(), rotation=90)

    ax.set_xscale('log')
    ax.set_yscale('log')   
    
    ax.set_xticks([10**i for i in range(int(np.log10(min_val)), int(np.log10(max_val))+1)])
    ax.set_yticks([10**i for i in range(int(np.log10(min_val)), int(np.log10(max_val))+1)])
#     ax.set_yticks([10**i for i in range(int(np.log10(min_val)), int(np.log10(max_val))+1)])

 
    
if len(SAMPLES) % n_columns != 0:
    for i in range(len(SAMPLES) % n_columns, n_columns):
        fig.delaxes(axes[-1, i])
        
plt.tight_layout()
plt.show()
# Out:
# 6.9 %
# /tmp/ipykernel_1471946/3227226573.py:61: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.get_xticks(), rotation=90)
# /tmp/ipykernel_1471946/3227226573.py:61: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.get_xticks(), rotation=90)
# /tmp/ipykernel_1471946/3227226573.py:61: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.get_xticks(), rotation=90)
# /tmp/ipykernel_1471946/3227226573.py:61: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.get_xticks(), rotation=90)
# /tmp/ipykernel_1471946/3227226573.py:61: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.get_xticks(), rotation=90)
# /tmp/ipykernel_1471946/3227226573.py:61: UserWarning: FixedFormatter should only be used together with FixedLocator
# ...

# %% [markdown]
# ## Length and raw RPKM of removed

# %%
len_df=df_RPKM_len[SAMPLES[0]].to_frame()
len_df.columns=["Length"]

merged_df = merged_df.sort_index()
len_df = len_df.sort_index()

len_samples=len(SAMPLES)
if len_samples == 1:
    len_samples = n_columns +1

fig, axes = plt.subplots(nrows=(len_samples+ 3) // 4, ncols=4, figsize=(16, ((len_samples + 3) // 4)*4.5),sharey=False,sharex=True)

n=0

for i, sample in enumerate(SAMPLES):
    row = i // 4
    col = i % 4
    ax = axes[row, col]
    zero_df_len=len_df[(merged_df[sample + "_raw"]>0) & (merged_df[sample + "_norm"]==0)]
    zero_df=merged_df[(merged_df[sample + "_raw"]>0) & (merged_df[sample + "_norm"]==0)]
    print(round(((i+1) * 100 / len(SAMPLES)),1), "%", end='\r')

    percent_0=round((len(merged_df[merged_df[sample + "_raw"]==0])/len(merged_df)-len(merged_df[merged_df[sample + "_norm"]==0])/len(merged_df))*100,2)
    bin_edges = [i * 1000 for i in range(0, 50)]
    ax.scatter( x=zero_df_len["Length"],y=zero_df[sample + "_raw"],)
    ax.set_title(sample)
    ax.set_xlabel("Contig length")
    ax.set_ylabel("RPKM")
    ax.text(0.95, 0.05, 'n=' + str(len(zero_df)) , transform=ax.transAxes, ha='right', va='bottom',fontsize=20, color="firebrick")

if len(SAMPLES) % 4 != 0:
    for i in range(len(SAMPLES) % 4, 4):
        fig.delaxes(axes[-1, i])
        
plt.tight_layout()
plt.show()
# Out:
# 100.0 %

# %% [markdown]
# # Filter by Coverage + RPKM

# %%
filtered_RPKM_raw_df,filtered_counts_raw_df=filter_abundances(df_RPKM_raw, df_count_raw, df_RPKM_cov_bases, df_RPKM_cov, df_RPKM_len)
filtered_RPKM_norm_df,filtered_counts_norm_df=filter_abundances(df_RPKM_norm, df_count_norm, df_RPKM_cov_bases, df_RPKM_cov, df_RPKM_len)
filtered_75_RPKM_raw_df=filter_abundances_75(df_RPKM_raw, df_RPKM_cov_bases, df_RPKM_cov, df_RPKM_len)
filtered_75_RPKM_norm_df=filter_abundances_75(df_RPKM_norm, df_RPKM_cov_bases, df_RPKM_cov, df_RPKM_len)

filtered_RPKM_raw_df.to_csv(out_filtered_raw_RPKM_file)
filtered_counts_raw_df.to_csv(out_filtered_raw_count_file)
filtered_RPKM_norm_df.to_csv(out_filtered_norm_RPKM_file)
filtered_counts_norm_df.to_csv(out_filtered_norm_count_file)
filtered_75_RPKM_raw_df.to_csv(out_filtered_75_raw_RPKM_file)
filtered_75_RPKM_norm_df.to_csv(out_filtered_75_norm_RPKM_file)
