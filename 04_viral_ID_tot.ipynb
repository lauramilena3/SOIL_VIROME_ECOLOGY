x05\x00\x00j\xb8\x05\x00\x00j\xba\x05\x00\x00\x85\x94R\x94(j\xba\x05\x00\x00)}\x94j\xbe\x05\x00\x00j\xb4\x05\x00\x00sNt\x94bj\xb5\x05\x00\x00j\xb8\x05\x00\x00j\xba\x05\x00\x00\x85\x94R\x94(j\xba\x05\x00\x00)}\x94j\xbe\x05\x00\x00j\xb5\x05\x00\x00sNt\x94bj\x97\x06\x00\x00j\x94\x06\x00\x00ub\x8c\x06config\x94}\x94(\x8c\tinput_dir\x94\x8c./home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA\x94\x8c\tkraken_db\x94\x8c\x1b/home/lmf/db/KRAKEN/kraken/\x94\x8c\rkrakenUniq_db\x94\x8c\x1e/home/lmf/db/KRAKEN/KrakenUniq\x94\x8c\necc_memory\x94M\x80>\x8c\x0bsubassembly\x94\x88\x8c\x1cadditional_reference_contigs\x94\x8c7/home/lmf/DANIEL/VIRAL_METAGENOMES/WRB_75_contigs.fasta\x94\x8c\x0eassembly_stats\x94\x88\x8c\x0bsubsampling\x94\x88\x8c\x0fmin_votu_length\x94M\x10\'\x8c\x0crun_vcontact\x94\x88\x8c\x0bimgvr_blast\x94\x88\x8c\x08run_DRAM\x94\x88\x8c\x11microbial_spacers\x94\x8c\\/home/lmf/DANIEL/MG-Assembly/ALL_MG_megahit_2000bp_derreplicated_minced_predicted_spacers.fa\x94\x8c\x0bresults_dir\x94\x8c\x00\x94\x8c\nmetagenome\x94\x88\x8c\tmicrobial\x94\x89\x8c\x08sourmash\x94\x89\x8c\x0bkey_samples\x94\x8c\x14key_samples_list.csv\x94\x8c\x10operating_system\x94\x8c\x05linux\x94\x8c\x0bforward_tag\x94\x8c\x02R1\x94\x8c\x0breverse_tag\x94\x8c\x02R2\x94\x8c\x0cnanopore_tag\x94\x8c\x08nanopore\x94\x8c\x0fnanopore_pooled\x94\x89\x8c\x14nanopore_pooled_name\x94\x8c\x03raw\x94\x8c\x0elong_assembler\x94jN\x06\x00\x00\x8c\x0bgenome_size\x94\x8c\x0320m\x94\x8c\x13trimmomatic_leading\x94\x8c\x0220\x94\x8c\x14trimmomatic_trailing\x94\x8c\x0220\x94\x8c\x17trimmomatic_window_size\x94\x8c\x014\x94\x8c\x1atrimmomatic_window_quality\x94\x8c\x0220\x94\x8c\x12trimmomatic_minlen\x94\x8c\x0250\x94\x8c\x10nanopore_quality\x94\x8c\x0210\x94\x8c\x0fnanopore_minlen\x94M\xe8\x03\x8c\x0fnanopore_maxlen\x94J\x80\x96\x98\x00\x8c\tVirSorter\x94\x89\x8c\x0ecross_assembly\x94\x89\x8c\nlong_index\x94\x89\x8c\x16representative_contigs\x94j\xb7\x06\x00\x00\x8c\x08sra_list\x94j\xb7\x06\x00\x00\x8c\x0eextract_mapped\x94\x89\x8c\x07p_ident\x94\x8c\x0295\x94\x8c\x0bkmer_window\x94\x8c\x0525000\x94\x8c\x08min_norm\x94\x8c\x010\x94\x8c\x08max_norm\x94\x8c\x03100\x94\x8c\rmax_subsample\x94\x8c\x0850000000\x94\x8c\x07min_len\x94\x8c\x041000\x94\x8c\x07min_cov\x94\x8c\x012\x94\x8c\x11contaminants_list\x94j\xb7\x06\x00\x00\x8c\radapters_file\x94\x8c\x0badapters.fa\x94\x8c\x11ambiguous_mapping\x94\x8c\x03all\x94\x8c\x0ebasecalled_dir\x94\x8c\x10data/basecalled/\x94\x8c\x13reference_databases\x94\x8c\x1eIMGVR GenBankViral RefSeqViral\x94\x8c\x08IMGVR_db\x94\x8c!/home/lmf/db/IMG_VR_2022-12-19_7/\x94\x8c\x0eRefSeqViral_db\x94\x8c6/home/lmf/db/RefSeqViral/RefSeq_viral_2024_09_03.fasta\x94\x8c\x0bpharokka_db\x94N\x8c\x08blast_db\x94\x8c\x1fdb/ncbi/NCBI_viral_proteins.faa\x94\x8c\x0cvirSorter_db\x94\x8c\x1bdb/VirSorter/virsorter-data\x94\x8c\x0ckraken_db_nt\x94\x8c\x17/home/lmf/db/KRAKEN/nt/\x94\x8c\x0fkraken_db_human\x94\x8c\x13db/kraken2_human_db\x94\x8c\x0ckraken_tools\x94\x8c\x11tools/KrakenTools\x94\x8c\x0bbracken_dir\x94\x8c\rtools/Bracken\x94\x8c\nweesam_dir\x94\x8c\x0ctools/weeSAM\x94\x8c\tcheckv_db\x94\x8c\x11db/checkv-db-v1.5\x94\x8c\tcheckm_db\x94\x8c\x0cdb/checkm-db\x94\x8c\x08iphop_db\x94\x8c\x0bdb/iphop_db\x94\x8c\rtaxmyphage_db\x94\x8c\x10db/taxmyphage_db\x94\x8c\x0csourmash_sig\x94\x8c7/home/lmf/db/SOURMASH/matrix_09_42_sourmash_k31.sig.zip\x94\x8c\x10sourmash_rocksdb\x94\x8c;/home/lmf/db/SOURMASH/matrix_09_42_sourmash_k31.sig.rocksdb\x94\x8c\x0csourmash_tax\x94\x8c9/home/lmf/db/SOURMASH/taxonomy/taxonomy_matrix_strain.csv\x94\x8c\x08canu_dir\x94\x8c\x1etools/canu-2.0/Linux-amd64/bin\x94\x8c\x12PhaGCN_newICTV_dir\x94\x8c\x14tools/PhaGCN_newICTV\x94\x8c\tquast_dir\x94\x8c\x11tools/quast-5.0.2\x94\x8c\rvirSorter_dir\x94\x8c\x0ftools/VirSorter\x94\x8c\x07WTP_dir\x94\x8c\ttools/WTP\x94\x8c\rvirFinder_dir\x94\x8c\x0ftools/VirFinder\x94\x8c\x0eclusterONE_dir\x94\x8c\x10tools/clusterONE\x94\x8c\x0cvcontact_dir\x94\x8c\x0ftools/vcontact2\x94\x8c\x1areference_genomes_vcontact\x94\x8c\x04None\x94\x8c\rtaxonomy_file\x94\x8c1db/vcontact2/formatting_taxonomy_affiliations.csv\x94\x8c\ngenomad_db\x94\x8c\rdb/genomad_db\x94\x8c\x07DRAM_db\x94\x8c\ndb/DRAM_db\x94\x8c\tgtdbtk_db\x94\x8c\ndb/GTDB-Tk\x94\x8c\nmmseqs_dir\x94\x8c\rtools/MMseqs2\x94\x8c\x08viga_dir\x94\x8c\ntools/viga\x94\x8c\tpiler_dir\x94\x8c\x11tools/pilercr1.06\x94\x8c\x07trf_dir\x94\x8c\ttools/TRF\x94\x8c\x0bvibrant_dir\x94\x8c\rtools/VIBRANT\x94\x8c\x0eviridic_folder\x94\x8c\x17tools/viridic_v1.0_r3.6\x94\x8c\x0fsra_toolkit_dir\x94\x8c tools/sratoolkit.2.10.0-ubuntu64\x94\x8c\x07ALE_dir\x94\x8c\ttools/ALE\x94\x8c\x08wish_dir\x94\x8c\ntools/WIsH\x94\x8c\nminced_dir\x94\x8c\x0ctools/minced\x94\x8c\x07dion_db\x94\x8c\x0cdb/dionSetDB\x94u\x8c\x04rule\x94\x8c\x0fviralID_parsing\x94\x8c\x0fbench_iteration\x94N\x8c\tscriptdir\x94\x8c//home/lmf/apps/MOSAIC/mosaic/rules/../notebooks\x94ub.'); from snakemake.logging import logger; logger.printshellcmds = True; import os; os.chdir(r'/home/lmf/apps/MOSAIC/mosaic');
######## snakemake preamble end #########

# %% [markdown]
# # Viral Identification

# %%
import glob, os
# import necessary modules
import pandas as pd
from Bio import SeqIO
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from matplotlib.colors import LinearSegmentedColormap

# Create a list of colors
cmap1=LinearSegmentedColormap.from_list("my_colormap", sns.color_palette("colorblind", n_colors=5))


sns.set_style("ticks",{'axes.grid' : True})
sns.set_palette("colorblind")


plt.rcParams["axes.linewidth"] = 1.5
plt.rcParams["xtick.major.width"] = 1.5
plt.rcParams["ytick.major.width"] = 1.5
plt.rcParams["xtick.major.size"] = 8
plt.rcParams["ytick.major.size"] = 8
plt.rcParams["axes.titlepad"] = 20

plt.rcParams['svg.fonttype'] = 'none'
plt.rcParams["axes.titlesize"] = 30
plt.rcParams['axes.labelsize'] = 23.5
plt.rcParams['xtick.labelsize'] = 18
plt.rcParams['ytick.labelsize'] = 18
plt.rcParams['legend.fontsize'] = 18
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = ['Liberation Sans']
plt.rcParams['text.usetex'] = False
plt.rcParams['svg.fonttype'] = 'none'
plt.rcParams["savefig.dpi"]=300

# %%
input_viral_sequences=snakemake.input.viral_sequences
input_assembled_sequences=snakemake.input.assembled_sequences

SAMPLES=list(snakemake.params.samples)
contig_dir=snakemake.params.contig_dir
viral_dir=snakemake.params.viral_dir
SUBASSEMBLY=snakemake.params.subassembly
CROSS_ASSEMBLY=snakemake.params.cross_assembly
LONG_ASSEMBLER=snakemake.params.long_assembler
#-------------------------------------------------------------------------------------------
output_viral_sequences_count_plot_png=snakemake.output.viral_sequences_count_plot_png
output_viral_sequences_count_plot_svg=snakemake.output.viral_sequences_count_plot_svg
output_viral_sequences_count_table_html=snakemake.output.viral_sequences_count_table_html
output_viral_sequences_length_plot_png=snakemake.output.viral_sequences_length_plot_png
output_viral_sequences_length_plot_svg=snakemake.output.viral_sequences_length_plot_svg
output_viral_sequences_length_table_html=snakemake.output.viral_sequences_length_table_html

# %% [markdown]
# ## Number of viral contigs

# %%
# Create an empty DataFrame to store the samples data
df_samples = pd.DataFrame()

# Initialize empty lists for storing sample names, file names, and lengths
names = []
files = []
lengths = []

# Initialize empty lists for storing positive viral contig names and their corresponding labels
names_p = []
positive = []
# Iterate over files in the working directory
n=0
len_pass=0
while n<len(input_assembled_sequences):
    file_assembly=input_assembled_sequences[n]
    file_viral=input_viral_sequences[n]    

    if "_spades" in file_assembly:
        # Iterate over records in the fasta file
        for record in SeqIO.parse(file_assembly, "fasta"):
            # Append the modified record ID, sample name, file name, and contig length to their respective lists
            names.append(record.id.replace("=", "_"))
            sample = file_assembly.split("/")[-1].split("_spades")[0]
            files.append(file_assembly.split("/")[-1].split("_filtered")[0])
            lengths.append(len(record.seq) / 1000000)
            len_pass=len_pass+1
    elif LONG_ASSEMBLER in file_assembly:
        # Process files long assembly
        for record in SeqIO.parse(file_assembly, "fasta"):
            # Append the modified record ID, sample name, file name, and contig length to their respective lists
            names.append(record.id.replace("=", "_"))
            sample = file_assembly.split("/")[-1].split("_corrected")[0]
            files.append(file_assembly.split("/")[-1].split("_corrected")[0])
            lengths.append(len(record.seq) / 1000000)
            len_pass=len_pass+1
    # Iterate over records in the positive viral contig file
    for record in SeqIO.parse(file_viral, "fasta"):
        # Append the modified record ID (without "_provirus" suffix) and label "positive" to their respective lists
        names_p.append(record.id.replace("=", "_").split("_provirus")[0])
        positive.append("positive")
        
    n=n+1
    
# Assign the lists to the corresponding columns in the df_samples DataFrame
df_samples["names"] = names
df_samples["files"] = files
df_samples["lengths"] = lengths

# Create a new DataFrame for positive viral contigs data
df_positive = pd.DataFrame()
df_positive["names"] = names_p
df_positive["positive"] = positive

# Merge the df_samples and df_positive DataFrames on the "names" column
df_samples = df_samples.merge(df_positive, left_on="names", right_on="names", how="outer")

# Fill missing values in the "positive" column with the label "negative"
df_samples['positive'] = df_samples['positive'].fillna("negative")

# Return the updated df_samples DataFrame
df_samples
# Out:
#                                                      names          files  \
# 0                 B_C1_V_NODE_1_length_58545_cov_36.000769  B_C1_V_spades
# 1                 B_C1_V_NODE_2_length_50422_cov_10.106280  B_C1_V_spades
# 2                  B_C1_V_NODE_3_length_40525_cov_8.997628  B_C1_V_spades
# 3                 B_C1_V_NODE_4_length_36900_cov_10.401628  B_C1_V_spades
# 4                  B_C1_V_NODE_5_length_33518_cov_9.610555  B_C1_V_spades
# ...                                                    ...            ...
# 2502545  RS_ORT4F_V_90_NODE_13857_length_1000_cov_5.571429            NaN
# 2502546  RS_ORT4F_V_90_NODE_13858_length_1000_cov_5.233862            NaN
# 2502547  RS_ORT4F_V_90_NODE_13859_length_1000_cov_4.220106            NaN
# 2502548  RS_ORT4F_V_90_NODE_13862_length_1000_cov_3.844444            NaN
# 2502549    RS_ORT4F_V_90_NODE_32_length_19855_cov_6.717374            NaN
#
#           lengths  positive
# 0        0.058545  positive
# ...

# %%
# Group the df_samples DataFrame by "names" and "positive" columns,
# keep the first record for each group, and reset the index
df = df_samples.groupby(["names", "positive"]).first().reset_index()

# Group the resulting DataFrame by "files" and "positive" columns,
# calculate the size of each group, and reset the index with a new column "Count"
df = df.groupby(["files", "positive"]).size().reset_index(name='Count')

# Create a pivot table using the "Count" column as values,
# "positive" column as columns, and "files" column as index.
# The missing values are filled with 0.
df_pivot = pd.pivot_table(df, values='Count', columns=['positive'], index="files",
                     aggfunc=np.sum, fill_value=0)

# Calculate the desired figure width based on the number of columns in df_pivot
fig_width = 0.5 * len(df_pivot)

# Create a bar plot with stacked bars for the "positive" and "negative" columns in df_pivot,
# set the figure size using the calculated width, and customize the appearance
ax = df_pivot[["positive", "negative"]].plot(kind='bar', stacked=True, figsize=(fig_width, 12), edgecolor='none', colormap=cmap1)

# Set the x-axis label and y-axis label
ax.set_xlabel("Sample")
ax.set_ylabel("# of Contigs")

# Add a legend to the plot
handles, labels = ax.get_legend_handles_labels()
ax.legend(reversed(handles), reversed(labels),loc='center left', bbox_to_anchor=(1, 0.5))

# Save the figure as png and svg
ax.figure.savefig(output_viral_sequences_count_plot_png, format="png", bbox_inches = "tight",transparent=True)
ax.figure.savefig(output_viral_sequences_count_plot_svg, format="svg", bbox_inches = "tight",transparent=True)

# %% [markdown]
# ## Number of viral bases

# %%
# Dataframe with number contigs per viral category
df_pivot["total"]=df_pivot["positive"]+df_pivot["negative"]
df_pivot["f_positive"]=round((df_pivot["positive"]/df_pivot["total"])*100,1)
df_pivot["f_negative"]=round((df_pivot["negative"]/df_pivot["total"])*100,1)

# sort the DataFrame by "Sample" column, apply background color gradient to it, and render it as an HTML table
df_pivot_out=df_pivot.style.background_gradient(cmap="RdYlGn", vmin=0).render()

# write the HTML table to a file
with open(output_viral_sequences_count_table_html,"w") as fp:
    fp.write(df_pivot_out)
    
# show the dataframe wand apply background color gradient
df_pivot.style.background_gradient(cmap="RdYlGn", vmin=0)
# Out:
# <style  type="text/css" >
# #T_18dd851c_03bf_11f0_bf47_b88303891ffcrow0_col0,#T_18dd851c_03bf_11f0_bf47_b88303891ffcrow25_col3,#T_18dd851c_03bf_11f0_bf47_b88303891ffcrow28_col0,#T_18dd851c_03bf_11f0_bf47_b88303891ffcrow31_col3,#T_18dd851c_03bf_11f0_bf47_b88303891ffcrow39_col0,#T_18dd851c_03bf_11f0_bf47_b88303891ffcrow42_col1,#T_18dd851c_03bf_11f0_bf47_b88303891ffcrow42_col2,#T_18dd851c_03bf_11f0_bf47_b88303891ffcrow49_col3{
#             background-color:  #ed5f3c;
#             color:  #000000;
#         }#T_18dd851c_03bf_11f0_bf47_b88303891ffcrow0_col1,#T_18dd851c_03bf_11f0_bf47_b88303891ffcrow7_col0,#T_18dd851c_03bf_11f0_bf47_b88303891ffcrow10_col3,#T_18dd851c_03bf_11f0_bf47_b88303891ffcrow21_col3,#T_18dd851c_03bf_11f0_bf47_b88303891ffcrow27_col1,#T_18dd851c_03bf_11f0_bf47_b88303891ffcrow60_col2,#T_18dd851c_03bf_11f0_bf47_b88303891ffcrow66_col1{
#             background-color:  #e95538;
#             color:  #000000;
# ...

# %%
# Group the df_samples DataFrame by "files" and "positive" columns and calculate the sum of other columns
df = df_samples.groupby(["files", "positive"]).sum()

# Create a pivot table from the df DataFrame, with values as 'lengths', columns as 'positive', and index as 'files'
df_Mbp = pd.pivot_table(df, values='lengths', columns=['positive'], index="files", aggfunc=np.sum, fill_value=0)

# Calculate the figure width based on the number of columns in df_Mbp
fig_width = 0.5 * len(df_Mbp)

# Create a bar plot with stacked bars using df_Mbp, set the colormap, figure size, edgecolor, and transparency
ax = df_Mbp[["positive", "negative"]].plot(kind='bar', stacked=True, colormap=cmap1, figsize=(fig_width, 12), edgecolor='none')

# Set the x-label and y-label of the plot
ax.set_xlabel("Sample")
ax.set_ylabel("Million basepairs")

# Add a legend to the plot
handles, labels = ax.get_legend_handles_labels()
ax.legend(reversed(handles), reversed(labels),loc='center left', bbox_to_anchor=(1, 0.5))

# Save the figure as PNG and SVG files with specified output paths, and adjust the bounding box and transparency
ax.figure.savefig(output_viral_sequences_length_plot_png, format="png", bbox_inches="tight", transparent=True)
ax.figure.savefig(output_viral_sequences_length_plot_svg, format="svg", bbox_inches="tight", transparent=True)

# %%
# Add a new column "total" to df_Mbp, which is the sum of "positive" and "negative" columns
df_Mbp["total"] = df_Mbp["positive"] + df_Mbp["negative"]

# Calculate the percentage of positive contigs and add a new column "f_positive" to df_Mbp
df_Mbp["f_positive"] = round((df_Mbp["positive"] / df_Mbp["total"]) * 100, 1)

# Calculate the percentage of negative contigs and add a new column "f_negative" to df_Mbp
df_Mbp["f_negative"] = round((df_Mbp["negative"] / df_Mbp["total"]) * 100, 1)

# Render the styled DataFrame to an HTML representation
df_Mbp_out = df_Mbp.style.background_gradient(cmap="RdYlGn", vmin=0).render()

# Write the HTML representation of the styled DataFrame to a file
with open(output_viral_sequences_length_table_html, "w") as fp:
    fp.write(df_Mbp_out)

# Apply a background gradient to the DataFrame using the "RdYlGn" colormap and set the minimum value to 0
df_Mbp.style.background_gradient(cmap="RdYlGn", vmin=0)
# Out:
# <style  type="text/css" >
# #T_1ba7a41d_03bf_11f0_8220_b88303891ffcrow0_col0,#T_1ba7a41d_03bf_11f0_8220_b88303891ffcrow22_col1,#T_1ba7a41d_03bf_11f0_8220_b88303891ffcrow41_col3,#T_1ba7a41d_03bf_11f0_8220_b88303891ffcrow51_col3,#T_1ba7a41d_03bf_11f0_8220_b88303891ffcrow62_col0{
#             background-color:  #ec5c3b;
#             color:  #000000;
#         }#T_1ba7a41d_03bf_11f0_8220_b88303891ffcrow0_col1,#T_1ba7a41d_03bf_11f0_8220_b88303891ffcrow15_col1,#T_1ba7a41d_03bf_11f0_8220_b88303891ffcrow44_col0,#T_1ba7a41d_03bf_11f0_8220_b88303891ffcrow48_col3,#T_1ba7a41d_03bf_11f0_8220_b88303891ffcrow57_col2,#T_1ba7a41d_03bf_11f0_8220_b88303891ffcrow66_col1,#T_1ba7a41d_03bf_11f0_8220_b88303891ffcrow70_col0{
#             background-color:  #db382b;
#             color:  #f1f1f1;
# ...
