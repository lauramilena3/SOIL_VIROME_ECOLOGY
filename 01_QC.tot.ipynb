# %%
######## snakemake preamble start (automatically inserted, do not edit) ########
import sys; sys.path.extend(['/home/lmf/anaconda3/envs/Mosaic_workflow/lib/python3.9/site-packages', '/home/lmf/.cache/snakemake/snakemake/source-cache/runtime-cache/tmp33f7xxd1/file/home/lmf/apps/MOSAIC/mosaic/rules/../notebooks', '/home/lmf/apps/MOSAIC/mosaic/rules/../notebooks']); import pickle; snakemake = pickle.loads(b'\x80\x04\x95A\x00\x01\x00\x00\x00\x00\x00\x8c\x10snakemake.script\x94\x8c\tSnakemake\x94\x93\x94)\x81\x94}\x94(\x8c\x05input\x94\x8c\x0csnakemake.io\x94\x8c\nInputFiles\x94\x93\x94)\x81\x94(\x8cG/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/B_C1_V_R1_read_count.txt\x94\x8cG/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/B_C2_V_R1_read_count.txt\x94\x8cG/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/B_C3_V_R1_read_count.txt\x94\x8cG/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/B_C4_V_R1_read_count.txt\x94\x8cJ/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/B_CIT1B_V_R1_read_count.txt\x94\x8cJ/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/B_CIT1F_V_R1_read_count.txt\x94\x8cJ/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/B_CIT2B_V_R1_read_count.txt\x94\x8cJ/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/B_CIT2F_V_R1_read_count.txt\x94\x8cJ/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/B_CIT3B_V_R1_read_count.txt\x94\x8cJ/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/B_CIT3F_V_R1_read_count.txt\x94\x8cJ/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/B_CIT4B_V_R1_read_count.txt\x94\x8cJ/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/B_CIT4F_V_R1_read_count.txt\x94\x8cJ/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/B_CNT1B_V_R1_read_count.txt\x94\x8cJ/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/B_CNT1F_V_R1_read_count.txt\x94\x8cJ/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/B_CNT2B_V_R1_read_count.txt\x94\x8cJ/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/B_CNT2F_V_R1_read_count.txt\x94\x8cJ/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/B_CNT3B_V_R1_read_count.txt\x94\x8cJ/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/B_CNT3F_V_R1_read_count.txt\x94\x8cJ/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/B_CNT4B_V_R1_read_count.txt\x94\x8cJ/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/B_CNT4F_V_R1_read_count.txt\x94\x8cJ/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/B_OIT1B_V_R1_read_count.txt\x94\x8cJ/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/B_OIT1F_V_R1_read_count.txt\x94\x8cJ/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/B_OIT2B_V_R1_read_count.txt\x94\x8cJ/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/B_OIT2F_V_R1_read_count.txt\x94\x8cJ/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/B_OIT3B_V_R1_read_count.txt\x94\x8cJ/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/B_OIT3F_V_R1_read_count.txt\x94\x8cJ/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/B_OIT4B_V_R1_read_count.txt\x94\x8cJ/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/B_OIT4F_V_R1_read_count.txt\x94\x8cJ/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/B_ORT1B_V_R1_read_count.txt\x94\x8cJ/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/B_ORT1F_V_R1_read_count.txt\x94\x8cJ/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/B_ORT2B_V_R1_read_count.txt\x94\x8cJ/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/B_ORT2F_V_R1_read_count.txt\x94\x8cJ/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/B_ORT3B_V_R1_read_count.txt\x94\x8cJ/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/B_ORT3F_V_R1_read_count.txt\x94\x8cJ/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/B_ORT4B_V_R1_read_count.txt\x94\x8cJ/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/B_ORT4F_V_R1_read_count.txt\x94\x8cH/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/RS_C1_V_R1_read_count.txt\x94\x8cH/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/RS_C2_V_R1_read_count.txt\x94\x8cH/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/RS_C3_V_R1_read_count.txt\x94\x8cH/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/RS_C4_V_R1_read_count.txt\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/RS_CIT1B_V_R1_read_count.txt\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/RS_CIT1F_V_R1_read_count.txt\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/RS_CIT2B_V_R1_read_count.txt\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/RS_CIT2F_V_R1_read_count.txt\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/RS_CIT3B_V_R1_read_count.txt\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/RS_CIT3F_V_R1_read_count.txt\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/RS_CIT4B_V_R1_read_count.txt\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/RS_CIT4F_V_R1_read_count.txt\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/RS_CNT1B_V_R1_read_count.txt\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/RS_CNT1F_V_R1_read_count.txt\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/RS_CNT2B_V_R1_read_count.txt\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/RS_CNT2F_V_R1_read_count.txt\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/RS_CNT3B_V_R1_read_count.txt\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/RS_CNT3F_V_R1_read_count.txt\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/RS_CNT4B_V_R1_read_count.txt\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/RS_CNT4F_V_R1_read_count.txt\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/RS_OIT1B_V_R1_read_count.txt\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/RS_OIT1F_V_R1_read_count.txt\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/RS_OIT2B_V_R1_read_count.txt\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/RS_OIT2F_V_R1_read_count.txt\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/RS_OIT3B_V_R1_read_count.txt\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/RS_OIT3F_V_R1_read_count.txt\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/RS_OIT4B_V_R1_read_count.txt\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/RS_OIT4F_V_R1_read_count.txt\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/RS_ORT1B_V_R1_read_count.txt\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/RS_ORT1F_V_R1_read_count.txt\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/RS_ORT2B_V_R1_read_count.txt\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/RS_ORT2F_V_R1_read_count.txt\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/RS_ORT3B_V_R1_read_count.txt\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/RS_ORT3F_V_R1_read_count.txt\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/RS_ORT4B_V_R1_read_count.txt\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/RS_ORT4F_V_R1_read_count.txt\x94\x8cG/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/B_C1_V_R2_read_count.txt\x94\x8cG/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/B_C2_V_R2_read_count.txt\x94\x8cG/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/B_C3_V_R2_read_count.txt\x94\x8cG/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/B_C4_V_R2_read_count.txt\x94\x8cJ/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/B_CIT1B_V_R2_read_count.txt\x94\x8cJ/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/B_CIT1F_V_R2_read_count.txt\x94\x8cJ/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/B_CIT2B_V_R2_read_count.txt\x94\x8cJ/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/B_CIT2F_V_R2_read_count.txt\x94\x8cJ/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/B_CIT3B_V_R2_read_count.txt\x94\x8cJ/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/B_CIT3F_V_R2_read_count.txt\x94\x8cJ/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/B_CIT4B_V_R2_read_count.txt\x94\x8cJ/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/B_CIT4F_V_R2_read_count.txt\x94\x8cJ/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/B_CNT1B_V_R2_read_count.txt\x94\x8cJ/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/B_CNT1F_V_R2_read_count.txt\x94\x8cJ/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/B_CNT2B_V_R2_read_count.txt\x94\x8cJ/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/B_CNT2F_V_R2_read_count.txt\x94\x8cJ/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/B_CNT3B_V_R2_read_count.txt\x94\x8cJ/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/B_CNT3F_V_R2_read_count.txt\x94\x8cJ/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/B_CNT4B_V_R2_read_count.txt\x94\x8cJ/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/B_CNT4F_V_R2_read_count.txt\x94\x8cJ/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/B_OIT1B_V_R2_read_count.txt\x94\x8cJ/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/B_OIT1F_V_R2_read_count.txt\x94\x8cJ/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/B_OIT2B_V_R2_read_count.txt\x94\x8cJ/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/B_OIT2F_V_R2_read_count.txt\x94\x8cJ/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/B_OIT3B_V_R2_read_count.txt\x94\x8cJ/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/B_OIT3F_V_R2_read_count.txt\x94\x8cJ/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/B_OIT4B_V_R2_read_count.txt\x94\x8cJ/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/B_OIT4F_V_R2_read_count.txt\x94\x8cJ/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/B_ORT1B_V_R2_read_count.txt\x94\x8cJ/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/B_ORT1F_V_R2_read_count.txt\x94\x8cJ/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/B_ORT2B_V_R2_read_count.txt\x94\x8cJ/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/B_ORT2F_V_R2_read_count.txt\x94\x8cJ/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/B_ORT3B_V_R2_read_count.txt\x94\x8cJ/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/B_ORT3F_V_R2_read_count.txt\x94\x8cJ/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/B_ORT4B_V_R2_read_count.txt\x94\x8cJ/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/B_ORT4F_V_R2_read_count.txt\x94\x8cH/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/RS_C1_V_R2_read_count.txt\x94\x8cH/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/RS_C2_V_R2_read_count.txt\x94\x8cH/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/RS_C3_V_R2_read_count.txt\x94\x8cH/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/RS_C4_V_R2_read_count.txt\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/RS_CIT1B_V_R2_read_count.txt\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/RS_CIT1F_V_R2_read_count.txt\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/RS_CIT2B_V_R2_read_count.txt\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/RS_CIT2F_V_R2_read_count.txt\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/RS_CIT3B_V_R2_read_count.txt\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/RS_CIT3F_V_R2_read_count.txt\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/RS_CIT4B_V_R2_read_count.txt\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/RS_CIT4F_V_R2_read_count.txt\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/RS_CNT1B_V_R2_read_count.txt\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/RS_CNT1F_V_R2_read_count.txt\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/RS_CNT2B_V_R2_read_count.txt\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/RS_CNT2F_V_R2_read_count.txt\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/RS_CNT3B_V_R2_read_count.txt\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/RS_CNT3F_V_R2_read_count.txt\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/RS_CNT4B_V_R2_read_count.txt\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/RS_CNT4F_V_R2_read_count.txt\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/RS_OIT1B_V_R2_read_count.txt\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/RS_OIT1F_V_R2_read_count.txt\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/RS_OIT2B_V_R2_read_count.txt\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/RS_OIT2F_V_R2_read_count.txt\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/RS_OIT3B_V_R2_read_count.txt\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/RS_OIT3F_V_R2_read_count.txt\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/RS_OIT4B_V_R2_read_count.txt\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/RS_OIT4F_V_R2_read_count.txt\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/RS_ORT1B_V_R2_read_count.txt\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/RS_ORT1F_V_R2_read_count.txt\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/RS_ORT2B_V_R2_read_count.txt\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/RS_ORT2F_V_R2_read_count.txt\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/RS_ORT3B_V_R2_read_count.txt\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/RS_ORT3F_V_R2_read_count.txt\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/RS_ORT4B_V_R2_read_count.txt\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/RS_ORT4F_V_R2_read_count.txt\x94\x8cU/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_C1_V_forward_paired_read_count.txt\x94\x8cU/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_C2_V_forward_paired_read_count.txt\x94\x8cU/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_C3_V_forward_paired_read_count.txt\x94\x8cU/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_C4_V_forward_paired_read_count.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT1B_V_forward_paired_read_count.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT1F_V_forward_paired_read_count.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT2B_V_forward_paired_read_count.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT2F_V_forward_paired_read_count.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT3B_V_forward_paired_read_count.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT3F_V_forward_paired_read_count.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT4B_V_forward_paired_read_count.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT4F_V_forward_paired_read_count.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT1B_V_forward_paired_read_count.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT1F_V_forward_paired_read_count.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT2B_V_forward_paired_read_count.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT2F_V_forward_paired_read_count.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT3B_V_forward_paired_read_count.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT3F_V_forward_paired_read_count.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT4B_V_forward_paired_read_count.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT4F_V_forward_paired_read_count.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT1B_V_forward_paired_read_count.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT1F_V_forward_paired_read_count.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT2B_V_forward_paired_read_count.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT2F_V_forward_paired_read_count.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT3B_V_forward_paired_read_count.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT3F_V_forward_paired_read_count.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT4B_V_forward_paired_read_count.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT4F_V_forward_paired_read_count.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT1B_V_forward_paired_read_count.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT1F_V_forward_paired_read_count.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT2B_V_forward_paired_read_count.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT2F_V_forward_paired_read_count.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT3B_V_forward_paired_read_count.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT3F_V_forward_paired_read_count.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT4B_V_forward_paired_read_count.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT4F_V_forward_paired_read_count.txt\x94\x8cV/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_C1_V_forward_paired_read_count.txt\x94\x8cV/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_C2_V_forward_paired_read_count.txt\x94\x8cV/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_C3_V_forward_paired_read_count.txt\x94\x8cV/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_C4_V_forward_paired_read_count.txt\x94\x8cY/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT1B_V_forward_paired_read_count.txt\x94\x8cY/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT1F_V_forward_paired_read_count.txt\x94\x8cY/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT2B_V_forward_paired_read_count.txt\x94\x8cY/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT2F_V_forward_paired_read_count.txt\x94\x8cY/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT3B_V_forward_paired_read_count.txt\x94\x8cY/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT3F_V_forward_paired_read_count.txt\x94\x8cY/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT4B_V_forward_paired_read_count.txt\x94\x8cY/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT4F_V_forward_paired_read_count.txt\x94\x8cY/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT1B_V_forward_paired_read_count.txt\x94\x8cY/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT1F_V_forward_paired_read_count.txt\x94\x8cY/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT2B_V_forward_paired_read_count.txt\x94\x8cY/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT2F_V_forward_paired_read_count.txt\x94\x8cY/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT3B_V_forward_paired_read_count.txt\x94\x8cY/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT3F_V_forward_paired_read_count.txt\x94\x8cY/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT4B_V_forward_paired_read_count.txt\x94\x8cY/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT4F_V_forward_paired_read_count.txt\x94\x8cY/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT1B_V_forward_paired_read_count.txt\x94\x8cY/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT1F_V_forward_paired_read_count.txt\x94\x8cY/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT2B_V_forward_paired_read_count.txt\x94\x8cY/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT2F_V_forward_paired_read_count.txt\x94\x8cY/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT3B_V_forward_paired_read_count.txt\x94\x8cY/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT3F_V_forward_paired_read_count.txt\x94\x8cY/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT4B_V_forward_paired_read_count.txt\x94\x8cY/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT4F_V_forward_paired_read_count.txt\x94\x8cY/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT1B_V_forward_paired_read_count.txt\x94\x8cY/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT1F_V_forward_paired_read_count.txt\x94\x8cY/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT2B_V_forward_paired_read_count.txt\x94\x8cY/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT2F_V_forward_paired_read_count.txt\x94\x8cY/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT3B_V_forward_paired_read_count.txt\x94\x8cY/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT3F_V_forward_paired_read_count.txt\x94\x8cY/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT4B_V_forward_paired_read_count.txt\x94\x8cY/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT4F_V_forward_paired_read_count.txt\x94\x8cU/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_C1_V_reverse_paired_read_count.txt\x94\x8cU/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_C2_V_reverse_paired_read_count.txt\x94\x8cU/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_C3_V_reverse_paired_read_count.txt\x94\x8cU/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_C4_V_reverse_paired_read_count.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT1B_V_reverse_paired_read_count.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT1F_V_reverse_paired_read_count.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT2B_V_reverse_paired_read_count.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT2F_V_reverse_paired_read_count.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT3B_V_reverse_paired_read_count.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT3F_V_reverse_paired_read_count.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT4B_V_reverse_paired_read_count.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT4F_V_reverse_paired_read_count.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT1B_V_reverse_paired_read_count.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT1F_V_reverse_paired_read_count.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT2B_V_reverse_paired_read_count.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT2F_V_reverse_paired_read_count.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT3B_V_reverse_paired_read_count.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT3F_V_reverse_paired_read_count.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT4B_V_reverse_paired_read_count.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT4F_V_reverse_paired_read_count.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT1B_V_reverse_paired_read_count.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT1F_V_reverse_paired_read_count.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT2B_V_reverse_paired_read_count.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT2F_V_reverse_paired_read_count.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT3B_V_reverse_paired_read_count.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT3F_V_reverse_paired_read_count.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT4B_V_reverse_paired_read_count.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT4F_V_reverse_paired_read_count.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT1B_V_reverse_paired_read_count.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT1F_V_reverse_paired_read_count.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT2B_V_reverse_paired_read_count.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT2F_V_reverse_paired_read_count.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT3B_V_reverse_paired_read_count.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT3F_V_reverse_paired_read_count.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT4B_V_reverse_paired_read_count.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT4F_V_reverse_paired_read_count.txt\x94\x8cV/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_C1_V_reverse_paired_read_count.txt\x94\x8cV/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_C2_V_reverse_paired_read_count.txt\x94\x8cV/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_C3_V_reverse_paired_read_count.txt\x94\x8cV/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_C4_V_reverse_paired_read_count.txt\x94\x8cY/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT1B_V_reverse_paired_read_count.txt\x94\x8cY/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT1F_V_reverse_paired_read_count.txt\x94\x8cY/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT2B_V_reverse_paired_read_count.txt\x94\x8cY/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT2F_V_reverse_paired_read_count.txt\x94\x8cY/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT3B_V_reverse_paired_read_count.txt\x94\x8cY/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT3F_V_reverse_paired_read_count.txt\x94\x8cY/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT4B_V_reverse_paired_read_count.txt\x94\x8cY/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT4F_V_reverse_paired_read_count.txt\x94\x8cY/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT1B_V_reverse_paired_read_count.txt\x94\x8cY/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT1F_V_reverse_paired_read_count.txt\x94\x8cY/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT2B_V_reverse_paired_read_count.txt\x94\x8cY/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT2F_V_reverse_paired_read_count.txt\x94\x8cY/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT3B_V_reverse_paired_read_count.txt\x94\x8cY/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT3F_V_reverse_paired_read_count.txt\x94\x8cY/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT4B_V_reverse_paired_read_count.txt\x94\x8cY/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT4F_V_reverse_paired_read_count.txt\x94\x8cY/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT1B_V_reverse_paired_read_count.txt\x94\x8cY/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT1F_V_reverse_paired_read_count.txt\x94\x8cY/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT2B_V_reverse_paired_read_count.txt\x94\x8cY/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT2F_V_reverse_paired_read_count.txt\x94\x8cY/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT3B_V_reverse_paired_read_count.txt\x94\x8cY/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT3F_V_reverse_paired_read_count.txt\x94\x8cY/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT4B_V_reverse_paired_read_count.txt\x94\x8cY/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT4F_V_reverse_paired_read_count.txt\x94\x8cY/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT1B_V_reverse_paired_read_count.txt\x94\x8cY/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT1F_V_reverse_paired_read_count.txt\x94\x8cY/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT2B_V_reverse_paired_read_count.txt\x94\x8cY/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT2F_V_reverse_paired_read_count.txt\x94\x8cY/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT3B_V_reverse_paired_read_count.txt\x94\x8cY/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT3F_V_reverse_paired_read_count.txt\x94\x8cY/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT4B_V_reverse_paired_read_count.txt\x94\x8cY/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT4F_V_reverse_paired_read_count.txt\x94\x8cZ/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_C1_V_merged_unpaired.tot_read_count.txt\x94\x8cZ/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_C2_V_merged_unpaired.tot_read_count.txt\x94\x8cZ/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_C3_V_merged_unpaired.tot_read_count.txt\x94\x8cZ/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_C4_V_merged_unpaired.tot_read_count.txt\x94\x8c]/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT1B_V_merged_unpaired.tot_read_count.txt\x94\x8c]/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT1F_V_merged_unpaired.tot_read_count.txt\x94\x8c]/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT2B_V_merged_unpaired.tot_read_count.txt\x94\x8c]/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT2F_V_merged_unpaired.tot_read_count.txt\x94\x8c]/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT3B_V_merged_unpaired.tot_read_count.txt\x94\x8c]/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT3F_V_merged_unpaired.tot_read_count.txt\x94\x8c]/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT4B_V_merged_unpaired.tot_read_count.txt\x94\x8c]/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT4F_V_merged_unpaired.tot_read_count.txt\x94\x8c]/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT1B_V_merged_unpaired.tot_read_count.txt\x94\x8c]/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT1F_V_merged_unpaired.tot_read_count.txt\x94\x8c]/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT2B_V_merged_unpaired.tot_read_count.txt\x94\x8c]/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT2F_V_merged_unpaired.tot_read_count.txt\x94\x8c]/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT3B_V_merged_unpaired.tot_read_count.txt\x94\x8c]/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT3F_V_merged_unpaired.tot_read_count.txt\x94\x8c]/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT4B_V_merged_unpaired.tot_read_count.txt\x94\x8c]/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT4F_V_merged_unpaired.tot_read_count.txt\x94\x8c]/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT1B_V_merged_unpaired.tot_read_count.txt\x94\x8c]/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT1F_V_merged_unpaired.tot_read_count.txt\x94\x8c]/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT2B_V_merged_unpaired.tot_read_count.txt\x94\x8c]/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT2F_V_merged_unpaired.tot_read_count.txt\x94\x8c]/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT3B_V_merged_unpaired.tot_read_count.txt\x94\x8c]/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT3F_V_merged_unpaired.tot_read_count.txt\x94\x8c]/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT4B_V_merged_unpaired.tot_read_count.txt\x94\x8c]/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT4F_V_merged_unpaired.tot_read_count.txt\x94\x8c]/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT1B_V_merged_unpaired.tot_read_count.txt\x94\x8c]/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT1F_V_merged_unpaired.tot_read_count.txt\x94\x8c]/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT2B_V_merged_unpaired.tot_read_count.txt\x94\x8c]/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT2F_V_merged_unpaired.tot_read_count.txt\x94\x8c]/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT3B_V_merged_unpaired.tot_read_count.txt\x94\x8c]/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT3F_V_merged_unpaired.tot_read_count.txt\x94\x8c]/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT4B_V_merged_unpaired.tot_read_count.txt\x94\x8c]/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT4F_V_merged_unpaired.tot_read_count.txt\x94\x8c[/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_C1_V_merged_unpaired.tot_read_count.txt\x94\x8c[/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_C2_V_merged_unpaired.tot_read_count.txt\x94\x8c[/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_C3_V_merged_unpaired.tot_read_count.txt\x94\x8c[/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_C4_V_merged_unpaired.tot_read_count.txt\x94\x8c^/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT1B_V_merged_unpaired.tot_read_count.txt\x94\x8c^/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT1F_V_merged_unpaired.tot_read_count.txt\x94\x8c^/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT2B_V_merged_unpaired.tot_read_count.txt\x94\x8c^/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT2F_V_merged_unpaired.tot_read_count.txt\x94\x8c^/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT3B_V_merged_unpaired.tot_read_count.txt\x94\x8c^/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT3F_V_merged_unpaired.tot_read_count.txt\x94\x8c^/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT4B_V_merged_unpaired.tot_read_count.txt\x94\x8c^/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT4F_V_merged_unpaired.tot_read_count.txt\x94\x8c^/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT1B_V_merged_unpaired.tot_read_count.txt\x94\x8c^/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT1F_V_merged_unpaired.tot_read_count.txt\x94\x8c^/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT2B_V_merged_unpaired.tot_read_count.txt\x94\x8c^/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT2F_V_merged_unpaired.tot_read_count.txt\x94\x8c^/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT3B_V_merged_unpaired.tot_read_count.txt\x94\x8c^/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT3F_V_merged_unpaired.tot_read_count.txt\x94\x8c^/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT4B_V_merged_unpaired.tot_read_count.txt\x94\x8c^/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT4F_V_merged_unpaired.tot_read_count.txt\x94\x8c^/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT1B_V_merged_unpaired.tot_read_count.txt\x94\x8c^/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT1F_V_merged_unpaired.tot_read_count.txt\x94\x8c^/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT2B_V_merged_unpaired.tot_read_count.txt\x94\x8c^/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT2F_V_merged_unpaired.tot_read_count.txt\x94\x8c^/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT3B_V_merged_unpaired.tot_read_count.txt\x94\x8c^/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT3F_V_merged_unpaired.tot_read_count.txt\x94\x8c^/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT4B_V_merged_unpaired.tot_read_count.txt\x94\x8c^/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT4F_V_merged_unpaired.tot_read_count.txt\x94\x8c^/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT1B_V_merged_unpaired.tot_read_count.txt\x94\x8c^/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT1F_V_merged_unpaired.tot_read_count.txt\x94\x8c^/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT2B_V_merged_unpaired.tot_read_count.txt\x94\x8c^/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT2F_V_merged_unpaired.tot_read_count.txt\x94\x8c^/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT3B_V_merged_unpaired.tot_read_count.txt\x94\x8c^/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT3F_V_merged_unpaired.tot_read_count.txt\x94\x8c^/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT4B_V_merged_unpaired.tot_read_count.txt\x94\x8c^/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT4F_V_merged_unpaired.tot_read_count.txt\x94\x8c_/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_C1_V_forward_paired_noEuk.tot_read_count.txt\x94\x8c_/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_C2_V_forward_paired_noEuk.tot_read_count.txt\x94\x8c_/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_C3_V_forward_paired_noEuk.tot_read_count.txt\x94\x8c_/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_C4_V_forward_paired_noEuk.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT1B_V_forward_paired_noEuk.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT1F_V_forward_paired_noEuk.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT2B_V_forward_paired_noEuk.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT2F_V_forward_paired_noEuk.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT3B_V_forward_paired_noEuk.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT3F_V_forward_paired_noEuk.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT4B_V_forward_paired_noEuk.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT4F_V_forward_paired_noEuk.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT1B_V_forward_paired_noEuk.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT1F_V_forward_paired_noEuk.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT2B_V_forward_paired_noEuk.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT2F_V_forward_paired_noEuk.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT3B_V_forward_paired_noEuk.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT3F_V_forward_paired_noEuk.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT4B_V_forward_paired_noEuk.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT4F_V_forward_paired_noEuk.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT1B_V_forward_paired_noEuk.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT1F_V_forward_paired_noEuk.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT2B_V_forward_paired_noEuk.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT2F_V_forward_paired_noEuk.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT3B_V_forward_paired_noEuk.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT3F_V_forward_paired_noEuk.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT4B_V_forward_paired_noEuk.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT4F_V_forward_paired_noEuk.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT1B_V_forward_paired_noEuk.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT1F_V_forward_paired_noEuk.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT2B_V_forward_paired_noEuk.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT2F_V_forward_paired_noEuk.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT3B_V_forward_paired_noEuk.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT3F_V_forward_paired_noEuk.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT4B_V_forward_paired_noEuk.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT4F_V_forward_paired_noEuk.tot_read_count.txt\x94\x8c`/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_C1_V_forward_paired_noEuk.tot_read_count.txt\x94\x8c`/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_C2_V_forward_paired_noEuk.tot_read_count.txt\x94\x8c`/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_C3_V_forward_paired_noEuk.tot_read_count.txt\x94\x8c`/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_C4_V_forward_paired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT1B_V_forward_paired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT1F_V_forward_paired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT2B_V_forward_paired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT2F_V_forward_paired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT3B_V_forward_paired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT3F_V_forward_paired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT4B_V_forward_paired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT4F_V_forward_paired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT1B_V_forward_paired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT1F_V_forward_paired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT2B_V_forward_paired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT2F_V_forward_paired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT3B_V_forward_paired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT3F_V_forward_paired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT4B_V_forward_paired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT4F_V_forward_paired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT1B_V_forward_paired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT1F_V_forward_paired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT2B_V_forward_paired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT2F_V_forward_paired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT3B_V_forward_paired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT3F_V_forward_paired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT4B_V_forward_paired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT4F_V_forward_paired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT1B_V_forward_paired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT1F_V_forward_paired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT2B_V_forward_paired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT2F_V_forward_paired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT3B_V_forward_paired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT3F_V_forward_paired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT4B_V_forward_paired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT4F_V_forward_paired_noEuk.tot_read_count.txt\x94\x8c_/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_C1_V_reverse_paired_noEuk.tot_read_count.txt\x94\x8c_/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_C2_V_reverse_paired_noEuk.tot_read_count.txt\x94\x8c_/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_C3_V_reverse_paired_noEuk.tot_read_count.txt\x94\x8c_/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_C4_V_reverse_paired_noEuk.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT1B_V_reverse_paired_noEuk.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT1F_V_reverse_paired_noEuk.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT2B_V_reverse_paired_noEuk.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT2F_V_reverse_paired_noEuk.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT3B_V_reverse_paired_noEuk.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT3F_V_reverse_paired_noEuk.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT4B_V_reverse_paired_noEuk.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT4F_V_reverse_paired_noEuk.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT1B_V_reverse_paired_noEuk.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT1F_V_reverse_paired_noEuk.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT2B_V_reverse_paired_noEuk.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT2F_V_reverse_paired_noEuk.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT3B_V_reverse_paired_noEuk.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT3F_V_reverse_paired_noEuk.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT4B_V_reverse_paired_noEuk.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT4F_V_reverse_paired_noEuk.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT1B_V_reverse_paired_noEuk.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT1F_V_reverse_paired_noEuk.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT2B_V_reverse_paired_noEuk.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT2F_V_reverse_paired_noEuk.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT3B_V_reverse_paired_noEuk.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT3F_V_reverse_paired_noEuk.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT4B_V_reverse_paired_noEuk.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT4F_V_reverse_paired_noEuk.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT1B_V_reverse_paired_noEuk.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT1F_V_reverse_paired_noEuk.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT2B_V_reverse_paired_noEuk.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT2F_V_reverse_paired_noEuk.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT3B_V_reverse_paired_noEuk.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT3F_V_reverse_paired_noEuk.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT4B_V_reverse_paired_noEuk.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT4F_V_reverse_paired_noEuk.tot_read_count.txt\x94\x8c`/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_C1_V_reverse_paired_noEuk.tot_read_count.txt\x94\x8c`/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_C2_V_reverse_paired_noEuk.tot_read_count.txt\x94\x8c`/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_C3_V_reverse_paired_noEuk.tot_read_count.txt\x94\x8c`/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_C4_V_reverse_paired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT1B_V_reverse_paired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT1F_V_reverse_paired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT2B_V_reverse_paired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT2F_V_reverse_paired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT3B_V_reverse_paired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT3F_V_reverse_paired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT4B_V_reverse_paired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT4F_V_reverse_paired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT1B_V_reverse_paired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT1F_V_reverse_paired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT2B_V_reverse_paired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT2F_V_reverse_paired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT3B_V_reverse_paired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT3F_V_reverse_paired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT4B_V_reverse_paired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT4F_V_reverse_paired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT1B_V_reverse_paired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT1F_V_reverse_paired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT2B_V_reverse_paired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT2F_V_reverse_paired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT3B_V_reverse_paired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT3F_V_reverse_paired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT4B_V_reverse_paired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT4F_V_reverse_paired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT1B_V_reverse_paired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT1F_V_reverse_paired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT2B_V_reverse_paired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT2F_V_reverse_paired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT3B_V_reverse_paired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT3F_V_reverse_paired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT4B_V_reverse_paired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT4F_V_reverse_paired_noEuk.tot_read_count.txt\x94\x8cY/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_C1_V_unpaired_noEuk.tot_read_count.txt\x94\x8cY/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_C2_V_unpaired_noEuk.tot_read_count.txt\x94\x8cY/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_C3_V_unpaired_noEuk.tot_read_count.txt\x94\x8cY/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_C4_V_unpaired_noEuk.tot_read_count.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT1B_V_unpaired_noEuk.tot_read_count.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT1F_V_unpaired_noEuk.tot_read_count.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT2B_V_unpaired_noEuk.tot_read_count.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT2F_V_unpaired_noEuk.tot_read_count.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT3B_V_unpaired_noEuk.tot_read_count.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT3F_V_unpaired_noEuk.tot_read_count.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT4B_V_unpaired_noEuk.tot_read_count.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT4F_V_unpaired_noEuk.tot_read_count.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT1B_V_unpaired_noEuk.tot_read_count.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT1F_V_unpaired_noEuk.tot_read_count.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT2B_V_unpaired_noEuk.tot_read_count.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT2F_V_unpaired_noEuk.tot_read_count.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT3B_V_unpaired_noEuk.tot_read_count.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT3F_V_unpaired_noEuk.tot_read_count.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT4B_V_unpaired_noEuk.tot_read_count.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT4F_V_unpaired_noEuk.tot_read_count.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT1B_V_unpaired_noEuk.tot_read_count.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT1F_V_unpaired_noEuk.tot_read_count.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT2B_V_unpaired_noEuk.tot_read_count.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT2F_V_unpaired_noEuk.tot_read_count.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT3B_V_unpaired_noEuk.tot_read_count.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT3F_V_unpaired_noEuk.tot_read_count.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT4B_V_unpaired_noEuk.tot_read_count.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT4F_V_unpaired_noEuk.tot_read_count.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT1B_V_unpaired_noEuk.tot_read_count.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT1F_V_unpaired_noEuk.tot_read_count.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT2B_V_unpaired_noEuk.tot_read_count.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT2F_V_unpaired_noEuk.tot_read_count.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT3B_V_unpaired_noEuk.tot_read_count.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT3F_V_unpaired_noEuk.tot_read_count.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT4B_V_unpaired_noEuk.tot_read_count.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT4F_V_unpaired_noEuk.tot_read_count.txt\x94\x8cZ/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_C1_V_unpaired_noEuk.tot_read_count.txt\x94\x8cZ/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_C2_V_unpaired_noEuk.tot_read_count.txt\x94\x8cZ/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_C3_V_unpaired_noEuk.tot_read_count.txt\x94\x8cZ/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_C4_V_unpaired_noEuk.tot_read_count.txt\x94\x8c]/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT1B_V_unpaired_noEuk.tot_read_count.txt\x94\x8c]/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT1F_V_unpaired_noEuk.tot_read_count.txt\x94\x8c]/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT2B_V_unpaired_noEuk.tot_read_count.txt\x94\x8c]/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT2F_V_unpaired_noEuk.tot_read_count.txt\x94\x8c]/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT3B_V_unpaired_noEuk.tot_read_count.txt\x94\x8c]/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT3F_V_unpaired_noEuk.tot_read_count.txt\x94\x8c]/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT4B_V_unpaired_noEuk.tot_read_count.txt\x94\x8c]/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT4F_V_unpaired_noEuk.tot_read_count.txt\x94\x8c]/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT1B_V_unpaired_noEuk.tot_read_count.txt\x94\x8c]/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT1F_V_unpaired_noEuk.tot_read_count.txt\x94\x8c]/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT2B_V_unpaired_noEuk.tot_read_count.txt\x94\x8c]/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT2F_V_unpaired_noEuk.tot_read_count.txt\x94\x8c]/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT3B_V_unpaired_noEuk.tot_read_count.txt\x94\x8c]/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT3F_V_unpaired_noEuk.tot_read_count.txt\x94\x8c]/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT4B_V_unpaired_noEuk.tot_read_count.txt\x94\x8c]/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT4F_V_unpaired_noEuk.tot_read_count.txt\x94\x8c]/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT1B_V_unpaired_noEuk.tot_read_count.txt\x94\x8c]/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT1F_V_unpaired_noEuk.tot_read_count.txt\x94\x8c]/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT2B_V_unpaired_noEuk.tot_read_count.txt\x94\x8c]/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT2F_V_unpaired_noEuk.tot_read_count.txt\x94\x8c]/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT3B_V_unpaired_noEuk.tot_read_count.txt\x94\x8c]/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT3F_V_unpaired_noEuk.tot_read_count.txt\x94\x8c]/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT4B_V_unpaired_noEuk.tot_read_count.txt\x94\x8c]/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT4F_V_unpaired_noEuk.tot_read_count.txt\x94\x8c]/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT1B_V_unpaired_noEuk.tot_read_count.txt\x94\x8c]/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT1F_V_unpaired_noEuk.tot_read_count.txt\x94\x8c]/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT2B_V_unpaired_noEuk.tot_read_count.txt\x94\x8c]/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT2F_V_unpaired_noEuk.tot_read_count.txt\x94\x8c]/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT3B_V_unpaired_noEuk.tot_read_count.txt\x94\x8c]/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT3F_V_unpaired_noEuk.tot_read_count.txt\x94\x8c]/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT4B_V_unpaired_noEuk.tot_read_count.txt\x94\x8c]/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT4F_V_unpaired_noEuk.tot_read_count.txt\x94\x8c_/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_C1_V_forward_paired_clean.tot_read_count.txt\x94\x8c_/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_C2_V_forward_paired_clean.tot_read_count.txt\x94\x8c_/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_C3_V_forward_paired_clean.tot_read_count.txt\x94\x8c_/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_C4_V_forward_paired_clean.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT1B_V_forward_paired_clean.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT1F_V_forward_paired_clean.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT2B_V_forward_paired_clean.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT2F_V_forward_paired_clean.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT3B_V_forward_paired_clean.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT3F_V_forward_paired_clean.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT4B_V_forward_paired_clean.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT4F_V_forward_paired_clean.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT1B_V_forward_paired_clean.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT1F_V_forward_paired_clean.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT2B_V_forward_paired_clean.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT2F_V_forward_paired_clean.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT3B_V_forward_paired_clean.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT3F_V_forward_paired_clean.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT4B_V_forward_paired_clean.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT4F_V_forward_paired_clean.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT1B_V_forward_paired_clean.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT1F_V_forward_paired_clean.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT2B_V_forward_paired_clean.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT2F_V_forward_paired_clean.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT3B_V_forward_paired_clean.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT3F_V_forward_paired_clean.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT4B_V_forward_paired_clean.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT4F_V_forward_paired_clean.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT1B_V_forward_paired_clean.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT1F_V_forward_paired_clean.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT2B_V_forward_paired_clean.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT2F_V_forward_paired_clean.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT3B_V_forward_paired_clean.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT3F_V_forward_paired_clean.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT4B_V_forward_paired_clean.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT4F_V_forward_paired_clean.tot_read_count.txt\x94\x8c`/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_C1_V_forward_paired_clean.tot_read_count.txt\x94\x8c`/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_C2_V_forward_paired_clean.tot_read_count.txt\x94\x8c`/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_C3_V_forward_paired_clean.tot_read_count.txt\x94\x8c`/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_C4_V_forward_paired_clean.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT1B_V_forward_paired_clean.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT1F_V_forward_paired_clean.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT2B_V_forward_paired_clean.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT2F_V_forward_paired_clean.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT3B_V_forward_paired_clean.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT3F_V_forward_paired_clean.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT4B_V_forward_paired_clean.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT4F_V_forward_paired_clean.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT1B_V_forward_paired_clean.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT1F_V_forward_paired_clean.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT2B_V_forward_paired_clean.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT2F_V_forward_paired_clean.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT3B_V_forward_paired_clean.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT3F_V_forward_paired_clean.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT4B_V_forward_paired_clean.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT4F_V_forward_paired_clean.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT1B_V_forward_paired_clean.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT1F_V_forward_paired_clean.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT2B_V_forward_paired_clean.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT2F_V_forward_paired_clean.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT3B_V_forward_paired_clean.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT3F_V_forward_paired_clean.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT4B_V_forward_paired_clean.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT4F_V_forward_paired_clean.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT1B_V_forward_paired_clean.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT1F_V_forward_paired_clean.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT2B_V_forward_paired_clean.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT2F_V_forward_paired_clean.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT3B_V_forward_paired_clean.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT3F_V_forward_paired_clean.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT4B_V_forward_paired_clean.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT4F_V_forward_paired_clean.tot_read_count.txt\x94\x8c_/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_C1_V_reverse_paired_clean.tot_read_count.txt\x94\x8c_/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_C2_V_reverse_paired_clean.tot_read_count.txt\x94\x8c_/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_C3_V_reverse_paired_clean.tot_read_count.txt\x94\x8c_/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_C4_V_reverse_paired_clean.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT1B_V_reverse_paired_clean.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT1F_V_reverse_paired_clean.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT2B_V_reverse_paired_clean.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT2F_V_reverse_paired_clean.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT3B_V_reverse_paired_clean.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT3F_V_reverse_paired_clean.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT4B_V_reverse_paired_clean.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT4F_V_reverse_paired_clean.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT1B_V_reverse_paired_clean.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT1F_V_reverse_paired_clean.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT2B_V_reverse_paired_clean.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT2F_V_reverse_paired_clean.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT3B_V_reverse_paired_clean.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT3F_V_reverse_paired_clean.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT4B_V_reverse_paired_clean.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT4F_V_reverse_paired_clean.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT1B_V_reverse_paired_clean.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT1F_V_reverse_paired_clean.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT2B_V_reverse_paired_clean.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT2F_V_reverse_paired_clean.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT3B_V_reverse_paired_clean.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT3F_V_reverse_paired_clean.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT4B_V_reverse_paired_clean.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT4F_V_reverse_paired_clean.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT1B_V_reverse_paired_clean.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT1F_V_reverse_paired_clean.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT2B_V_reverse_paired_clean.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT2F_V_reverse_paired_clean.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT3B_V_reverse_paired_clean.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT3F_V_reverse_paired_clean.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT4B_V_reverse_paired_clean.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT4F_V_reverse_paired_clean.tot_read_count.txt\x94\x8c`/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_C1_V_reverse_paired_clean.tot_read_count.txt\x94\x8c`/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_C2_V_reverse_paired_clean.tot_read_count.txt\x94\x8c`/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_C3_V_reverse_paired_clean.tot_read_count.txt\x94\x8c`/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_C4_V_reverse_paired_clean.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT1B_V_reverse_paired_clean.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT1F_V_reverse_paired_clean.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT2B_V_reverse_paired_clean.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT2F_V_reverse_paired_clean.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT3B_V_reverse_paired_clean.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT3F_V_reverse_paired_clean.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT4B_V_reverse_paired_clean.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT4F_V_reverse_paired_clean.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT1B_V_reverse_paired_clean.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT1F_V_reverse_paired_clean.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT2B_V_reverse_paired_clean.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT2F_V_reverse_paired_clean.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT3B_V_reverse_paired_clean.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT3F_V_reverse_paired_clean.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT4B_V_reverse_paired_clean.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT4F_V_reverse_paired_clean.tot_read_count.txt\x94\x95Q\x00\x01\x00\x00\x00\x00\x00\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT1B_V_reverse_paired_clean.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT1F_V_reverse_paired_clean.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT2B_V_reverse_paired_clean.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT2F_V_reverse_paired_clean.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT3B_V_reverse_paired_clean.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT3F_V_reverse_paired_clean.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT4B_V_reverse_paired_clean.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT4F_V_reverse_paired_clean.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT1B_V_reverse_paired_clean.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT1F_V_reverse_paired_clean.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT2B_V_reverse_paired_clean.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT2F_V_reverse_paired_clean.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT3B_V_reverse_paired_clean.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT3F_V_reverse_paired_clean.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT4B_V_reverse_paired_clean.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT4F_V_reverse_paired_clean.tot_read_count.txt\x94\x8cY/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_C1_V_unpaired_clean.tot_read_count.txt\x94\x8cY/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_C2_V_unpaired_clean.tot_read_count.txt\x94\x8cY/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_C3_V_unpaired_clean.tot_read_count.txt\x94\x8cY/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_C4_V_unpaired_clean.tot_read_count.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT1B_V_unpaired_clean.tot_read_count.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT1F_V_unpaired_clean.tot_read_count.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT2B_V_unpaired_clean.tot_read_count.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT2F_V_unpaired_clean.tot_read_count.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT3B_V_unpaired_clean.tot_read_count.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT3F_V_unpaired_clean.tot_read_count.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT4B_V_unpaired_clean.tot_read_count.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT4F_V_unpaired_clean.tot_read_count.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT1B_V_unpaired_clean.tot_read_count.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT1F_V_unpaired_clean.tot_read_count.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT2B_V_unpaired_clean.tot_read_count.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT2F_V_unpaired_clean.tot_read_count.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT3B_V_unpaired_clean.tot_read_count.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT3F_V_unpaired_clean.tot_read_count.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT4B_V_unpaired_clean.tot_read_count.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT4F_V_unpaired_clean.tot_read_count.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT1B_V_unpaired_clean.tot_read_count.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT1F_V_unpaired_clean.tot_read_count.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT2B_V_unpaired_clean.tot_read_count.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT2F_V_unpaired_clean.tot_read_count.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT3B_V_unpaired_clean.tot_read_count.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT3F_V_unpaired_clean.tot_read_count.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT4B_V_unpaired_clean.tot_read_count.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT4F_V_unpaired_clean.tot_read_count.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT1B_V_unpaired_clean.tot_read_count.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT1F_V_unpaired_clean.tot_read_count.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT2B_V_unpaired_clean.tot_read_count.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT2F_V_unpaired_clean.tot_read_count.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT3B_V_unpaired_clean.tot_read_count.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT3F_V_unpaired_clean.tot_read_count.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT4B_V_unpaired_clean.tot_read_count.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT4F_V_unpaired_clean.tot_read_count.txt\x94\x8cZ/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_C1_V_unpaired_clean.tot_read_count.txt\x94\x8cZ/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_C2_V_unpaired_clean.tot_read_count.txt\x94\x8cZ/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_C3_V_unpaired_clean.tot_read_count.txt\x94\x8cZ/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_C4_V_unpaired_clean.tot_read_count.txt\x94\x8c]/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT1B_V_unpaired_clean.tot_read_count.txt\x94\x8c]/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT1F_V_unpaired_clean.tot_read_count.txt\x94\x8c]/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT2B_V_unpaired_clean.tot_read_count.txt\x94\x8c]/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT2F_V_unpaired_clean.tot_read_count.txt\x94\x8c]/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT3B_V_unpaired_clean.tot_read_count.txt\x94\x8c]/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT3F_V_unpaired_clean.tot_read_count.txt\x94\x8c]/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT4B_V_unpaired_clean.tot_read_count.txt\x94\x8c]/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT4F_V_unpaired_clean.tot_read_count.txt\x94\x8c]/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT1B_V_unpaired_clean.tot_read_count.txt\x94\x8c]/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT1F_V_unpaired_clean.tot_read_count.txt\x94\x8c]/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT2B_V_unpaired_clean.tot_read_count.txt\x94\x8c]/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT2F_V_unpaired_clean.tot_read_count.txt\x94\x8c]/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT3B_V_unpaired_clean.tot_read_count.txt\x94\x8c]/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT3F_V_unpaired_clean.tot_read_count.txt\x94\x8c]/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT4B_V_unpaired_clean.tot_read_count.txt\x94\x8c]/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT4F_V_unpaired_clean.tot_read_count.txt\x94\x8c]/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT1B_V_unpaired_clean.tot_read_count.txt\x94\x8c]/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT1F_V_unpaired_clean.tot_read_count.txt\x94\x8c]/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT2B_V_unpaired_clean.tot_read_count.txt\x94\x8c]/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT2F_V_unpaired_clean.tot_read_count.txt\x94\x8c]/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT3B_V_unpaired_clean.tot_read_count.txt\x94\x8c]/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT3F_V_unpaired_clean.tot_read_count.txt\x94\x8c]/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT4B_V_unpaired_clean.tot_read_count.txt\x94\x8c]/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT4F_V_unpaired_clean.tot_read_count.txt\x94\x8c]/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT1B_V_unpaired_clean.tot_read_count.txt\x94\x8c]/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT1F_V_unpaired_clean.tot_read_count.txt\x94\x8c]/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT2B_V_unpaired_clean.tot_read_count.txt\x94\x8c]/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT2F_V_unpaired_clean.tot_read_count.txt\x94\x8c]/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT3B_V_unpaired_clean.tot_read_count.txt\x94\x8c]/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT3F_V_unpaired_clean.tot_read_count.txt\x94\x8c]/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT4B_V_unpaired_clean.tot_read_count.txt\x94\x8c]/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT4F_V_unpaired_clean.tot_read_count.txt\x94\x8c^/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_C1_V_forward_paired_norm.tot_read_count.txt\x94\x8c^/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_C2_V_forward_paired_norm.tot_read_count.txt\x94\x8c^/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_C3_V_forward_paired_norm.tot_read_count.txt\x94\x8c^/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_C4_V_forward_paired_norm.tot_read_count.txt\x94\x8ca/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT1B_V_forward_paired_norm.tot_read_count.txt\x94\x8ca/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT1F_V_forward_paired_norm.tot_read_count.txt\x94\x8ca/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT2B_V_forward_paired_norm.tot_read_count.txt\x94\x8ca/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT2F_V_forward_paired_norm.tot_read_count.txt\x94\x8ca/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT3B_V_forward_paired_norm.tot_read_count.txt\x94\x8ca/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT3F_V_forward_paired_norm.tot_read_count.txt\x94\x8ca/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT4B_V_forward_paired_norm.tot_read_count.txt\x94\x8ca/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT4F_V_forward_paired_norm.tot_read_count.txt\x94\x8ca/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT1B_V_forward_paired_norm.tot_read_count.txt\x94\x8ca/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT1F_V_forward_paired_norm.tot_read_count.txt\x94\x8ca/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT2B_V_forward_paired_norm.tot_read_count.txt\x94\x8ca/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT2F_V_forward_paired_norm.tot_read_count.txt\x94\x8ca/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT3B_V_forward_paired_norm.tot_read_count.txt\x94\x8ca/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT3F_V_forward_paired_norm.tot_read_count.txt\x94\x8ca/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT4B_V_forward_paired_norm.tot_read_count.txt\x94\x8ca/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT4F_V_forward_paired_norm.tot_read_count.txt\x94\x8ca/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT1B_V_forward_paired_norm.tot_read_count.txt\x94\x8ca/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT1F_V_forward_paired_norm.tot_read_count.txt\x94\x8ca/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT2B_V_forward_paired_norm.tot_read_count.txt\x94\x8ca/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT2F_V_forward_paired_norm.tot_read_count.txt\x94\x8ca/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT3B_V_forward_paired_norm.tot_read_count.txt\x94\x8ca/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT3F_V_forward_paired_norm.tot_read_count.txt\x94\x8ca/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT4B_V_forward_paired_norm.tot_read_count.txt\x94\x8ca/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT4F_V_forward_paired_norm.tot_read_count.txt\x94\x8ca/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT1B_V_forward_paired_norm.tot_read_count.txt\x94\x8ca/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT1F_V_forward_paired_norm.tot_read_count.txt\x94\x8ca/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT2B_V_forward_paired_norm.tot_read_count.txt\x94\x8ca/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT2F_V_forward_paired_norm.tot_read_count.txt\x94\x8ca/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT3B_V_forward_paired_norm.tot_read_count.txt\x94\x8ca/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT3F_V_forward_paired_norm.tot_read_count.txt\x94\x8ca/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT4B_V_forward_paired_norm.tot_read_count.txt\x94\x8ca/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT4F_V_forward_paired_norm.tot_read_count.txt\x94\x8c_/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_C1_V_forward_paired_norm.tot_read_count.txt\x94\x8c_/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_C2_V_forward_paired_norm.tot_read_count.txt\x94\x8c_/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_C3_V_forward_paired_norm.tot_read_count.txt\x94\x8c_/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_C4_V_forward_paired_norm.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT1B_V_forward_paired_norm.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT1F_V_forward_paired_norm.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT2B_V_forward_paired_norm.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT2F_V_forward_paired_norm.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT3B_V_forward_paired_norm.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT3F_V_forward_paired_norm.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT4B_V_forward_paired_norm.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT4F_V_forward_paired_norm.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT1B_V_forward_paired_norm.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT1F_V_forward_paired_norm.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT2B_V_forward_paired_norm.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT2F_V_forward_paired_norm.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT3B_V_forward_paired_norm.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT3F_V_forward_paired_norm.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT4B_V_forward_paired_norm.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT4F_V_forward_paired_norm.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT1B_V_forward_paired_norm.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT1F_V_forward_paired_norm.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT2B_V_forward_paired_norm.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT2F_V_forward_paired_norm.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT3B_V_forward_paired_norm.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT3F_V_forward_paired_norm.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT4B_V_forward_paired_norm.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT4F_V_forward_paired_norm.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT1B_V_forward_paired_norm.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT1F_V_forward_paired_norm.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT2B_V_forward_paired_norm.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT2F_V_forward_paired_norm.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT3B_V_forward_paired_norm.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT3F_V_forward_paired_norm.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT4B_V_forward_paired_norm.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT4F_V_forward_paired_norm.tot_read_count.txt\x94\x8c^/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_C1_V_reverse_paired_norm.tot_read_count.txt\x94\x8c^/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_C2_V_reverse_paired_norm.tot_read_count.txt\x94\x8c^/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_C3_V_reverse_paired_norm.tot_read_count.txt\x94\x8c^/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_C4_V_reverse_paired_norm.tot_read_count.txt\x94\x8ca/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT1B_V_reverse_paired_norm.tot_read_count.txt\x94\x8ca/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT1F_V_reverse_paired_norm.tot_read_count.txt\x94\x8ca/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT2B_V_reverse_paired_norm.tot_read_count.txt\x94\x8ca/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT2F_V_reverse_paired_norm.tot_read_count.txt\x94\x8ca/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT3B_V_reverse_paired_norm.tot_read_count.txt\x94\x8ca/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT3F_V_reverse_paired_norm.tot_read_count.txt\x94\x8ca/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT4B_V_reverse_paired_norm.tot_read_count.txt\x94\x8ca/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT4F_V_reverse_paired_norm.tot_read_count.txt\x94\x8ca/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT1B_V_reverse_paired_norm.tot_read_count.txt\x94\x8ca/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT1F_V_reverse_paired_norm.tot_read_count.txt\x94\x8ca/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT2B_V_reverse_paired_norm.tot_read_count.txt\x94\x8ca/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT2F_V_reverse_paired_norm.tot_read_count.txt\x94\x8ca/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT3B_V_reverse_paired_norm.tot_read_count.txt\x94\x8ca/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT3F_V_reverse_paired_norm.tot_read_count.txt\x94\x8ca/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT4B_V_reverse_paired_norm.tot_read_count.txt\x94\x8ca/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT4F_V_reverse_paired_norm.tot_read_count.txt\x94\x8ca/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT1B_V_reverse_paired_norm.tot_read_count.txt\x94\x8ca/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT1F_V_reverse_paired_norm.tot_read_count.txt\x94\x8ca/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT2B_V_reverse_paired_norm.tot_read_count.txt\x94\x8ca/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT2F_V_reverse_paired_norm.tot_read_count.txt\x94\x8ca/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT3B_V_reverse_paired_norm.tot_read_count.txt\x94\x8ca/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT3F_V_reverse_paired_norm.tot_read_count.txt\x94\x8ca/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT4B_V_reverse_paired_norm.tot_read_count.txt\x94\x8ca/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT4F_V_reverse_paired_norm.tot_read_count.txt\x94\x8ca/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT1B_V_reverse_paired_norm.tot_read_count.txt\x94\x8ca/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT1F_V_reverse_paired_norm.tot_read_count.txt\x94\x8ca/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT2B_V_reverse_paired_norm.tot_read_count.txt\x94\x8ca/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT2F_V_reverse_paired_norm.tot_read_count.txt\x94\x8ca/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT3B_V_reverse_paired_norm.tot_read_count.txt\x94\x8ca/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT3F_V_reverse_paired_norm.tot_read_count.txt\x94\x8ca/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT4B_V_reverse_paired_norm.tot_read_count.txt\x94\x8ca/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT4F_V_reverse_paired_norm.tot_read_count.txt\x94\x8c_/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_C1_V_reverse_paired_norm.tot_read_count.txt\x94\x8c_/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_C2_V_reverse_paired_norm.tot_read_count.txt\x94\x8c_/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_C3_V_reverse_paired_norm.tot_read_count.txt\x94\x8c_/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_C4_V_reverse_paired_norm.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT1B_V_reverse_paired_norm.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT1F_V_reverse_paired_norm.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT2B_V_reverse_paired_norm.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT2F_V_reverse_paired_norm.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT3B_V_reverse_paired_norm.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT3F_V_reverse_paired_norm.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT4B_V_reverse_paired_norm.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT4F_V_reverse_paired_norm.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT1B_V_reverse_paired_norm.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT1F_V_reverse_paired_norm.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT2B_V_reverse_paired_norm.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT2F_V_reverse_paired_norm.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT3B_V_reverse_paired_norm.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT3F_V_reverse_paired_norm.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT4B_V_reverse_paired_norm.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT4F_V_reverse_paired_norm.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT1B_V_reverse_paired_norm.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT1F_V_reverse_paired_norm.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT2B_V_reverse_paired_norm.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT2F_V_reverse_paired_norm.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT3B_V_reverse_paired_norm.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT3F_V_reverse_paired_norm.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT4B_V_reverse_paired_norm.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT4F_V_reverse_paired_norm.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT1B_V_reverse_paired_norm.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT1F_V_reverse_paired_norm.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT2B_V_reverse_paired_norm.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT2F_V_reverse_paired_norm.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT3B_V_reverse_paired_norm.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT3F_V_reverse_paired_norm.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT4B_V_reverse_paired_norm.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT4F_V_reverse_paired_norm.tot_read_count.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_C1_V_unpaired_norm.tot_read_count.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_C2_V_unpaired_norm.tot_read_count.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_C3_V_unpaired_norm.tot_read_count.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_C4_V_unpaired_norm.tot_read_count.txt\x94\x8c[/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT1B_V_unpaired_norm.tot_read_count.txt\x94\x8c[/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT1F_V_unpaired_norm.tot_read_count.txt\x94\x8c[/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT2B_V_unpaired_norm.tot_read_count.txt\x94\x8c[/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT2F_V_unpaired_norm.tot_read_count.txt\x94\x8c[/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT3B_V_unpaired_norm.tot_read_count.txt\x94\x8c[/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT3F_V_unpaired_norm.tot_read_count.txt\x94\x8c[/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT4B_V_unpaired_norm.tot_read_count.txt\x94\x8c[/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT4F_V_unpaired_norm.tot_read_count.txt\x94\x8c[/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT1B_V_unpaired_norm.tot_read_count.txt\x94\x8c[/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT1F_V_unpaired_norm.tot_read_count.txt\x94\x8c[/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT2B_V_unpaired_norm.tot_read_count.txt\x94\x8c[/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT2F_V_unpaired_norm.tot_read_count.txt\x94\x8c[/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT3B_V_unpaired_norm.tot_read_count.txt\x94\x8c[/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT3F_V_unpaired_norm.tot_read_count.txt\x94\x8c[/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT4B_V_unpaired_norm.tot_read_count.txt\x94\x8c[/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT4F_V_unpaired_norm.tot_read_count.txt\x94\x8c[/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT1B_V_unpaired_norm.tot_read_count.txt\x94\x8c[/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT1F_V_unpaired_norm.tot_read_count.txt\x94\x8c[/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT2B_V_unpaired_norm.tot_read_count.txt\x94\x8c[/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT2F_V_unpaired_norm.tot_read_count.txt\x94\x8c[/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT3B_V_unpaired_norm.tot_read_count.txt\x94\x8c[/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT3F_V_unpaired_norm.tot_read_count.txt\x94\x8c[/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT4B_V_unpaired_norm.tot_read_count.txt\x94\x8c[/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT4F_V_unpaired_norm.tot_read_count.txt\x94\x8c[/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT1B_V_unpaired_norm.tot_read_count.txt\x94\x8c[/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT1F_V_unpaired_norm.tot_read_count.txt\x94\x8c[/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT2B_V_unpaired_norm.tot_read_count.txt\x94\x8c[/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT2F_V_unpaired_norm.tot_read_count.txt\x94\x8c[/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT3B_V_unpaired_norm.tot_read_count.txt\x94\x8c[/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT3F_V_unpaired_norm.tot_read_count.txt\x94\x8c[/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT4B_V_unpaired_norm.tot_read_count.txt\x94\x8c[/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT4F_V_unpaired_norm.tot_read_count.txt\x94\x8cY/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_C1_V_unpaired_norm.tot_read_count.txt\x94\x8cY/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_C2_V_unpaired_norm.tot_read_count.txt\x94\x8cY/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_C3_V_unpaired_norm.tot_read_count.txt\x94\x8cY/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_C4_V_unpaired_norm.tot_read_count.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT1B_V_unpaired_norm.tot_read_count.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT1F_V_unpaired_norm.tot_read_count.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT2B_V_unpaired_norm.tot_read_count.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT2F_V_unpaired_norm.tot_read_count.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT3B_V_unpaired_norm.tot_read_count.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT3F_V_unpaired_norm.tot_read_count.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT4B_V_unpaired_norm.tot_read_count.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT4F_V_unpaired_norm.tot_read_count.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT1B_V_unpaired_norm.tot_read_count.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT1F_V_unpaired_norm.tot_read_count.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT2B_V_unpaired_norm.tot_read_count.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT2F_V_unpaired_norm.tot_read_count.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT3B_V_unpaired_norm.tot_read_count.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT3F_V_unpaired_norm.tot_read_count.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT4B_V_unpaired_norm.tot_read_count.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT4F_V_unpaired_norm.tot_read_count.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT1B_V_unpaired_norm.tot_read_count.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT1F_V_unpaired_norm.tot_read_count.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT2B_V_unpaired_norm.tot_read_count.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT2F_V_unpaired_norm.tot_read_count.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT3B_V_unpaired_norm.tot_read_count.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT3F_V_unpaired_norm.tot_read_count.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT4B_V_unpaired_norm.tot_read_count.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT4F_V_unpaired_norm.tot_read_count.txt\x94e(\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT1B_V_unpaired_norm.tot_read_count.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT1F_V_unpaired_norm.tot_read_count.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT2B_V_unpaired_norm.tot_read_count.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT2F_V_unpaired_norm.tot_read_count.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT3B_V_unpaired_norm.tot_read_count.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT3F_V_unpaired_norm.tot_read_count.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT4B_V_unpaired_norm.tot_read_count.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT4F_V_unpaired_norm.tot_read_count.txt\x94\x8cN/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_C1_V_kmer_histogram.tot.csv\x94\x8cN/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_C2_V_kmer_histogram.tot.csv\x94\x8cN/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_C3_V_kmer_histogram.tot.csv\x94\x8cN/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_C4_V_kmer_histogram.tot.csv\x94\x8cQ/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT1B_V_kmer_histogram.tot.csv\x94\x8cQ/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT1F_V_kmer_histogram.tot.csv\x94\x8cQ/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT2B_V_kmer_histogram.tot.csv\x94\x8cQ/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT2F_V_kmer_histogram.tot.csv\x94\x8cQ/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT3B_V_kmer_histogram.tot.csv\x94\x8cQ/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT3F_V_kmer_histogram.tot.csv\x94\x8cQ/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT4B_V_kmer_histogram.tot.csv\x94\x8cQ/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT4F_V_kmer_histogram.tot.csv\x94\x8cQ/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT1B_V_kmer_histogram.tot.csv\x94\x8cQ/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT1F_V_kmer_histogram.tot.csv\x94\x8cQ/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT2B_V_kmer_histogram.tot.csv\x94\x8cQ/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT2F_V_kmer_histogram.tot.csv\x94\x8cQ/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT3B_V_kmer_histogram.tot.csv\x94\x8cQ/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT3F_V_kmer_histogram.tot.csv\x94\x8cQ/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT4B_V_kmer_histogram.tot.csv\x94\x8cQ/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT4F_V_kmer_histogram.tot.csv\x94\x8cQ/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT1B_V_kmer_histogram.tot.csv\x94\x8cQ/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT1F_V_kmer_histogram.tot.csv\x94\x8cQ/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT2B_V_kmer_histogram.tot.csv\x94\x8cQ/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT2F_V_kmer_histogram.tot.csv\x94\x8cQ/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT3B_V_kmer_histogram.tot.csv\x94\x8cQ/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT3F_V_kmer_histogram.tot.csv\x94\x8cQ/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT4B_V_kmer_histogram.tot.csv\x94\x8cQ/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT4F_V_kmer_histogram.tot.csv\x94\x8cQ/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT1B_V_kmer_histogram.tot.csv\x94\x8cQ/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT1F_V_kmer_histogram.tot.csv\x94\x8cQ/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT2B_V_kmer_histogram.tot.csv\x94\x8cQ/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT2F_V_kmer_histogram.tot.csv\x94\x8cQ/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT3B_V_kmer_histogram.tot.csv\x94\x8cQ/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT3F_V_kmer_histogram.tot.csv\x94\x8cQ/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT4B_V_kmer_histogram.tot.csv\x94\x8cQ/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT4F_V_kmer_histogram.tot.csv\x94\x8cO/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_C1_V_kmer_histogram.tot.csv\x94\x8cO/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_C2_V_kmer_histogram.tot.csv\x94\x8cO/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_C3_V_kmer_histogram.tot.csv\x94\x8cO/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_C4_V_kmer_histogram.tot.csv\x94\x8cR/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT1B_V_kmer_histogram.tot.csv\x94\x8cR/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT1F_V_kmer_histogram.tot.csv\x94\x8cR/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT2B_V_kmer_histogram.tot.csv\x94\x8cR/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT2F_V_kmer_histogram.tot.csv\x94\x8cR/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT3B_V_kmer_histogram.tot.csv\x94\x8cR/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT3F_V_kmer_histogram.tot.csv\x94\x8cR/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT4B_V_kmer_histogram.tot.csv\x94\x8cR/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT4F_V_kmer_histogram.tot.csv\x94\x8cR/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT1B_V_kmer_histogram.tot.csv\x94\x8cR/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT1F_V_kmer_histogram.tot.csv\x94\x8cR/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT2B_V_kmer_histogram.tot.csv\x94\x8cR/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT2F_V_kmer_histogram.tot.csv\x94\x8cR/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT3B_V_kmer_histogram.tot.csv\x94\x8cR/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT3F_V_kmer_histogram.tot.csv\x94\x8cR/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT4B_V_kmer_histogram.tot.csv\x94\x8cR/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT4F_V_kmer_histogram.tot.csv\x94\x8cR/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT1B_V_kmer_histogram.tot.csv\x94\x8cR/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT1F_V_kmer_histogram.tot.csv\x94\x8cR/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT2B_V_kmer_histogram.tot.csv\x94\x8cR/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT2F_V_kmer_histogram.tot.csv\x94\x8cR/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT3B_V_kmer_histogram.tot.csv\x94\x8cR/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT3F_V_kmer_histogram.tot.csv\x94\x8cR/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT4B_V_kmer_histogram.tot.csv\x94\x8cR/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT4F_V_kmer_histogram.tot.csv\x94\x8cR/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT1B_V_kmer_histogram.tot.csv\x94\x8cR/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT1F_V_kmer_histogram.tot.csv\x94\x8cR/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT2B_V_kmer_histogram.tot.csv\x94\x8cR/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT2F_V_kmer_histogram.tot.csv\x94\x8cR/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT3B_V_kmer_histogram.tot.csv\x94\x8cR/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT3F_V_kmer_histogram.tot.csv\x94\x8cR/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT4B_V_kmer_histogram.tot.csv\x94\x8cR/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT4F_V_kmer_histogram.tot.csv\x94\x8cV/home/lmf/DANIEL/VIRAL_METAGENOMES/01_QC/preQC_illumina_report_data/multiqc_fastqc.txt\x94\x8cW/home/lmf/DANIEL/VIRAL_METAGENOMES/01_QC/postQC_illumina_report_data/multiqc_fastqc.txt\x94\x8cG/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/B_C1_V_R1_read_count.txt\x94\x8cG/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/B_C2_V_R1_read_count.txt\x94\x8cG/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/B_C3_V_R1_read_count.txt\x94\x8cG/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/B_C4_V_R1_read_count.txt\x94\x8cJ/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/B_CIT1B_V_R1_read_count.txt\x94\x8cJ/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/B_CIT1F_V_R1_read_count.txt\x94\x8cJ/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/B_CIT2B_V_R1_read_count.txt\x94\x8cJ/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/B_CIT2F_V_R1_read_count.txt\x94\x8cJ/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/B_CIT3B_V_R1_read_count.txt\x94\x8cJ/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/B_CIT3F_V_R1_read_count.txt\x94\x8cJ/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/B_CIT4B_V_R1_read_count.txt\x94\x8cJ/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/B_CIT4F_V_R1_read_count.txt\x94\x8cJ/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/B_CNT1B_V_R1_read_count.txt\x94\x8cJ/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/B_CNT1F_V_R1_read_count.txt\x94\x8cJ/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/B_CNT2B_V_R1_read_count.txt\x94\x8cJ/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/B_CNT2F_V_R1_read_count.txt\x94\x8cJ/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/B_CNT3B_V_R1_read_count.txt\x94\x8cJ/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/B_CNT3F_V_R1_read_count.txt\x94\x8cJ/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/B_CNT4B_V_R1_read_count.txt\x94\x8cJ/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/B_CNT4F_V_R1_read_count.txt\x94\x8cJ/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/B_OIT1B_V_R1_read_count.txt\x94\x8cJ/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/B_OIT1F_V_R1_read_count.txt\x94\x8cJ/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/B_OIT2B_V_R1_read_count.txt\x94\x8cJ/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/B_OIT2F_V_R1_read_count.txt\x94\x8cJ/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/B_OIT3B_V_R1_read_count.txt\x94\x8cJ/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/B_OIT3F_V_R1_read_count.txt\x94\x8cJ/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/B_OIT4B_V_R1_read_count.txt\x94\x8cJ/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/B_OIT4F_V_R1_read_count.txt\x94\x8cJ/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/B_ORT1B_V_R1_read_count.txt\x94\x8cJ/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/B_ORT1F_V_R1_read_count.txt\x94\x8cJ/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/B_ORT2B_V_R1_read_count.txt\x94\x8cJ/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/B_ORT2F_V_R1_read_count.txt\x94\x8cJ/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/B_ORT3B_V_R1_read_count.txt\x94\x8cJ/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/B_ORT3F_V_R1_read_count.txt\x94\x8cJ/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/B_ORT4B_V_R1_read_count.txt\x94\x8cJ/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/B_ORT4F_V_R1_read_count.txt\x94\x8cH/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/RS_C1_V_R1_read_count.txt\x94\x8cH/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/RS_C2_V_R1_read_count.txt\x94\x8cH/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/RS_C3_V_R1_read_count.txt\x94\x8cH/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/RS_C4_V_R1_read_count.txt\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/RS_CIT1B_V_R1_read_count.txt\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/RS_CIT1F_V_R1_read_count.txt\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/RS_CIT2B_V_R1_read_count.txt\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/RS_CIT2F_V_R1_read_count.txt\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/RS_CIT3B_V_R1_read_count.txt\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/RS_CIT3F_V_R1_read_count.txt\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/RS_CIT4B_V_R1_read_count.txt\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/RS_CIT4F_V_R1_read_count.txt\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/RS_CNT1B_V_R1_read_count.txt\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/RS_CNT1F_V_R1_read_count.txt\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/RS_CNT2B_V_R1_read_count.txt\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/RS_CNT2F_V_R1_read_count.txt\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/RS_CNT3B_V_R1_read_count.txt\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/RS_CNT3F_V_R1_read_count.txt\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/RS_CNT4B_V_R1_read_count.txt\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/RS_CNT4F_V_R1_read_count.txt\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/RS_OIT1B_V_R1_read_count.txt\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/RS_OIT1F_V_R1_read_count.txt\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/RS_OIT2B_V_R1_read_count.txt\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/RS_OIT2F_V_R1_read_count.txt\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/RS_OIT3B_V_R1_read_count.txt\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/RS_OIT3F_V_R1_read_count.txt\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/RS_OIT4B_V_R1_read_count.txt\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/RS_OIT4F_V_R1_read_count.txt\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/RS_ORT1B_V_R1_read_count.txt\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/RS_ORT1F_V_R1_read_count.txt\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/RS_ORT2B_V_R1_read_count.txt\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/RS_ORT2F_V_R1_read_count.txt\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/RS_ORT3B_V_R1_read_count.txt\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/RS_ORT3F_V_R1_read_count.txt\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/RS_ORT4B_V_R1_read_count.txt\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/RS_ORT4F_V_R1_read_count.txt\x94\x8cG/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/B_C1_V_R2_read_count.txt\x94\x8cG/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/B_C2_V_R2_read_count.txt\x94\x8cG/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/B_C3_V_R2_read_count.txt\x94\x8cG/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/B_C4_V_R2_read_count.txt\x94\x8cJ/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/B_CIT1B_V_R2_read_count.txt\x94\x8cJ/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/B_CIT1F_V_R2_read_count.txt\x94\x8cJ/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/B_CIT2B_V_R2_read_count.txt\x94\x8cJ/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/B_CIT2F_V_R2_read_count.txt\x94\x8cJ/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/B_CIT3B_V_R2_read_count.txt\x94\x8cJ/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/B_CIT3F_V_R2_read_count.txt\x94\x8cJ/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/B_CIT4B_V_R2_read_count.txt\x94\x8cJ/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/B_CIT4F_V_R2_read_count.txt\x94\x8cJ/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/B_CNT1B_V_R2_read_count.txt\x94\x8cJ/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/B_CNT1F_V_R2_read_count.txt\x94\x8cJ/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/B_CNT2B_V_R2_read_count.txt\x94\x8cJ/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/B_CNT2F_V_R2_read_count.txt\x94\x8cJ/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/B_CNT3B_V_R2_read_count.txt\x94\x8cJ/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/B_CNT3F_V_R2_read_count.txt\x94\x8cJ/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/B_CNT4B_V_R2_read_count.txt\x94\x8cJ/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/B_CNT4F_V_R2_read_count.txt\x94\x8cJ/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/B_OIT1B_V_R2_read_count.txt\x94\x8cJ/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/B_OIT1F_V_R2_read_count.txt\x94\x8cJ/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/B_OIT2B_V_R2_read_count.txt\x94\x8cJ/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/B_OIT2F_V_R2_read_count.txt\x94\x8cJ/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/B_OIT3B_V_R2_read_count.txt\x94\x8cJ/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/B_OIT3F_V_R2_read_count.txt\x94\x8cJ/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/B_OIT4B_V_R2_read_count.txt\x94\x8cJ/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/B_OIT4F_V_R2_read_count.txt\x94\x8cJ/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/B_ORT1B_V_R2_read_count.txt\x94\x8cJ/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/B_ORT1F_V_R2_read_count.txt\x94\x8cJ/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/B_ORT2B_V_R2_read_count.txt\x94\x8cJ/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/B_ORT2F_V_R2_read_count.txt\x94\x8cJ/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/B_ORT3B_V_R2_read_count.txt\x94\x8cJ/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/B_ORT3F_V_R2_read_count.txt\x94\x8cJ/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/B_ORT4B_V_R2_read_count.txt\x94\x8cJ/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/B_ORT4F_V_R2_read_count.txt\x94\x8cH/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/RS_C1_V_R2_read_count.txt\x94\x8cH/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/RS_C2_V_R2_read_count.txt\x94\x8cH/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/RS_C3_V_R2_read_count.txt\x94\x8cH/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/RS_C4_V_R2_read_count.txt\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/RS_CIT1B_V_R2_read_count.txt\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/RS_CIT1F_V_R2_read_count.txt\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/RS_CIT2B_V_R2_read_count.txt\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/RS_CIT2F_V_R2_read_count.txt\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/RS_CIT3B_V_R2_read_count.txt\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/RS_CIT3F_V_R2_read_count.txt\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/RS_CIT4B_V_R2_read_count.txt\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/RS_CIT4F_V_R2_read_count.txt\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/RS_CNT1B_V_R2_read_count.txt\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/RS_CNT1F_V_R2_read_count.txt\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/RS_CNT2B_V_R2_read_count.txt\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/RS_CNT2F_V_R2_read_count.txt\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/RS_CNT3B_V_R2_read_count.txt\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/RS_CNT3F_V_R2_read_count.txt\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/RS_CNT4B_V_R2_read_count.txt\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/RS_CNT4F_V_R2_read_count.txt\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/RS_OIT1B_V_R2_read_count.txt\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/RS_OIT1F_V_R2_read_count.txt\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/RS_OIT2B_V_R2_read_count.txt\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/RS_OIT2F_V_R2_read_count.txt\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/RS_OIT3B_V_R2_read_count.txt\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/RS_OIT3F_V_R2_read_count.txt\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/RS_OIT4B_V_R2_read_count.txt\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/RS_OIT4F_V_R2_read_count.txt\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/RS_ORT1B_V_R2_read_count.txt\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/RS_ORT1F_V_R2_read_count.txt\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/RS_ORT2B_V_R2_read_count.txt\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/RS_ORT2F_V_R2_read_count.txt\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/RS_ORT3B_V_R2_read_count.txt\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/RS_ORT3F_V_R2_read_count.txt\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/RS_ORT4B_V_R2_read_count.txt\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA/RS_ORT4F_V_R2_read_count.txt\x94\x8cU/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_C1_V_forward_paired_read_count.txt\x94\x8cU/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_C2_V_forward_paired_read_count.txt\x94\x8cU/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_C3_V_forward_paired_read_count.txt\x94\x8cU/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_C4_V_forward_paired_read_count.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT1B_V_forward_paired_read_count.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT1F_V_forward_paired_read_count.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT2B_V_forward_paired_read_count.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT2F_V_forward_paired_read_count.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT3B_V_forward_paired_read_count.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT3F_V_forward_paired_read_count.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT4B_V_forward_paired_read_count.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT4F_V_forward_paired_read_count.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT1B_V_forward_paired_read_count.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT1F_V_forward_paired_read_count.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT2B_V_forward_paired_read_count.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT2F_V_forward_paired_read_count.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT3B_V_forward_paired_read_count.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT3F_V_forward_paired_read_count.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT4B_V_forward_paired_read_count.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT4F_V_forward_paired_read_count.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT1B_V_forward_paired_read_count.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT1F_V_forward_paired_read_count.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT2B_V_forward_paired_read_count.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT2F_V_forward_paired_read_count.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT3B_V_forward_paired_read_count.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT3F_V_forward_paired_read_count.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT4B_V_forward_paired_read_count.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT4F_V_forward_paired_read_count.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT1B_V_forward_paired_read_count.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT1F_V_forward_paired_read_count.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT2B_V_forward_paired_read_count.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT2F_V_forward_paired_read_count.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT3B_V_forward_paired_read_count.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT3F_V_forward_paired_read_count.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT4B_V_forward_paired_read_count.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT4F_V_forward_paired_read_count.txt\x94\x8cV/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_C1_V_forward_paired_read_count.txt\x94\x8cV/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_C2_V_forward_paired_read_count.txt\x94\x8cV/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_C3_V_forward_paired_read_count.txt\x94\x8cV/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_C4_V_forward_paired_read_count.txt\x94\x8cY/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT1B_V_forward_paired_read_count.txt\x94\x8cY/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT1F_V_forward_paired_read_count.txt\x94\x8cY/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT2B_V_forward_paired_read_count.txt\x94\x8cY/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT2F_V_forward_paired_read_count.txt\x94\x8cY/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT3B_V_forward_paired_read_count.txt\x94\x8cY/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT3F_V_forward_paired_read_count.txt\x94\x8cY/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT4B_V_forward_paired_read_count.txt\x94\x8cY/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT4F_V_forward_paired_read_count.txt\x94\x8cY/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT1B_V_forward_paired_read_count.txt\x94\x8cY/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT1F_V_forward_paired_read_count.txt\x94\x8cY/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT2B_V_forward_paired_read_count.txt\x94\x8cY/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT2F_V_forward_paired_read_count.txt\x94\x8cY/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT3B_V_forward_paired_read_count.txt\x94\x8cY/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT3F_V_forward_paired_read_count.txt\x94\x8cY/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT4B_V_forward_paired_read_count.txt\x94\x8cY/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT4F_V_forward_paired_read_count.txt\x94\x8cY/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT1B_V_forward_paired_read_count.txt\x94\x8cY/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT1F_V_forward_paired_read_count.txt\x94\x8cY/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT2B_V_forward_paired_read_count.txt\x94\x8cY/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT2F_V_forward_paired_read_count.txt\x94\x8cY/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT3B_V_forward_paired_read_count.txt\x94\x8cY/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT3F_V_forward_paired_read_count.txt\x94\x8cY/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT4B_V_forward_paired_read_count.txt\x94\x8cY/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT4F_V_forward_paired_read_count.txt\x94\x8cY/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT1B_V_forward_paired_read_count.txt\x94\x8cY/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT1F_V_forward_paired_read_count.txt\x94\x8cY/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT2B_V_forward_paired_read_count.txt\x94\x8cY/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT2F_V_forward_paired_read_count.txt\x94\x8cY/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT3B_V_forward_paired_read_count.txt\x94\x8cY/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT3F_V_forward_paired_read_count.txt\x94\x8cY/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT4B_V_forward_paired_read_count.txt\x94\x8cY/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT4F_V_forward_paired_read_count.txt\x94\x8cU/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_C1_V_reverse_paired_read_count.txt\x94\x8cU/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_C2_V_reverse_paired_read_count.txt\x94\x8cU/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_C3_V_reverse_paired_read_count.txt\x94\x8cU/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_C4_V_reverse_paired_read_count.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT1B_V_reverse_paired_read_count.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT1F_V_reverse_paired_read_count.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT2B_V_reverse_paired_read_count.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT2F_V_reverse_paired_read_count.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT3B_V_reverse_paired_read_count.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT3F_V_reverse_paired_read_count.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT4B_V_reverse_paired_read_count.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT4F_V_reverse_paired_read_count.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT1B_V_reverse_paired_read_count.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT1F_V_reverse_paired_read_count.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT2B_V_reverse_paired_read_count.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT2F_V_reverse_paired_read_count.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT3B_V_reverse_paired_read_count.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT3F_V_reverse_paired_read_count.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT4B_V_reverse_paired_read_count.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT4F_V_reverse_paired_read_count.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT1B_V_reverse_paired_read_count.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT1F_V_reverse_paired_read_count.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT2B_V_reverse_paired_read_count.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT2F_V_reverse_paired_read_count.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT3B_V_reverse_paired_read_count.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT3F_V_reverse_paired_read_count.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT4B_V_reverse_paired_read_count.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT4F_V_reverse_paired_read_count.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT1B_V_reverse_paired_read_count.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT1F_V_reverse_paired_read_count.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT2B_V_reverse_paired_read_count.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT2F_V_reverse_paired_read_count.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT3B_V_reverse_paired_read_count.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT3F_V_reverse_paired_read_count.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT4B_V_reverse_paired_read_count.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT4F_V_reverse_paired_read_count.txt\x94\x8cV/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_C1_V_reverse_paired_read_count.txt\x94\x8cV/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_C2_V_reverse_paired_read_count.txt\x94\x8cV/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_C3_V_reverse_paired_read_count.txt\x94\x8cV/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_C4_V_reverse_paired_read_count.txt\x94\x8cY/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT1B_V_reverse_paired_read_count.txt\x94\x8cY/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT1F_V_reverse_paired_read_count.txt\x94\x8cY/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT2B_V_reverse_paired_read_count.txt\x94\x8cY/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT2F_V_reverse_paired_read_count.txt\x94\x8cY/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT3B_V_reverse_paired_read_count.txt\x94\x8cY/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT3F_V_reverse_paired_read_count.txt\x94\x8cY/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT4B_V_reverse_paired_read_count.txt\x94\x8cY/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT4F_V_reverse_paired_read_count.txt\x94\x8cY/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT1B_V_reverse_paired_read_count.txt\x94\x8cY/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT1F_V_reverse_paired_read_count.txt\x94\x8cY/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT2B_V_reverse_paired_read_count.txt\x94\x8cY/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT2F_V_reverse_paired_read_count.txt\x94\x8cY/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT3B_V_reverse_paired_read_count.txt\x94\x8cY/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT3F_V_reverse_paired_read_count.txt\x94\x8cY/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT4B_V_reverse_paired_read_count.txt\x94\x8cY/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT4F_V_reverse_paired_read_count.txt\x94\x8cY/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT1B_V_reverse_paired_read_count.txt\x94\x8cY/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT1F_V_reverse_paired_read_count.txt\x94\x8cY/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT2B_V_reverse_paired_read_count.txt\x94\x8cY/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT2F_V_reverse_paired_read_count.txt\x94\x8cY/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT3B_V_reverse_paired_read_count.txt\x94\x8cY/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT3F_V_reverse_paired_read_count.txt\x94\x8cY/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT4B_V_reverse_paired_read_count.txt\x94\x8cY/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT4F_V_reverse_paired_read_count.txt\x94\x8cY/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT1B_V_reverse_paired_read_count.txt\x94\x8cY/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT1F_V_reverse_paired_read_count.txt\x94\x8cY/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT2B_V_reverse_paired_read_count.txt\x94\x8cY/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT2F_V_reverse_paired_read_count.txt\x94\x8cY/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT3B_V_reverse_paired_read_count.txt\x94\x8cY/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT3F_V_reverse_paired_read_count.txt\x94\x8cY/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT4B_V_reverse_paired_read_count.txt\x94\x8cY/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT4F_V_reverse_paired_read_count.txt\x94\x8c_/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_C1_V_forward_paired_noEuk.tot_read_count.txt\x94\x8c_/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_C2_V_forward_paired_noEuk.tot_read_count.txt\x94\x8c_/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_C3_V_forward_paired_noEuk.tot_read_count.txt\x94\x8c_/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_C4_V_forward_paired_noEuk.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT1B_V_forward_paired_noEuk.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT1F_V_forward_paired_noEuk.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT2B_V_forward_paired_noEuk.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT2F_V_forward_paired_noEuk.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT3B_V_forward_paired_noEuk.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT3F_V_forward_paired_noEuk.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT4B_V_forward_paired_noEuk.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT4F_V_forward_paired_noEuk.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT1B_V_forward_paired_noEuk.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT1F_V_forward_paired_noEuk.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT2B_V_forward_paired_noEuk.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT2F_V_forward_paired_noEuk.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT3B_V_forward_paired_noEuk.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT3F_V_forward_paired_noEuk.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT4B_V_forward_paired_noEuk.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT4F_V_forward_paired_noEuk.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT1B_V_forward_paired_noEuk.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT1F_V_forward_paired_noEuk.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT2B_V_forward_paired_noEuk.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT2F_V_forward_paired_noEuk.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT3B_V_forward_paired_noEuk.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT3F_V_forward_paired_noEuk.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT4B_V_forward_paired_noEuk.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT4F_V_forward_paired_noEuk.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT1B_V_forward_paired_noEuk.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT1F_V_forward_paired_noEuk.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT2B_V_forward_paired_noEuk.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT2F_V_forward_paired_noEuk.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT3B_V_forward_paired_noEuk.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT3F_V_forward_paired_noEuk.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT4B_V_forward_paired_noEuk.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT4F_V_forward_paired_noEuk.tot_read_count.txt\x94\x8c`/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_C1_V_forward_paired_noEuk.tot_read_count.txt\x94\x8c`/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_C2_V_forward_paired_noEuk.tot_read_count.txt\x94\x8c`/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_C3_V_forward_paired_noEuk.tot_read_count.txt\x94\x8c`/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_C4_V_forward_paired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT1B_V_forward_paired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT1F_V_forward_paired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT2B_V_forward_paired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT2F_V_forward_paired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT3B_V_forward_paired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT3F_V_forward_paired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT4B_V_forward_paired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT4F_V_forward_paired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT1B_V_forward_paired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT1F_V_forward_paired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT2B_V_forward_paired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT2F_V_forward_paired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT3B_V_forward_paired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT3F_V_forward_paired_noEuk.tot_read_count.txt\x94\x95\x03\x00\x01\x00\x00\x00\x00\x00\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT4B_V_forward_paired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT4F_V_forward_paired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT1B_V_forward_paired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT1F_V_forward_paired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT2B_V_forward_paired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT2F_V_forward_paired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT3B_V_forward_paired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT3F_V_forward_paired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT4B_V_forward_paired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT4F_V_forward_paired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT1B_V_forward_paired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT1F_V_forward_paired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT2B_V_forward_paired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT2F_V_forward_paired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT3B_V_forward_paired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT3F_V_forward_paired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT4B_V_forward_paired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT4F_V_forward_paired_noEuk.tot_read_count.txt\x94\x8c_/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_C1_V_reverse_paired_noEuk.tot_read_count.txt\x94\x8c_/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_C2_V_reverse_paired_noEuk.tot_read_count.txt\x94\x8c_/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_C3_V_reverse_paired_noEuk.tot_read_count.txt\x94\x8c_/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_C4_V_reverse_paired_noEuk.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT1B_V_reverse_paired_noEuk.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT1F_V_reverse_paired_noEuk.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT2B_V_reverse_paired_noEuk.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT2F_V_reverse_paired_noEuk.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT3B_V_reverse_paired_noEuk.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT3F_V_reverse_paired_noEuk.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT4B_V_reverse_paired_noEuk.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT4F_V_reverse_paired_noEuk.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT1B_V_reverse_paired_noEuk.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT1F_V_reverse_paired_noEuk.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT2B_V_reverse_paired_noEuk.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT2F_V_reverse_paired_noEuk.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT3B_V_reverse_paired_noEuk.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT3F_V_reverse_paired_noEuk.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT4B_V_reverse_paired_noEuk.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT4F_V_reverse_paired_noEuk.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT1B_V_reverse_paired_noEuk.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT1F_V_reverse_paired_noEuk.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT2B_V_reverse_paired_noEuk.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT2F_V_reverse_paired_noEuk.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT3B_V_reverse_paired_noEuk.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT3F_V_reverse_paired_noEuk.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT4B_V_reverse_paired_noEuk.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT4F_V_reverse_paired_noEuk.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT1B_V_reverse_paired_noEuk.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT1F_V_reverse_paired_noEuk.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT2B_V_reverse_paired_noEuk.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT2F_V_reverse_paired_noEuk.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT3B_V_reverse_paired_noEuk.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT3F_V_reverse_paired_noEuk.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT4B_V_reverse_paired_noEuk.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT4F_V_reverse_paired_noEuk.tot_read_count.txt\x94\x8c`/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_C1_V_reverse_paired_noEuk.tot_read_count.txt\x94\x8c`/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_C2_V_reverse_paired_noEuk.tot_read_count.txt\x94\x8c`/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_C3_V_reverse_paired_noEuk.tot_read_count.txt\x94\x8c`/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_C4_V_reverse_paired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT1B_V_reverse_paired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT1F_V_reverse_paired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT2B_V_reverse_paired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT2F_V_reverse_paired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT3B_V_reverse_paired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT3F_V_reverse_paired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT4B_V_reverse_paired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT4F_V_reverse_paired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT1B_V_reverse_paired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT1F_V_reverse_paired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT2B_V_reverse_paired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT2F_V_reverse_paired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT3B_V_reverse_paired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT3F_V_reverse_paired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT4B_V_reverse_paired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT4F_V_reverse_paired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT1B_V_reverse_paired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT1F_V_reverse_paired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT2B_V_reverse_paired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT2F_V_reverse_paired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT3B_V_reverse_paired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT3F_V_reverse_paired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT4B_V_reverse_paired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT4F_V_reverse_paired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT1B_V_reverse_paired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT1F_V_reverse_paired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT2B_V_reverse_paired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT2F_V_reverse_paired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT3B_V_reverse_paired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT3F_V_reverse_paired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT4B_V_reverse_paired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT4F_V_reverse_paired_noEuk.tot_read_count.txt\x94\x8c_/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_C1_V_forward_paired_clean.tot_read_count.txt\x94\x8c_/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_C2_V_forward_paired_clean.tot_read_count.txt\x94\x8c_/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_C3_V_forward_paired_clean.tot_read_count.txt\x94\x8c_/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_C4_V_forward_paired_clean.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT1B_V_forward_paired_clean.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT1F_V_forward_paired_clean.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT2B_V_forward_paired_clean.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT2F_V_forward_paired_clean.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT3B_V_forward_paired_clean.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT3F_V_forward_paired_clean.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT4B_V_forward_paired_clean.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT4F_V_forward_paired_clean.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT1B_V_forward_paired_clean.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT1F_V_forward_paired_clean.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT2B_V_forward_paired_clean.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT2F_V_forward_paired_clean.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT3B_V_forward_paired_clean.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT3F_V_forward_paired_clean.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT4B_V_forward_paired_clean.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT4F_V_forward_paired_clean.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT1B_V_forward_paired_clean.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT1F_V_forward_paired_clean.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT2B_V_forward_paired_clean.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT2F_V_forward_paired_clean.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT3B_V_forward_paired_clean.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT3F_V_forward_paired_clean.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT4B_V_forward_paired_clean.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT4F_V_forward_paired_clean.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT1B_V_forward_paired_clean.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT1F_V_forward_paired_clean.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT2B_V_forward_paired_clean.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT2F_V_forward_paired_clean.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT3B_V_forward_paired_clean.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT3F_V_forward_paired_clean.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT4B_V_forward_paired_clean.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT4F_V_forward_paired_clean.tot_read_count.txt\x94\x8c`/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_C1_V_forward_paired_clean.tot_read_count.txt\x94\x8c`/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_C2_V_forward_paired_clean.tot_read_count.txt\x94\x8c`/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_C3_V_forward_paired_clean.tot_read_count.txt\x94\x8c`/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_C4_V_forward_paired_clean.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT1B_V_forward_paired_clean.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT1F_V_forward_paired_clean.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT2B_V_forward_paired_clean.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT2F_V_forward_paired_clean.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT3B_V_forward_paired_clean.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT3F_V_forward_paired_clean.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT4B_V_forward_paired_clean.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT4F_V_forward_paired_clean.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT1B_V_forward_paired_clean.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT1F_V_forward_paired_clean.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT2B_V_forward_paired_clean.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT2F_V_forward_paired_clean.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT3B_V_forward_paired_clean.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT3F_V_forward_paired_clean.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT4B_V_forward_paired_clean.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT4F_V_forward_paired_clean.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT1B_V_forward_paired_clean.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT1F_V_forward_paired_clean.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT2B_V_forward_paired_clean.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT2F_V_forward_paired_clean.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT3B_V_forward_paired_clean.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT3F_V_forward_paired_clean.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT4B_V_forward_paired_clean.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT4F_V_forward_paired_clean.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT1B_V_forward_paired_clean.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT1F_V_forward_paired_clean.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT2B_V_forward_paired_clean.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT2F_V_forward_paired_clean.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT3B_V_forward_paired_clean.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT3F_V_forward_paired_clean.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT4B_V_forward_paired_clean.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT4F_V_forward_paired_clean.tot_read_count.txt\x94\x8c_/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_C1_V_reverse_paired_clean.tot_read_count.txt\x94\x8c_/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_C2_V_reverse_paired_clean.tot_read_count.txt\x94\x8c_/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_C3_V_reverse_paired_clean.tot_read_count.txt\x94\x8c_/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_C4_V_reverse_paired_clean.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT1B_V_reverse_paired_clean.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT1F_V_reverse_paired_clean.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT2B_V_reverse_paired_clean.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT2F_V_reverse_paired_clean.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT3B_V_reverse_paired_clean.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT3F_V_reverse_paired_clean.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT4B_V_reverse_paired_clean.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT4F_V_reverse_paired_clean.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT1B_V_reverse_paired_clean.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT1F_V_reverse_paired_clean.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT2B_V_reverse_paired_clean.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT2F_V_reverse_paired_clean.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT3B_V_reverse_paired_clean.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT3F_V_reverse_paired_clean.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT4B_V_reverse_paired_clean.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT4F_V_reverse_paired_clean.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT1B_V_reverse_paired_clean.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT1F_V_reverse_paired_clean.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT2B_V_reverse_paired_clean.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT2F_V_reverse_paired_clean.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT3B_V_reverse_paired_clean.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT3F_V_reverse_paired_clean.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT4B_V_reverse_paired_clean.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT4F_V_reverse_paired_clean.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT1B_V_reverse_paired_clean.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT1F_V_reverse_paired_clean.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT2B_V_reverse_paired_clean.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT2F_V_reverse_paired_clean.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT3B_V_reverse_paired_clean.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT3F_V_reverse_paired_clean.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT4B_V_reverse_paired_clean.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT4F_V_reverse_paired_clean.tot_read_count.txt\x94\x8c`/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_C1_V_reverse_paired_clean.tot_read_count.txt\x94\x8c`/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_C2_V_reverse_paired_clean.tot_read_count.txt\x94\x8c`/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_C3_V_reverse_paired_clean.tot_read_count.txt\x94\x8c`/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_C4_V_reverse_paired_clean.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT1B_V_reverse_paired_clean.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT1F_V_reverse_paired_clean.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT2B_V_reverse_paired_clean.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT2F_V_reverse_paired_clean.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT3B_V_reverse_paired_clean.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT3F_V_reverse_paired_clean.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT4B_V_reverse_paired_clean.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT4F_V_reverse_paired_clean.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT1B_V_reverse_paired_clean.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT1F_V_reverse_paired_clean.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT2B_V_reverse_paired_clean.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT2F_V_reverse_paired_clean.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT3B_V_reverse_paired_clean.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT3F_V_reverse_paired_clean.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT4B_V_reverse_paired_clean.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT4F_V_reverse_paired_clean.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT1B_V_reverse_paired_clean.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT1F_V_reverse_paired_clean.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT2B_V_reverse_paired_clean.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT2F_V_reverse_paired_clean.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT3B_V_reverse_paired_clean.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT3F_V_reverse_paired_clean.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT4B_V_reverse_paired_clean.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT4F_V_reverse_paired_clean.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT1B_V_reverse_paired_clean.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT1F_V_reverse_paired_clean.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT2B_V_reverse_paired_clean.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT2F_V_reverse_paired_clean.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT3B_V_reverse_paired_clean.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT3F_V_reverse_paired_clean.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT4B_V_reverse_paired_clean.tot_read_count.txt\x94\x8cc/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT4F_V_reverse_paired_clean.tot_read_count.txt\x94\x8c^/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_C1_V_forward_paired_norm.tot_read_count.txt\x94\x8c^/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_C2_V_forward_paired_norm.tot_read_count.txt\x94\x8c^/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_C3_V_forward_paired_norm.tot_read_count.txt\x94\x8c^/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_C4_V_forward_paired_norm.tot_read_count.txt\x94\x8ca/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT1B_V_forward_paired_norm.tot_read_count.txt\x94\x8ca/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT1F_V_forward_paired_norm.tot_read_count.txt\x94\x8ca/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT2B_V_forward_paired_norm.tot_read_count.txt\x94\x8ca/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT2F_V_forward_paired_norm.tot_read_count.txt\x94\x8ca/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT3B_V_forward_paired_norm.tot_read_count.txt\x94\x8ca/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT3F_V_forward_paired_norm.tot_read_count.txt\x94\x8ca/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT4B_V_forward_paired_norm.tot_read_count.txt\x94\x8ca/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT4F_V_forward_paired_norm.tot_read_count.txt\x94\x8ca/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT1B_V_forward_paired_norm.tot_read_count.txt\x94\x8ca/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT1F_V_forward_paired_norm.tot_read_count.txt\x94\x8ca/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT2B_V_forward_paired_norm.tot_read_count.txt\x94\x8ca/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT2F_V_forward_paired_norm.tot_read_count.txt\x94\x8ca/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT3B_V_forward_paired_norm.tot_read_count.txt\x94\x8ca/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT3F_V_forward_paired_norm.tot_read_count.txt\x94\x8ca/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT4B_V_forward_paired_norm.tot_read_count.txt\x94\x8ca/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT4F_V_forward_paired_norm.tot_read_count.txt\x94\x8ca/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT1B_V_forward_paired_norm.tot_read_count.txt\x94\x8ca/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT1F_V_forward_paired_norm.tot_read_count.txt\x94\x8ca/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT2B_V_forward_paired_norm.tot_read_count.txt\x94\x8ca/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT2F_V_forward_paired_norm.tot_read_count.txt\x94\x8ca/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT3B_V_forward_paired_norm.tot_read_count.txt\x94\x8ca/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT3F_V_forward_paired_norm.tot_read_count.txt\x94\x8ca/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT4B_V_forward_paired_norm.tot_read_count.txt\x94\x8ca/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT4F_V_forward_paired_norm.tot_read_count.txt\x94\x8ca/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT1B_V_forward_paired_norm.tot_read_count.txt\x94\x8ca/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT1F_V_forward_paired_norm.tot_read_count.txt\x94\x8ca/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT2B_V_forward_paired_norm.tot_read_count.txt\x94\x8ca/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT2F_V_forward_paired_norm.tot_read_count.txt\x94\x8ca/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT3B_V_forward_paired_norm.tot_read_count.txt\x94\x8ca/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT3F_V_forward_paired_norm.tot_read_count.txt\x94\x8ca/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT4B_V_forward_paired_norm.tot_read_count.txt\x94\x8ca/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT4F_V_forward_paired_norm.tot_read_count.txt\x94\x8c_/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_C1_V_forward_paired_norm.tot_read_count.txt\x94\x8c_/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_C2_V_forward_paired_norm.tot_read_count.txt\x94\x8c_/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_C3_V_forward_paired_norm.tot_read_count.txt\x94\x8c_/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_C4_V_forward_paired_norm.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT1B_V_forward_paired_norm.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT1F_V_forward_paired_norm.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT2B_V_forward_paired_norm.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT2F_V_forward_paired_norm.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT3B_V_forward_paired_norm.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT3F_V_forward_paired_norm.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT4B_V_forward_paired_norm.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT4F_V_forward_paired_norm.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT1B_V_forward_paired_norm.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT1F_V_forward_paired_norm.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT2B_V_forward_paired_norm.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT2F_V_forward_paired_norm.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT3B_V_forward_paired_norm.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT3F_V_forward_paired_norm.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT4B_V_forward_paired_norm.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT4F_V_forward_paired_norm.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT1B_V_forward_paired_norm.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT1F_V_forward_paired_norm.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT2B_V_forward_paired_norm.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT2F_V_forward_paired_norm.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT3B_V_forward_paired_norm.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT3F_V_forward_paired_norm.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT4B_V_forward_paired_norm.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT4F_V_forward_paired_norm.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT1B_V_forward_paired_norm.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT1F_V_forward_paired_norm.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT2B_V_forward_paired_norm.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT2F_V_forward_paired_norm.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT3B_V_forward_paired_norm.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT3F_V_forward_paired_norm.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT4B_V_forward_paired_norm.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT4F_V_forward_paired_norm.tot_read_count.txt\x94\x8c^/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_C1_V_reverse_paired_norm.tot_read_count.txt\x94\x8c^/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_C2_V_reverse_paired_norm.tot_read_count.txt\x94\x8c^/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_C3_V_reverse_paired_norm.tot_read_count.txt\x94\x8c^/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_C4_V_reverse_paired_norm.tot_read_count.txt\x94\x8ca/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT1B_V_reverse_paired_norm.tot_read_count.txt\x94\x8ca/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT1F_V_reverse_paired_norm.tot_read_count.txt\x94\x8ca/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT2B_V_reverse_paired_norm.tot_read_count.txt\x94\x8ca/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT2F_V_reverse_paired_norm.tot_read_count.txt\x94\x8ca/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT3B_V_reverse_paired_norm.tot_read_count.txt\x94\x8ca/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT3F_V_reverse_paired_norm.tot_read_count.txt\x94\x8ca/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT4B_V_reverse_paired_norm.tot_read_count.txt\x94\x8ca/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT4F_V_reverse_paired_norm.tot_read_count.txt\x94\x8ca/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT1B_V_reverse_paired_norm.tot_read_count.txt\x94\x8ca/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT1F_V_reverse_paired_norm.tot_read_count.txt\x94\x8ca/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT2B_V_reverse_paired_norm.tot_read_count.txt\x94\x8ca/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT2F_V_reverse_paired_norm.tot_read_count.txt\x94\x8ca/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT3B_V_reverse_paired_norm.tot_read_count.txt\x94\x8ca/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT3F_V_reverse_paired_norm.tot_read_count.txt\x94\x8ca/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT4B_V_reverse_paired_norm.tot_read_count.txt\x94\x8ca/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT4F_V_reverse_paired_norm.tot_read_count.txt\x94\x8ca/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT1B_V_reverse_paired_norm.tot_read_count.txt\x94\x8ca/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT1F_V_reverse_paired_norm.tot_read_count.txt\x94\x8ca/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT2B_V_reverse_paired_norm.tot_read_count.txt\x94\x8ca/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT2F_V_reverse_paired_norm.tot_read_count.txt\x94\x8ca/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT3B_V_reverse_paired_norm.tot_read_count.txt\x94\x8ca/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT3F_V_reverse_paired_norm.tot_read_count.txt\x94\x8ca/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT4B_V_reverse_paired_norm.tot_read_count.txt\x94\x8ca/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT4F_V_reverse_paired_norm.tot_read_count.txt\x94\x8ca/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT1B_V_reverse_paired_norm.tot_read_count.txt\x94\x8ca/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT1F_V_reverse_paired_norm.tot_read_count.txt\x94\x8ca/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT2B_V_reverse_paired_norm.tot_read_count.txt\x94\x8ca/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT2F_V_reverse_paired_norm.tot_read_count.txt\x94\x8ca/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT3B_V_reverse_paired_norm.tot_read_count.txt\x94\x8ca/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT3F_V_reverse_paired_norm.tot_read_count.txt\x94\x8ca/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT4B_V_reverse_paired_norm.tot_read_count.txt\x94\x8ca/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT4F_V_reverse_paired_norm.tot_read_count.txt\x94\x8c_/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_C1_V_reverse_paired_norm.tot_read_count.txt\x94\x8c_/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_C2_V_reverse_paired_norm.tot_read_count.txt\x94\x8c_/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_C3_V_reverse_paired_norm.tot_read_count.txt\x94\x8c_/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_C4_V_reverse_paired_norm.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT1B_V_reverse_paired_norm.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT1F_V_reverse_paired_norm.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT2B_V_reverse_paired_norm.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT2F_V_reverse_paired_norm.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT3B_V_reverse_paired_norm.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT3F_V_reverse_paired_norm.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT4B_V_reverse_paired_norm.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT4F_V_reverse_paired_norm.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT1B_V_reverse_paired_norm.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT1F_V_reverse_paired_norm.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT2B_V_reverse_paired_norm.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT2F_V_reverse_paired_norm.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT3B_V_reverse_paired_norm.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT3F_V_reverse_paired_norm.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT4B_V_reverse_paired_norm.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT4F_V_reverse_paired_norm.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT1B_V_reverse_paired_norm.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT1F_V_reverse_paired_norm.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT2B_V_reverse_paired_norm.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT2F_V_reverse_paired_norm.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT3B_V_reverse_paired_norm.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT3F_V_reverse_paired_norm.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT4B_V_reverse_paired_norm.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT4F_V_reverse_paired_norm.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT1B_V_reverse_paired_norm.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT1F_V_reverse_paired_norm.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT2B_V_reverse_paired_norm.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT2F_V_reverse_paired_norm.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT3B_V_reverse_paired_norm.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT3F_V_reverse_paired_norm.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT4B_V_reverse_paired_norm.tot_read_count.txt\x94\x8cb/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT4F_V_reverse_paired_norm.tot_read_count.txt\x94\x8cH/home/lmf/DANIEL/VIRAL_METAGENOMES/01_QC/B_C1_V_stats_pcr_duplicates.log\x94\x8cH/home/lmf/DANIEL/VIRAL_METAGENOMES/01_QC/B_C2_V_stats_pcr_duplicates.log\x94\x8cH/home/lmf/DANIEL/VIRAL_METAGENOMES/01_QC/B_C3_V_stats_pcr_duplicates.log\x94\x8cH/home/lmf/DANIEL/VIRAL_METAGENOMES/01_QC/B_C4_V_stats_pcr_duplicates.log\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/01_QC/B_CIT1B_V_stats_pcr_duplicates.log\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/01_QC/B_CIT1F_V_stats_pcr_duplicates.log\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/01_QC/B_CIT2B_V_stats_pcr_duplicates.log\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/01_QC/B_CIT2F_V_stats_pcr_duplicates.log\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/01_QC/B_CIT3B_V_stats_pcr_duplicates.log\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/01_QC/B_CIT3F_V_stats_pcr_duplicates.log\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/01_QC/B_CIT4B_V_stats_pcr_duplicates.log\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/01_QC/B_CIT4F_V_stats_pcr_duplicates.log\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/01_QC/B_CNT1B_V_stats_pcr_duplicates.log\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/01_QC/B_CNT1F_V_stats_pcr_duplicates.log\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/01_QC/B_CNT2B_V_stats_pcr_duplicates.log\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/01_QC/B_CNT2F_V_stats_pcr_duplicates.log\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/01_QC/B_CNT3B_V_stats_pcr_duplicates.log\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/01_QC/B_CNT3F_V_stats_pcr_duplicates.log\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/01_QC/B_CNT4B_V_stats_pcr_duplicates.log\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/01_QC/B_CNT4F_V_stats_pcr_duplicates.log\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/01_QC/B_OIT1B_V_stats_pcr_duplicates.log\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/01_QC/B_OIT1F_V_stats_pcr_duplicates.log\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/01_QC/B_OIT2B_V_stats_pcr_duplicates.log\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/01_QC/B_OIT2F_V_stats_pcr_duplicates.log\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/01_QC/B_OIT3B_V_stats_pcr_duplicates.log\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/01_QC/B_OIT3F_V_stats_pcr_duplicates.log\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/01_QC/B_OIT4B_V_stats_pcr_duplicates.log\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/01_QC/B_OIT4F_V_stats_pcr_duplicates.log\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/01_QC/B_ORT1B_V_stats_pcr_duplicates.log\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/01_QC/B_ORT1F_V_stats_pcr_duplicates.log\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/01_QC/B_ORT2B_V_stats_pcr_duplicates.log\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/01_QC/B_ORT2F_V_stats_pcr_duplicates.log\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/01_QC/B_ORT3B_V_stats_pcr_duplicates.log\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/01_QC/B_ORT3F_V_stats_pcr_duplicates.log\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/01_QC/B_ORT4B_V_stats_pcr_duplicates.log\x94\x8cK/home/lmf/DANIEL/VIRAL_METAGENOMES/01_QC/B_ORT4F_V_stats_pcr_duplicates.log\x94\x8cI/home/lmf/DANIEL/VIRAL_METAGENOMES/01_QC/RS_C1_V_stats_pcr_duplicates.log\x94\x8cI/home/lmf/DANIEL/VIRAL_METAGENOMES/01_QC/RS_C2_V_stats_pcr_duplicates.log\x94\x8cI/home/lmf/DANIEL/VIRAL_METAGENOMES/01_QC/RS_C3_V_stats_pcr_duplicates.log\x94\x8cI/home/lmf/DANIEL/VIRAL_METAGENOMES/01_QC/RS_C4_V_stats_pcr_duplicates.log\x94\x8cL/home/lmf/DANIEL/VIRAL_METAGENOMES/01_QC/RS_CIT1B_V_stats_pcr_duplicates.log\x94\x8cL/home/lmf/DANIEL/VIRAL_METAGENOMES/01_QC/RS_CIT1F_V_stats_pcr_duplicates.log\x94\x8cL/home/lmf/DANIEL/VIRAL_METAGENOMES/01_QC/RS_CIT2B_V_stats_pcr_duplicates.log\x94\x8cL/home/lmf/DANIEL/VIRAL_METAGENOMES/01_QC/RS_CIT2F_V_stats_pcr_duplicates.log\x94\x8cL/home/lmf/DANIEL/VIRAL_METAGENOMES/01_QC/RS_CIT3B_V_stats_pcr_duplicates.log\x94\x8cL/home/lmf/DANIEL/VIRAL_METAGENOMES/01_QC/RS_CIT3F_V_stats_pcr_duplicates.log\x94\x8cL/home/lmf/DANIEL/VIRAL_METAGENOMES/01_QC/RS_CIT4B_V_stats_pcr_duplicates.log\x94\x8cL/home/lmf/DANIEL/VIRAL_METAGENOMES/01_QC/RS_CIT4F_V_stats_pcr_duplicates.log\x94\x8cL/home/lmf/DANIEL/VIRAL_METAGENOMES/01_QC/RS_CNT1B_V_stats_pcr_duplicates.log\x94\x8cL/home/lmf/DANIEL/VIRAL_METAGENOMES/01_QC/RS_CNT1F_V_stats_pcr_duplicates.log\x94\x8cL/home/lmf/DANIEL/VIRAL_METAGENOMES/01_QC/RS_CNT2B_V_stats_pcr_duplicates.log\x94\x8cL/home/lmf/DANIEL/VIRAL_METAGENOMES/01_QC/RS_CNT2F_V_stats_pcr_duplicates.log\x94\x8cL/home/lmf/DANIEL/VIRAL_METAGENOMES/01_QC/RS_CNT3B_V_stats_pcr_duplicates.log\x94\x8cL/home/lmf/DANIEL/VIRAL_METAGENOMES/01_QC/RS_CNT3F_V_stats_pcr_duplicates.log\x94\x8cL/home/lmf/DANIEL/VIRAL_METAGENOMES/01_QC/RS_CNT4B_V_stats_pcr_duplicates.log\x94\x8cL/home/lmf/DANIEL/VIRAL_METAGENOMES/01_QC/RS_CNT4F_V_stats_pcr_duplicates.log\x94\x8cL/home/lmf/DANIEL/VIRAL_METAGENOMES/01_QC/RS_OIT1B_V_stats_pcr_duplicates.log\x94\x8cL/home/lmf/DANIEL/VIRAL_METAGENOMES/01_QC/RS_OIT1F_V_stats_pcr_duplicates.log\x94\x8cL/home/lmf/DANIEL/VIRAL_METAGENOMES/01_QC/RS_OIT2B_V_stats_pcr_duplicates.log\x94\x8cL/home/lmf/DANIEL/VIRAL_METAGENOMES/01_QC/RS_OIT2F_V_stats_pcr_duplicates.log\x94\x8cL/home/lmf/DANIEL/VIRAL_METAGENOMES/01_QC/RS_OIT3B_V_stats_pcr_duplicates.log\x94\x8cL/home/lmf/DANIEL/VIRAL_METAGENOMES/01_QC/RS_OIT3F_V_stats_pcr_duplicates.log\x94\x8cL/home/lmf/DANIEL/VIRAL_METAGENOMES/01_QC/RS_OIT4B_V_stats_pcr_duplicates.log\x94\x8cL/home/lmf/DANIEL/VIRAL_METAGENOMES/01_QC/RS_OIT4F_V_stats_pcr_duplicates.log\x94\x8cL/home/lmf/DANIEL/VIRAL_METAGENOMES/01_QC/RS_ORT1B_V_stats_pcr_duplicates.log\x94\x8cL/home/lmf/DANIEL/VIRAL_METAGENOMES/01_QC/RS_ORT1F_V_stats_pcr_duplicates.log\x94\x8cL/home/lmf/DANIEL/VIRAL_METAGENOMES/01_QC/RS_ORT2B_V_stats_pcr_duplicates.log\x94\x8cL/home/lmf/DANIEL/VIRAL_METAGENOMES/01_QC/RS_ORT2F_V_stats_pcr_duplicates.log\x94\x8cL/home/lmf/DANIEL/VIRAL_METAGENOMES/01_QC/RS_ORT3B_V_stats_pcr_duplicates.log\x94\x8cL/home/lmf/DANIEL/VIRAL_METAGENOMES/01_QC/RS_ORT3F_V_stats_pcr_duplicates.log\x94\x8cL/home/lmf/DANIEL/VIRAL_METAGENOMES/01_QC/RS_ORT4B_V_stats_pcr_duplicates.log\x94\x8cL/home/lmf/DANIEL/VIRAL_METAGENOMES/01_QC/RS_ORT4F_V_stats_pcr_duplicates.log\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_C1_V_kmer_count_histogram_pre.tot.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_C2_V_kmer_count_histogram_pre.tot.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_C3_V_kmer_count_histogram_pre.tot.txt\x94\x8cX/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_C4_V_kmer_count_histogram_pre.tot.txt\x94\x8c[/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT1B_V_kmer_count_histogram_pre.tot.txt\x94\x8c[/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT1F_V_kmer_count_histogram_pre.tot.txt\x94\x8c[/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT2B_V_kmer_count_histogram_pre.tot.txt\x94\x8c[/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT2F_V_kmer_count_histogram_pre.tot.txt\x94\x8c[/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT3B_V_kmer_count_histogram_pre.tot.txt\x94\x8c[/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT3F_V_kmer_count_histogram_pre.tot.txt\x94\x8c[/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT4B_V_kmer_count_histogram_pre.tot.txt\x94\x8c[/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT4F_V_kmer_count_histogram_pre.tot.txt\x94\x8c[/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT1B_V_kmer_count_histogram_pre.tot.txt\x94\x8c[/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT1F_V_kmer_count_histogram_pre.tot.txt\x94\x8c[/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT2B_V_kmer_count_histogram_pre.tot.txt\x94\x8c[/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT2F_V_kmer_count_histogram_pre.tot.txt\x94\x8c[/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT3B_V_kmer_count_histogram_pre.tot.txt\x94\x8c[/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT3F_V_kmer_count_histogram_pre.tot.txt\x94\x8c[/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT4B_V_kmer_count_histogram_pre.tot.txt\x94\x8c[/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT4F_V_kmer_count_histogram_pre.tot.txt\x94\x8c[/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT1B_V_kmer_count_histogram_pre.tot.txt\x94\x8c[/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT1F_V_kmer_count_histogram_pre.tot.txt\x94\x8c[/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT2B_V_kmer_count_histogram_pre.tot.txt\x94\x8c[/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT2F_V_kmer_count_histogram_pre.tot.txt\x94\x8c[/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT3B_V_kmer_count_histogram_pre.tot.txt\x94\x8c[/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT3F_V_kmer_count_histogram_pre.tot.txt\x94\x8c[/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT4B_V_kmer_count_histogram_pre.tot.txt\x94\x8c[/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT4F_V_kmer_count_histogram_pre.tot.txt\x94\x8c[/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT1B_V_kmer_count_histogram_pre.tot.txt\x94\x8c[/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT1F_V_kmer_count_histogram_pre.tot.txt\x94\x8c[/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT2B_V_kmer_count_histogram_pre.tot.txt\x94\x8c[/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT2F_V_kmer_count_histogram_pre.tot.txt\x94\x8c[/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT3B_V_kmer_count_histogram_pre.tot.txt\x94\x8c[/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT3F_V_kmer_count_histogram_pre.tot.txt\x94\x8c[/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT4B_V_kmer_count_histogram_pre.tot.txt\x94\x8c[/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT4F_V_kmer_count_histogram_pre.tot.txt\x94\x8cY/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_C1_V_kmer_count_histogram_pre.tot.txt\x94\x8cY/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_C2_V_kmer_count_histogram_pre.tot.txt\x94\x8cY/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_C3_V_kmer_count_histogram_pre.tot.txt\x94\x8cY/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_C4_V_kmer_count_histogram_pre.tot.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT1B_V_kmer_count_histogram_pre.tot.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT1F_V_kmer_count_histogram_pre.tot.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT2B_V_kmer_count_histogram_pre.tot.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT2F_V_kmer_count_histogram_pre.tot.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT3B_V_kmer_count_histogram_pre.tot.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT3F_V_kmer_count_histogram_pre.tot.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT4B_V_kmer_count_histogram_pre.tot.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT4F_V_kmer_count_histogram_pre.tot.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT1B_V_kmer_count_histogram_pre.tot.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT1F_V_kmer_count_histogram_pre.tot.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT2B_V_kmer_count_histogram_pre.tot.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT2F_V_kmer_count_histogram_pre.tot.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT3B_V_kmer_count_histogram_pre.tot.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT3F_V_kmer_count_histogram_pre.tot.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT4B_V_kmer_count_histogram_pre.tot.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT4F_V_kmer_count_histogram_pre.tot.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT1B_V_kmer_count_histogram_pre.tot.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT1F_V_kmer_count_histogram_pre.tot.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT2B_V_kmer_count_histogram_pre.tot.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT2F_V_kmer_count_histogram_pre.tot.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT3B_V_kmer_count_histogram_pre.tot.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT3F_V_kmer_count_histogram_pre.tot.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT4B_V_kmer_count_histogram_pre.tot.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT4F_V_kmer_count_histogram_pre.tot.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT1B_V_kmer_count_histogram_pre.tot.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT1F_V_kmer_count_histogram_pre.tot.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT2B_V_kmer_count_histogram_pre.tot.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT2F_V_kmer_count_histogram_pre.tot.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT3B_V_kmer_count_histogram_pre.tot.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT3F_V_kmer_count_histogram_pre.tot.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT4B_V_kmer_count_histogram_pre.tot.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT4F_V_kmer_count_histogram_pre.tot.txt\x94\x8cY/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_C1_V_kmer_count_histogram_post.tot.txt\x94\x8cY/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_C2_V_kmer_count_histogram_post.tot.txt\x94\x8cY/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_C3_V_kmer_count_histogram_post.tot.txt\x94\x8cY/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_C4_V_kmer_count_histogram_post.tot.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT1B_V_kmer_count_histogram_post.tot.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT1F_V_kmer_count_histogram_post.tot.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT2B_V_kmer_count_histogram_post.tot.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT2F_V_kmer_count_histogram_post.tot.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT3B_V_kmer_count_histogram_post.tot.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT3F_V_kmer_count_histogram_post.tot.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT4B_V_kmer_count_histogram_post.tot.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT4F_V_kmer_count_histogram_post.tot.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT1B_V_kmer_count_histogram_post.tot.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT1F_V_kmer_count_histogram_post.tot.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT2B_V_kmer_count_histogram_post.tot.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT2F_V_kmer_count_histogram_post.tot.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT3B_V_kmer_count_histogram_post.tot.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT3F_V_kmer_count_histogram_post.tot.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT4B_V_kmer_count_histogram_post.tot.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT4F_V_kmer_count_histogram_post.tot.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT1B_V_kmer_count_histogram_post.tot.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT1F_V_kmer_count_histogram_post.tot.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT2B_V_kmer_count_histogram_post.tot.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT2F_V_kmer_count_histogram_post.tot.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT3B_V_kmer_count_histogram_post.tot.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT3F_V_kmer_count_histogram_post.tot.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT4B_V_kmer_count_histogram_post.tot.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT4F_V_kmer_count_histogram_post.tot.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT1B_V_kmer_count_histogram_post.tot.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT1F_V_kmer_count_histogram_post.tot.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT2B_V_kmer_count_histogram_post.tot.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT2F_V_kmer_count_histogram_post.tot.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT3B_V_kmer_count_histogram_post.tot.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT3F_V_kmer_count_histogram_post.tot.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT4B_V_kmer_count_histogram_post.tot.txt\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT4F_V_kmer_count_histogram_post.tot.txt\x94\x8cZ/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_C1_V_kmer_count_histogram_post.tot.txt\x94\x8cZ/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_C2_V_kmer_count_histogram_post.tot.txt\x94\x8cZ/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_C3_V_kmer_count_histogram_post.tot.txt\x94\x8cZ/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_C4_V_kmer_count_histogram_post.tot.txt\x94\x8c]/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT1B_V_kmer_count_histogram_post.tot.txt\x94\x8c]/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT1F_V_kmer_count_histogram_post.tot.txt\x94\x8c]/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT2B_V_kmer_count_histogram_post.tot.txt\x94\x8c]/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT2F_V_kmer_count_histogram_post.tot.txt\x94\x8c]/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT3B_V_kmer_count_histogram_post.tot.txt\x94\x8c]/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT3F_V_kmer_count_histogram_post.tot.txt\x94\x8c]/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT4B_V_kmer_count_histogram_post.tot.txt\x94\x8c]/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT4F_V_kmer_count_histogram_post.tot.txt\x94\x8c]/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT1B_V_kmer_count_histogram_post.tot.txt\x94\x8c]/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT1F_V_kmer_count_histogram_post.tot.txt\x94\x8c]/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT2B_V_kmer_count_histogram_post.tot.txt\x94\x8c]/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT2F_V_kmer_count_histogram_post.tot.txt\x94\x8c]/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT3B_V_kmer_count_histogram_post.tot.txt\x94\x8c]/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT3F_V_kmer_count_histogram_post.tot.txt\x94e(\x8c]/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT4B_V_kmer_count_histogram_post.tot.txt\x94\x8c]/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT4F_V_kmer_count_histogram_post.tot.txt\x94\x8c]/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT1B_V_kmer_count_histogram_post.tot.txt\x94\x8c]/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT1F_V_kmer_count_histogram_post.tot.txt\x94\x8c]/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT2B_V_kmer_count_histogram_post.tot.txt\x94\x8c]/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT2F_V_kmer_count_histogram_post.tot.txt\x94\x8c]/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT3B_V_kmer_count_histogram_post.tot.txt\x94\x8c]/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT3F_V_kmer_count_histogram_post.tot.txt\x94\x8c]/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT4B_V_kmer_count_histogram_post.tot.txt\x94\x8c]/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT4F_V_kmer_count_histogram_post.tot.txt\x94\x8c]/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT1B_V_kmer_count_histogram_post.tot.txt\x94\x8c]/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT1F_V_kmer_count_histogram_post.tot.txt\x94\x8c]/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT2B_V_kmer_count_histogram_post.tot.txt\x94\x8c]/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT2F_V_kmer_count_histogram_post.tot.txt\x94\x8c]/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT3B_V_kmer_count_histogram_post.tot.txt\x94\x8c]/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT3F_V_kmer_count_histogram_post.tot.txt\x94\x8c]/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT4B_V_kmer_count_histogram_post.tot.txt\x94\x8c]/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT4F_V_kmer_count_histogram_post.tot.txt\x94\x8cP/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_C1_V_kmer_count_peaks.tot.txt\x94\x8cP/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_C2_V_kmer_count_peaks.tot.txt\x94\x8cP/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_C3_V_kmer_count_peaks.tot.txt\x94\x8cP/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_C4_V_kmer_count_peaks.tot.txt\x94\x8cS/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT1B_V_kmer_count_peaks.tot.txt\x94\x8cS/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT1F_V_kmer_count_peaks.tot.txt\x94\x8cS/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT2B_V_kmer_count_peaks.tot.txt\x94\x8cS/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT2F_V_kmer_count_peaks.tot.txt\x94\x8cS/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT3B_V_kmer_count_peaks.tot.txt\x94\x8cS/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT3F_V_kmer_count_peaks.tot.txt\x94\x8cS/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT4B_V_kmer_count_peaks.tot.txt\x94\x8cS/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT4F_V_kmer_count_peaks.tot.txt\x94\x8cS/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT1B_V_kmer_count_peaks.tot.txt\x94\x8cS/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT1F_V_kmer_count_peaks.tot.txt\x94\x8cS/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT2B_V_kmer_count_peaks.tot.txt\x94\x8cS/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT2F_V_kmer_count_peaks.tot.txt\x94\x8cS/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT3B_V_kmer_count_peaks.tot.txt\x94\x8cS/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT3F_V_kmer_count_peaks.tot.txt\x94\x8cS/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT4B_V_kmer_count_peaks.tot.txt\x94\x8cS/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CNT4F_V_kmer_count_peaks.tot.txt\x94\x8cS/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT1B_V_kmer_count_peaks.tot.txt\x94\x8cS/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT1F_V_kmer_count_peaks.tot.txt\x94\x8cS/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT2B_V_kmer_count_peaks.tot.txt\x94\x8cS/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT2F_V_kmer_count_peaks.tot.txt\x94\x8cS/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT3B_V_kmer_count_peaks.tot.txt\x94\x8cS/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT3F_V_kmer_count_peaks.tot.txt\x94\x8cS/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT4B_V_kmer_count_peaks.tot.txt\x94\x8cS/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_OIT4F_V_kmer_count_peaks.tot.txt\x94\x8cS/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT1B_V_kmer_count_peaks.tot.txt\x94\x8cS/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT1F_V_kmer_count_peaks.tot.txt\x94\x8cS/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT2B_V_kmer_count_peaks.tot.txt\x94\x8cS/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT2F_V_kmer_count_peaks.tot.txt\x94\x8cS/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT3B_V_kmer_count_peaks.tot.txt\x94\x8cS/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT3F_V_kmer_count_peaks.tot.txt\x94\x8cS/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT4B_V_kmer_count_peaks.tot.txt\x94\x8cS/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_ORT4F_V_kmer_count_peaks.tot.txt\x94\x8cQ/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_C1_V_kmer_count_peaks.tot.txt\x94\x8cQ/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_C2_V_kmer_count_peaks.tot.txt\x94\x8cQ/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_C3_V_kmer_count_peaks.tot.txt\x94\x8cQ/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_C4_V_kmer_count_peaks.tot.txt\x94\x8cT/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT1B_V_kmer_count_peaks.tot.txt\x94\x8cT/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT1F_V_kmer_count_peaks.tot.txt\x94\x8cT/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT2B_V_kmer_count_peaks.tot.txt\x94\x8cT/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT2F_V_kmer_count_peaks.tot.txt\x94\x8cT/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT3B_V_kmer_count_peaks.tot.txt\x94\x8cT/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT3F_V_kmer_count_peaks.tot.txt\x94\x8cT/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT4B_V_kmer_count_peaks.tot.txt\x94\x8cT/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CIT4F_V_kmer_count_peaks.tot.txt\x94\x8cT/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT1B_V_kmer_count_peaks.tot.txt\x94\x8cT/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT1F_V_kmer_count_peaks.tot.txt\x94\x8cT/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT2B_V_kmer_count_peaks.tot.txt\x94\x8cT/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT2F_V_kmer_count_peaks.tot.txt\x94\x8cT/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT3B_V_kmer_count_peaks.tot.txt\x94\x8cT/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT3F_V_kmer_count_peaks.tot.txt\x94\x8cT/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT4B_V_kmer_count_peaks.tot.txt\x94\x8cT/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_CNT4F_V_kmer_count_peaks.tot.txt\x94\x8cT/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT1B_V_kmer_count_peaks.tot.txt\x94\x8cT/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT1F_V_kmer_count_peaks.tot.txt\x94\x8cT/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT2B_V_kmer_count_peaks.tot.txt\x94\x8cT/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT2F_V_kmer_count_peaks.tot.txt\x94\x8cT/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT3B_V_kmer_count_peaks.tot.txt\x94\x8cT/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT3F_V_kmer_count_peaks.tot.txt\x94\x8cT/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT4B_V_kmer_count_peaks.tot.txt\x94\x8cT/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_OIT4F_V_kmer_count_peaks.tot.txt\x94\x8cT/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT1B_V_kmer_count_peaks.tot.txt\x94\x8cT/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT1F_V_kmer_count_peaks.tot.txt\x94\x8cT/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT2B_V_kmer_count_peaks.tot.txt\x94\x8cT/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT2F_V_kmer_count_peaks.tot.txt\x94\x8cT/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT3B_V_kmer_count_peaks.tot.txt\x94\x8cT/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT3F_V_kmer_count_peaks.tot.txt\x94\x8cT/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT4B_V_kmer_count_peaks.tot.txt\x94\x8cT/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/RS_ORT4F_V_kmer_count_peaks.tot.txt\x94e}\x94(\x8c\x06_names\x94}\x94(\x8c\nhistograms\x94M\xf0\x03M8\x04\x86\x94\x8c\tpreqc_txt\x94M8\x04N\x86\x94\x8c\npostqc_txt\x94M9\x04N\x86\x94\x8c\x16read_count_raw_forward\x94M:\x04M\x82\x04\x86\x94\x8c\x16read_count_raw_reverse\x94M\x82\x04M\xca\x04\x86\x94\x8c\x1aread_count_trimmed_forward\x94M\xca\x04M\x12\x05\x86\x94\x8c\x1aread_count_trimmed_reverse\x94M\x12\x05MZ\x05\x86\x94\x8c\x16read_count_euk_forward\x94MZ\x05M\xa2\x05\x86\x94\x8c\x16read_count_euk_reverse\x94M\xa2\x05M\xea\x05\x86\x94\x8c\x16read_count_duk_forward\x94M\xea\x05M2\x06\x86\x94\x8c\x16read_count_duk_reverse\x94M2\x06Mz\x06\x86\x94\x8c\x17read_count_norm_forward\x94Mz\x06M\xc2\x06\x86\x94\x8c\x17read_count_norm_reverse\x94M\xc2\x06M\n\x07\x86\x94\x8c\x0csupper_dedup\x94M\n\x07MR\x07\x86\x94\x8c\x12histogram_kmer_pre\x94MR\x07M\x9a\x07\x86\x94\x8c\x13histogram_kmer_post\x94M\x9a\x07M\xe2\x07\x86\x94\x8c\tpeak_kmer\x94M\xe2\x07M*\x08\x86\x94u\x8c\x12_allowed_overrides\x94]\x94(\x8c\x05index\x94\x8c\x04sort\x94ej[\x08\x00\x00\x8c\tfunctools\x94\x8c\x07partial\x94\x93\x94h\x06\x8c\x19Namedlist._used_attribute\x94\x93\x94\x85\x94R\x94(ja\x08\x00\x00)}\x94\x8c\x05_name\x94j[\x08\x00\x00sNt\x94bj\\\x08\x00\x00j_\x08\x00\x00ja\x08\x00\x00\x85\x94R\x94(ja\x08\x00\x00)}\x94je\x08\x00\x00j\\\x08\x00\x00sNt\x94bj7\x08\x00\x00h\x06\x8c\tNamedlist\x94\x93\x94)\x81\x94(j\xfa\x03\x00\x00j\xfb\x03\x00\x00j\xfc\x03\x00\x00j\xfd\x03\x00\x00j\xfe\x03\x00\x00j\xff\x03\x00\x00j\x00\x04\x00\x00j\x01\x04\x00\x00j\x02\x04\x00\x00j\x03\x04\x00\x00j\x04\x04\x00\x00j\x05\x04\x00\x00j\x06\x04\x00\x00j\x07\x04\x00\x00j\x08\x04\x00\x00j\t\x04\x00\x00j\n\x04\x00\x00j\x0b\x04\x00\x00j\x0c\x04\x00\x00j\r\x04\x00\x00j\x0e\x04\x00\x00j\x0f\x04\x00\x00j\x10\x04\x00\x00j\x11\x04\x00\x00j\x12\x04\x00\x00j\x13\x04\x00\x00j\x14\x04\x00\x00j\x15\x04\x00\x00j\x16\x04\x00\x00j\x17\x04\x00\x00j\x18\x04\x00\x00j\x19\x04\x00\x00j\x1a\x04\x00\x00j\x1b\x04\x00\x00j\x1c\x04\x00\x00j\x1d\x04\x00\x00j\x1e\x04\x00\x00j\x1f\x04\x00\x00j \x04\x00\x00j!\x04\x00\x00j"\x04\x00\x00j#\x04\x00\x00j$\x04\x00\x00j%\x04\x00\x00j&\x04\x00\x00j\'\x04\x00\x00j(\x04\x00\x00j)\x04\x00\x00j*\x04\x00\x00j+\x04\x00\x00j,\x04\x00\x00j-\x04\x00\x00j.\x04\x00\x00j/\x04\x00\x00j0\x04\x00\x00j1\x04\x00\x00j2\x04\x00\x00j3\x04\x00\x00j4\x04\x00\x00j5\x04\x00\x00j6\x04\x00\x00j7\x04\x00\x00j8\x04\x00\x00j9\x04\x00\x00j:\x04\x00\x00j;\x04\x00\x00j<\x04\x00\x00j=\x04\x00\x00j>\x04\x00\x00j?\x04\x00\x00j@\x04\x00\x00jA\x04\x00\x00e}\x94(j5\x08\x00\x00}\x94jY\x08\x00\x00]\x94(j[\x08\x00\x00j\\\x08\x00\x00ej[\x08\x00\x00j_\x08\x00\x00ja\x08\x00\x00\x85\x94R\x94(ja\x08\x00\x00)}\x94je\x08\x00\x00j[\x08\x00\x00sNt\x94bj\\\x08\x00\x00j_\x08\x00\x00ja\x08\x00\x00\x85\x94R\x94(ja\x08\x00\x00)}\x94je\x08\x00\x00j\\\x08\x00\x00sNt\x94bubj9\x08\x00\x00jB\x04\x00\x00j;\x08\x00\x00jC\x04\x00\x00j=\x08\x00\x00jl\x08\x00\x00)\x81\x94(jD\x04\x00\x00jE\x04\x00\x00jF\x04\x00\x00jG\x04\x00\x00jH\x04\x00\x00jI\x04\x00\x00jJ\x04\x00\x00jK\x04\x00\x00jL\x04\x00\x00jM\x04\x00\x00jN\x04\x00\x00jO\x04\x00\x00jP\x04\x00\x00jQ\x04\x00\x00jR\x04\x00\x00jS\x04\x00\x00jT\x04\x00\x00jU\x04\x00\x00jV\x04\x00\x00jW\x04\x00\x00jX\x04\x00\x00jY\x04\x00\x00jZ\x04\x00\x00j[\x04\x00\x00j\\\x04\x00\x00j]\x04\x00\x00j^\x04\x00\x00j_\x04\x00\x00j`\x04\x00\x00ja\x04\x00\x00jb\x04\x00\x00jc\x04\x00\x00jd\x04\x00\x00je\x04\x00\x00jf\x04\x00\x00jg\x04\x00\x00jh\x04\x00\x00ji\x04\x00\x00jj\x04\x00\x00jk\x04\x00\x00jl\x04\x00\x00jm\x04\x00\x00jn\x04\x00\x00jo\x04\x00\x00jp\x04\x00\x00jq\x04\x00\x00jr\x04\x00\x00js\x04\x00\x00jt\x04\x00\x00ju\x04\x00\x00jv\x04\x00\x00jw\x04\x00\x00jx\x04\x00\x00jy\x04\x00\x00jz\x04\x00\x00j{\x04\x00\x00j|\x04\x00\x00j}\x04\x00\x00j~\x04\x00\x00j\x7f\x04\x00\x00j\x80\x04\x00\x00j\x81\x04\x00\x00j\x82\x04\x00\x00j\x83\x04\x00\x00j\x84\x04\x00\x00j\x85\x04\x00\x00j\x86\x04\x00\x00j\x87\x04\x00\x00j\x88\x04\x00\x00j\x89\x04\x00\x00j\x8a\x04\x00\x00j\x8b\x04\x00\x00e}\x94(j5\x08\x00\x00}\x94jY\x08\x00\x00]\x94(j[\x08\x00\x00j\\\x08\x00\x00ej[\x08\x00\x00j_\x08\x00\x00ja\x08\x00\x00\x85\x94R\x94(ja\x08\x00\x00)}\x94je\x08\x00\x00j[\x08\x00\x00sNt\x94bj\\\x08\x00\x00j_\x08\x00\x00ja\x08\x00\x00\x85\x94R\x94(ja\x08\x00\x00)}\x94je\x08\x00\x00j\\\x08\x00\x00sNt\x94bubj?\x08\x00\x00jl\x08\x00\x00)\x81\x94(j\x8c\x04\x00\x00j\x8d\x04\x00\x00j\x8e\x04\x00\x00j\x8f\x04\x00\x00j\x90\x04\x00\x00j\x91\x04\x00\x00j\x92\x04\x00\x00j\x93\x04\x00\x00j\x94\x04\x00\x00j\x95\x04\x00\x00j\x96\x04\x00\x00j\x97\x04\x00\x00j\x98\x04\x00\x00j\x99\x04\x00\x00j\x9a\x04\x00\x00j\x9b\x04\x00\x00j\x9c\x04\x00\x00j\x9d\x04\x00\x00j\x9e\x04\x00\x00j\x9f\x04\x00\x00j\xa0\x04\x00\x00j\xa1\x04\x00\x00j\xa2\x04\x00\x00j\xa3\x04\x00\x00j\xa4\x04\x00\x00j\xa5\x04\x00\x00j\xa6\x04\x00\x00j\xa7\x04\x00\x00j\xa8\x04\x00\x00j\xa9\x04\x00\x00j\xaa\x04\x00\x00j\xab\x04\x00\x00j\xac\x04\x00\x00j\xad\x04\x00\x00j\xae\x04\x00\x00j\xaf\x04\x00\x00j\xb0\x04\x00\x00j\xb1\x04\x00\x00j\xb2\x04\x00\x00j\xb3\x04\x00\x00j\xb4\x04\x00\x00j\xb5\x04\x00\x00j\xb6\x04\x00\x00j\xb7\x04\x00\x00j\xb8\x04\x00\x00j\xb9\x04\x00\x00j\xba\x04\x00\x00j\xbb\x04\x00\x00\x9597\x00\x00\x00\x00\x00\x00j\xbc\x04\x00\x00j\xbd\x04\x00\x00j\xbe\x04\x00\x00j\xbf\x04\x00\x00j\xc0\x04\x00\x00j\xc1\x04\x00\x00j\xc2\x04\x00\x00j\xc3\x04\x00\x00j\xc4\x04\x00\x00j\xc5\x04\x00\x00j\xc6\x04\x00\x00j\xc7\x04\x00\x00j\xc8\x04\x00\x00j\xc9\x04\x00\x00j\xca\x04\x00\x00j\xcb\x04\x00\x00j\xcc\x04\x00\x00j\xcd\x04\x00\x00j\xce\x04\x00\x00j\xcf\x04\x00\x00j\xd0\x04\x00\x00j\xd1\x04\x00\x00j\xd2\x04\x00\x00j\xd3\x04\x00\x00e}\x94(j5\x08\x00\x00}\x94jY\x08\x00\x00]\x94(j[\x08\x00\x00j\\\x08\x00\x00ej[\x08\x00\x00j_\x08\x00\x00ja\x08\x00\x00\x85\x94R\x94(ja\x08\x00\x00)}\x94je\x08\x00\x00j[\x08\x00\x00sNt\x94bj\\\x08\x00\x00j_\x08\x00\x00ja\x08\x00\x00\x85\x94R\x94(ja\x08\x00\x00)}\x94je\x08\x00\x00j\\\x08\x00\x00sNt\x94bubjA\x08\x00\x00jl\x08\x00\x00)\x81\x94(j\xd4\x04\x00\x00j\xd5\x04\x00\x00j\xd6\x04\x00\x00j\xd7\x04\x00\x00j\xd8\x04\x00\x00j\xd9\x04\x00\x00j\xda\x04\x00\x00j\xdb\x04\x00\x00j\xdc\x04\x00\x00j\xdd\x04\x00\x00j\xde\x04\x00\x00j\xdf\x04\x00\x00j\xe0\x04\x00\x00j\xe1\x04\x00\x00j\xe2\x04\x00\x00j\xe3\x04\x00\x00j\xe4\x04\x00\x00j\xe5\x04\x00\x00j\xe6\x04\x00\x00j\xe7\x04\x00\x00j\xe8\x04\x00\x00j\xe9\x04\x00\x00j\xea\x04\x00\x00j\xeb\x04\x00\x00j\xec\x04\x00\x00j\xed\x04\x00\x00j\xee\x04\x00\x00j\xef\x04\x00\x00j\xf0\x04\x00\x00j\xf1\x04\x00\x00j\xf2\x04\x00\x00j\xf3\x04\x00\x00j\xf4\x04\x00\x00j\xf5\x04\x00\x00j\xf6\x04\x00\x00j\xf7\x04\x00\x00j\xf8\x04\x00\x00j\xf9\x04\x00\x00j\xfa\x04\x00\x00j\xfb\x04\x00\x00j\xfc\x04\x00\x00j\xfd\x04\x00\x00j\xfe\x04\x00\x00j\xff\x04\x00\x00j\x00\x05\x00\x00j\x01\x05\x00\x00j\x02\x05\x00\x00j\x03\x05\x00\x00j\x04\x05\x00\x00j\x05\x05\x00\x00j\x06\x05\x00\x00j\x07\x05\x00\x00j\x08\x05\x00\x00j\t\x05\x00\x00j\n\x05\x00\x00j\x0b\x05\x00\x00j\x0c\x05\x00\x00j\r\x05\x00\x00j\x0e\x05\x00\x00j\x0f\x05\x00\x00j\x10\x05\x00\x00j\x11\x05\x00\x00j\x12\x05\x00\x00j\x13\x05\x00\x00j\x14\x05\x00\x00j\x15\x05\x00\x00j\x16\x05\x00\x00j\x17\x05\x00\x00j\x18\x05\x00\x00j\x19\x05\x00\x00j\x1a\x05\x00\x00j\x1b\x05\x00\x00e}\x94(j5\x08\x00\x00}\x94jY\x08\x00\x00]\x94(j[\x08\x00\x00j\\\x08\x00\x00ej[\x08\x00\x00j_\x08\x00\x00ja\x08\x00\x00\x85\x94R\x94(ja\x08\x00\x00)}\x94je\x08\x00\x00j[\x08\x00\x00sNt\x94bj\\\x08\x00\x00j_\x08\x00\x00ja\x08\x00\x00\x85\x94R\x94(ja\x08\x00\x00)}\x94je\x08\x00\x00j\\\x08\x00\x00sNt\x94bubjC\x08\x00\x00jl\x08\x00\x00)\x81\x94(j\x1c\x05\x00\x00j\x1d\x05\x00\x00j\x1e\x05\x00\x00j\x1f\x05\x00\x00j \x05\x00\x00j!\x05\x00\x00j"\x05\x00\x00j#\x05\x00\x00j$\x05\x00\x00j%\x05\x00\x00j&\x05\x00\x00j\'\x05\x00\x00j(\x05\x00\x00j)\x05\x00\x00j*\x05\x00\x00j+\x05\x00\x00j,\x05\x00\x00j-\x05\x00\x00j.\x05\x00\x00j/\x05\x00\x00j0\x05\x00\x00j1\x05\x00\x00j2\x05\x00\x00j3\x05\x00\x00j4\x05\x00\x00j5\x05\x00\x00j6\x05\x00\x00j7\x05\x00\x00j8\x05\x00\x00j9\x05\x00\x00j:\x05\x00\x00j;\x05\x00\x00j<\x05\x00\x00j=\x05\x00\x00j>\x05\x00\x00j?\x05\x00\x00j@\x05\x00\x00jA\x05\x00\x00jB\x05\x00\x00jC\x05\x00\x00jD\x05\x00\x00jE\x05\x00\x00jF\x05\x00\x00jG\x05\x00\x00jH\x05\x00\x00jI\x05\x00\x00jJ\x05\x00\x00jK\x05\x00\x00jL\x05\x00\x00jM\x05\x00\x00jN\x05\x00\x00jO\x05\x00\x00jP\x05\x00\x00jQ\x05\x00\x00jR\x05\x00\x00jS\x05\x00\x00jT\x05\x00\x00jU\x05\x00\x00jV\x05\x00\x00jW\x05\x00\x00jX\x05\x00\x00jY\x05\x00\x00jZ\x05\x00\x00j[\x05\x00\x00j\\\x05\x00\x00j]\x05\x00\x00j^\x05\x00\x00j_\x05\x00\x00j`\x05\x00\x00ja\x05\x00\x00jb\x05\x00\x00jc\x05\x00\x00e}\x94(j5\x08\x00\x00}\x94jY\x08\x00\x00]\x94(j[\x08\x00\x00j\\\x08\x00\x00ej[\x08\x00\x00j_\x08\x00\x00ja\x08\x00\x00\x85\x94R\x94(ja\x08\x00\x00)}\x94je\x08\x00\x00j[\x08\x00\x00sNt\x94bj\\\x08\x00\x00j_\x08\x00\x00ja\x08\x00\x00\x85\x94R\x94(ja\x08\x00\x00)}\x94je\x08\x00\x00j\\\x08\x00\x00sNt\x94bubjE\x08\x00\x00jl\x08\x00\x00)\x81\x94(jd\x05\x00\x00je\x05\x00\x00jf\x05\x00\x00jg\x05\x00\x00jh\x05\x00\x00ji\x05\x00\x00jj\x05\x00\x00jk\x05\x00\x00jl\x05\x00\x00jm\x05\x00\x00jn\x05\x00\x00jo\x05\x00\x00jp\x05\x00\x00jq\x05\x00\x00jr\x05\x00\x00js\x05\x00\x00jt\x05\x00\x00ju\x05\x00\x00jv\x05\x00\x00jw\x05\x00\x00jx\x05\x00\x00jy\x05\x00\x00jz\x05\x00\x00j{\x05\x00\x00j|\x05\x00\x00j}\x05\x00\x00j~\x05\x00\x00j\x7f\x05\x00\x00j\x80\x05\x00\x00j\x81\x05\x00\x00j\x82\x05\x00\x00j\x83\x05\x00\x00j\x84\x05\x00\x00j\x85\x05\x00\x00j\x86\x05\x00\x00j\x87\x05\x00\x00j\x88\x05\x00\x00j\x89\x05\x00\x00j\x8a\x05\x00\x00j\x8b\x05\x00\x00j\x8c\x05\x00\x00j\x8d\x05\x00\x00j\x8e\x05\x00\x00j\x8f\x05\x00\x00j\x90\x05\x00\x00j\x91\x05\x00\x00j\x92\x05\x00\x00j\x93\x05\x00\x00j\x94\x05\x00\x00j\x95\x05\x00\x00j\x96\x05\x00\x00j\x97\x05\x00\x00j\x98\x05\x00\x00j\x99\x05\x00\x00j\x9a\x05\x00\x00j\x9b\x05\x00\x00j\x9c\x05\x00\x00j\x9d\x05\x00\x00j\x9e\x05\x00\x00j\x9f\x05\x00\x00j\xa0\x05\x00\x00j\xa1\x05\x00\x00j\xa2\x05\x00\x00j\xa3\x05\x00\x00j\xa4\x05\x00\x00j\xa5\x05\x00\x00j\xa6\x05\x00\x00j\xa7\x05\x00\x00j\xa8\x05\x00\x00j\xa9\x05\x00\x00j\xaa\x05\x00\x00j\xab\x05\x00\x00e}\x94(j5\x08\x00\x00}\x94jY\x08\x00\x00]\x94(j[\x08\x00\x00j\\\x08\x00\x00ej[\x08\x00\x00j_\x08\x00\x00ja\x08\x00\x00\x85\x94R\x94(ja\x08\x00\x00)}\x94je\x08\x00\x00j[\x08\x00\x00sNt\x94bj\\\x08\x00\x00j_\x08\x00\x00ja\x08\x00\x00\x85\x94R\x94(ja\x08\x00\x00)}\x94je\x08\x00\x00j\\\x08\x00\x00sNt\x94bubjG\x08\x00\x00jl\x08\x00\x00)\x81\x94(j\xac\x05\x00\x00j\xad\x05\x00\x00j\xae\x05\x00\x00j\xaf\x05\x00\x00j\xb0\x05\x00\x00j\xb1\x05\x00\x00j\xb2\x05\x00\x00j\xb3\x05\x00\x00j\xb4\x05\x00\x00j\xb5\x05\x00\x00j\xb6\x05\x00\x00j\xb7\x05\x00\x00j\xb8\x05\x00\x00j\xb9\x05\x00\x00j\xba\x05\x00\x00j\xbb\x05\x00\x00j\xbc\x05\x00\x00j\xbd\x05\x00\x00j\xbe\x05\x00\x00j\xbf\x05\x00\x00j\xc0\x05\x00\x00j\xc1\x05\x00\x00j\xc2\x05\x00\x00j\xc3\x05\x00\x00j\xc4\x05\x00\x00j\xc5\x05\x00\x00j\xc6\x05\x00\x00j\xc7\x05\x00\x00j\xc8\x05\x00\x00j\xc9\x05\x00\x00j\xca\x05\x00\x00j\xcb\x05\x00\x00j\xcc\x05\x00\x00j\xcd\x05\x00\x00j\xce\x05\x00\x00j\xcf\x05\x00\x00j\xd0\x05\x00\x00j\xd1\x05\x00\x00j\xd2\x05\x00\x00j\xd3\x05\x00\x00j\xd4\x05\x00\x00j\xd5\x05\x00\x00j\xd6\x05\x00\x00j\xd7\x05\x00\x00j\xd8\x05\x00\x00j\xd9\x05\x00\x00j\xda\x05\x00\x00j\xdb\x05\x00\x00j\xdc\x05\x00\x00j\xdd\x05\x00\x00j\xde\x05\x00\x00j\xdf\x05\x00\x00j\xe0\x05\x00\x00j\xe1\x05\x00\x00j\xe2\x05\x00\x00j\xe3\x05\x00\x00j\xe4\x05\x00\x00j\xe5\x05\x00\x00j\xe6\x05\x00\x00j\xe7\x05\x00\x00j\xe8\x05\x00\x00j\xe9\x05\x00\x00j\xea\x05\x00\x00j\xeb\x05\x00\x00j\xec\x05\x00\x00j\xed\x05\x00\x00j\xee\x05\x00\x00j\xef\x05\x00\x00j\xf0\x05\x00\x00j\xf1\x05\x00\x00j\xf2\x05\x00\x00j\xf3\x05\x00\x00e}\x94(j5\x08\x00\x00}\x94jY\x08\x00\x00]\x94(j[\x08\x00\x00j\\\x08\x00\x00ej[\x08\x00\x00j_\x08\x00\x00ja\x08\x00\x00\x85\x94R\x94(ja\x08\x00\x00)}\x94je\x08\x00\x00j[\x08\x00\x00sNt\x94bj\\\x08\x00\x00j_\x08\x00\x00ja\x08\x00\x00\x85\x94R\x94(ja\x08\x00\x00)}\x94je\x08\x00\x00j\\\x08\x00\x00sNt\x94bubjI\x08\x00\x00jl\x08\x00\x00)\x81\x94(j\xf4\x05\x00\x00j\xf5\x05\x00\x00j\xf6\x05\x00\x00j\xf7\x05\x00\x00j\xf8\x05\x00\x00j\xf9\x05\x00\x00j\xfa\x05\x00\x00j\xfb\x05\x00\x00j\xfc\x05\x00\x00j\xfd\x05\x00\x00j\xfe\x05\x00\x00j\xff\x05\x00\x00j\x00\x06\x00\x00j\x01\x06\x00\x00j\x02\x06\x00\x00j\x03\x06\x00\x00j\x04\x06\x00\x00j\x05\x06\x00\x00j\x06\x06\x00\x00j\x07\x06\x00\x00j\x08\x06\x00\x00j\t\x06\x00\x00j\n\x06\x00\x00j\x0b\x06\x00\x00j\x0c\x06\x00\x00j\r\x06\x00\x00j\x0e\x06\x00\x00j\x0f\x06\x00\x00j\x10\x06\x00\x00j\x11\x06\x00\x00j\x12\x06\x00\x00j\x13\x06\x00\x00j\x14\x06\x00\x00j\x15\x06\x00\x00j\x16\x06\x00\x00j\x17\x06\x00\x00j\x18\x06\x00\x00j\x19\x06\x00\x00j\x1a\x06\x00\x00j\x1b\x06\x00\x00j\x1c\x06\x00\x00j\x1d\x06\x00\x00j\x1e\x06\x00\x00j\x1f\x06\x00\x00j \x06\x00\x00j!\x06\x00\x00j"\x06\x00\x00j#\x06\x00\x00j$\x06\x00\x00j%\x06\x00\x00j&\x06\x00\x00j\'\x06\x00\x00j(\x06\x00\x00j)\x06\x00\x00j*\x06\x00\x00j+\x06\x00\x00j,\x06\x00\x00j-\x06\x00\x00j.\x06\x00\x00j/\x06\x00\x00j0\x06\x00\x00j1\x06\x00\x00j2\x06\x00\x00j3\x06\x00\x00j4\x06\x00\x00j5\x06\x00\x00j6\x06\x00\x00j7\x06\x00\x00j8\x06\x00\x00j9\x06\x00\x00j:\x06\x00\x00j;\x06\x00\x00e}\x94(j5\x08\x00\x00}\x94jY\x08\x00\x00]\x94(j[\x08\x00\x00j\\\x08\x00\x00ej[\x08\x00\x00j_\x08\x00\x00ja\x08\x00\x00\x85\x94R\x94(ja\x08\x00\x00)}\x94je\x08\x00\x00j[\x08\x00\x00sNt\x94bj\\\x08\x00\x00j_\x08\x00\x00ja\x08\x00\x00\x85\x94R\x94(ja\x08\x00\x00)}\x94je\x08\x00\x00j\\\x08\x00\x00sNt\x94bubjK\x08\x00\x00jl\x08\x00\x00)\x81\x94(j<\x06\x00\x00j=\x06\x00\x00j>\x06\x00\x00j?\x06\x00\x00j@\x06\x00\x00jA\x06\x00\x00jB\x06\x00\x00jC\x06\x00\x00jD\x06\x00\x00jE\x06\x00\x00jF\x06\x00\x00jG\x06\x00\x00jH\x06\x00\x00jI\x06\x00\x00jJ\x06\x00\x00jK\x06\x00\x00jL\x06\x00\x00jM\x06\x00\x00jN\x06\x00\x00jO\x06\x00\x00jP\x06\x00\x00jQ\x06\x00\x00jR\x06\x00\x00jS\x06\x00\x00jT\x06\x00\x00jU\x06\x00\x00jV\x06\x00\x00jW\x06\x00\x00jX\x06\x00\x00jY\x06\x00\x00jZ\x06\x00\x00j[\x06\x00\x00j\\\x06\x00\x00j]\x06\x00\x00j^\x06\x00\x00j_\x06\x00\x00j`\x06\x00\x00ja\x06\x00\x00jb\x06\x00\x00jc\x06\x00\x00jd\x06\x00\x00je\x06\x00\x00jf\x06\x00\x00jg\x06\x00\x00jh\x06\x00\x00ji\x06\x00\x00jj\x06\x00\x00jk\x06\x00\x00jl\x06\x00\x00jm\x06\x00\x00jn\x06\x00\x00jo\x06\x00\x00jp\x06\x00\x00jq\x06\x00\x00jr\x06\x00\x00js\x06\x00\x00jt\x06\x00\x00ju\x06\x00\x00jv\x06\x00\x00jw\x06\x00\x00jx\x06\x00\x00jy\x06\x00\x00jz\x06\x00\x00j{\x06\x00\x00j|\x06\x00\x00j}\x06\x00\x00j~\x06\x00\x00j\x7f\x06\x00\x00j\x80\x06\x00\x00j\x81\x06\x00\x00j\x82\x06\x00\x00j\x83\x06\x00\x00e}\x94(j5\x08\x00\x00}\x94jY\x08\x00\x00]\x94(j[\x08\x00\x00j\\\x08\x00\x00ej[\x08\x00\x00j_\x08\x00\x00ja\x08\x00\x00\x85\x94R\x94(ja\x08\x00\x00)}\x94je\x08\x00\x00j[\x08\x00\x00sNt\x94bj\\\x08\x00\x00j_\x08\x00\x00ja\x08\x00\x00\x85\x94R\x94(ja\x08\x00\x00)}\x94je\x08\x00\x00j\\\x08\x00\x00sNt\x94bubjM\x08\x00\x00jl\x08\x00\x00)\x81\x94(j\x84\x06\x00\x00j\x85\x06\x00\x00j\x86\x06\x00\x00j\x87\x06\x00\x00j\x88\x06\x00\x00j\x89\x06\x00\x00j\x8a\x06\x00\x00j\x8b\x06\x00\x00j\x8c\x06\x00\x00j\x8d\x06\x00\x00j\x8e\x06\x00\x00j\x8f\x06\x00\x00j\x90\x06\x00\x00j\x91\x06\x00\x00j\x92\x06\x00\x00j\x93\x06\x00\x00j\x94\x06\x00\x00j\x95\x06\x00\x00j\x96\x06\x00\x00j\x97\x06\x00\x00j\x98\x06\x00\x00j\x99\x06\x00\x00j\x9a\x06\x00\x00j\x9b\x06\x00\x00j\x9c\x06\x00\x00j\x9d\x06\x00\x00j\x9e\x06\x00\x00j\x9f\x06\x00\x00j\xa0\x06\x00\x00j\xa1\x06\x00\x00j\xa2\x06\x00\x00j\xa3\x06\x00\x00j\xa4\x06\x00\x00j\xa5\x06\x00\x00j\xa6\x06\x00\x00j\xa7\x06\x00\x00j\xa8\x06\x00\x00j\xa9\x06\x00\x00j\xaa\x06\x00\x00j\xab\x06\x00\x00j\xac\x06\x00\x00j\xad\x06\x00\x00j\xae\x06\x00\x00j\xaf\x06\x00\x00j\xb0\x06\x00\x00j\xb1\x06\x00\x00j\xb2\x06\x00\x00j\xb3\x06\x00\x00j\xb4\x06\x00\x00j\xb5\x06\x00\x00j\xb6\x06\x00\x00j\xb7\x06\x00\x00j\xb8\x06\x00\x00j\xb9\x06\x00\x00j\xba\x06\x00\x00j\xbb\x06\x00\x00j\xbc\x06\x00\x00j\xbd\x06\x00\x00j\xbe\x06\x00\x00j\xbf\x06\x00\x00j\xc0\x06\x00\x00j\xc1\x06\x00\x00j\xc2\x06\x00\x00j\xc3\x06\x00\x00j\xc4\x06\x00\x00j\xc5\x06\x00\x00j\xc6\x06\x00\x00j\xc7\x06\x00\x00j\xc8\x06\x00\x00j\xc9\x06\x00\x00j\xca\x06\x00\x00j\xcb\x06\x00\x00e}\x94(j5\x08\x00\x00}\x94jY\x08\x00\x00]\x94(j[\x08\x00\x00j\\\x08\x00\x00ej[\x08\x00\x00j_\x08\x00\x00ja\x08\x00\x00\x85\x94R\x94(ja\x08\x00\x00)}\x94je\x08\x00\x00j[\x08\x00\x00sNt\x94bj\\\x08\x00\x00j_\x08\x00\x00ja\x08\x00\x00\x85\x94R\x94(ja\x08\x00\x00)}\x94je\x08\x00\x00j\\\x08\x00\x00sNt\x94bubjO\x08\x00\x00jl\x08\x00\x00)\x81\x94(j\xcc\x06\x00\x00j\xcd\x06\x00\x00j\xce\x06\x00\x00j\xcf\x06\x00\x00j\xd0\x06\x00\x00j\xd1\x06\x00\x00j\xd2\x06\x00\x00j\xd3\x06\x00\x00j\xd4\x06\x00\x00j\xd5\x06\x00\x00j\xd6\x06\x00\x00j\xd7\x06\x00\x00j\xd8\x06\x00\x00j\xd9\x06\x00\x00j\xda\x06\x00\x00j\xdb\x06\x00\x00j\xdc\x06\x00\x00j\xdd\x06\x00\x00j\xde\x06\x00\x00j\xdf\x06\x00\x00j\xe0\x06\x00\x00j\xe1\x06\x00\x00j\xe2\x06\x00\x00j\xe3\x06\x00\x00j\xe4\x06\x00\x00j\xe5\x06\x00\x00j\xe6\x06\x00\x00j\xe7\x06\x00\x00j\xe8\x06\x00\x00j\xe9\x06\x00\x00j\xea\x06\x00\x00j\xeb\x06\x00\x00j\xec\x06\x00\x00j\xed\x06\x00\x00j\xee\x06\x00\x00j\xef\x06\x00\x00j\xf0\x06\x00\x00j\xf1\x06\x00\x00j\xf2\x06\x00\x00j\xf3\x06\x00\x00j\xf4\x06\x00\x00j\xf5\x06\x00\x00j\xf6\x06\x00\x00j\xf7\x06\x00\x00j\xf8\x06\x00\x00j\xf9\x06\x00\x00j\xfa\x06\x00\x00j\xfb\x06\x00\x00j\xfc\x06\x00\x00j\xfd\x06\x00\x00j\xfe\x06\x00\x00j\xff\x06\x00\x00j\x00\x07\x00\x00j\x01\x07\x00\x00j\x02\x07\x00\x00j\x03\x07\x00\x00j\x04\x07\x00\x00j\x05\x07\x00\x00j\x06\x07\x00\x00j\x07\x07\x00\x00j\x08\x07\x00\x00j\t\x07\x00\x00j\n\x07\x00\x00j\x0b\x07\x00\x00j\x0c\x07\x00\x00j\r\x07\x00\x00j\x0e\x07\x00\x00j\x0f\x07\x00\x00j\x10\x07\x00\x00j\x11\x07\x00\x00j\x12\x07\x00\x00j\x13\x07\x00\x00e}\x94(j5\x08\x00\x00}\x94jY\x08\x00\x00]\x94(j[\x08\x00\x00j\\\x08\x00\x00ej[\x08\x00\x00j_\x08\x00\x00ja\x08\x00\x00\x85\x94R\x94(ja\x08\x00\x00)}\x94je\x08\x00\x00j[\x08\x00\x00sNt\x94bj\\\x08\x00\x00j_\x08\x00\x00ja\x08\x00\x00\x85\x94R\x94(ja\x08\x00\x00)}\x94je\x08\x00\x00j\\\x08\x00\x00sNt\x94bubjQ\x08\x00\x00jl\x08\x00\x00)\x81\x94(j\x14\x07\x00\x00j\x15\x07\x00\x00j\x16\x07\x00\x00j\x17\x07\x00\x00j\x18\x07\x00\x00j\x19\x07\x00\x00j\x1a\x07\x00\x00j\x1b\x07\x00\x00j\x1c\x07\x00\x00j\x1d\x07\x00\x00j\x1e\x07\x00\x00j\x1f\x07\x00\x00j \x07\x00\x00j!\x07\x00\x00j"\x07\x00\x00j#\x07\x00\x00j$\x07\x00\x00j%\x07\x00\x00j&\x07\x00\x00j\'\x07\x00\x00j(\x07\x00\x00j)\x07\x00\x00j*\x07\x00\x00j+\x07\x00\x00j,\x07\x00\x00j-\x07\x00\x00j.\x07\x00\x00j/\x07\x00\x00j0\x07\x00\x00j1\x07\x00\x00j2\x07\x00\x00j3\x07\x00\x00j4\x07\x00\x00j5\x07\x00\x00j6\x07\x00\x00j7\x07\x00\x00j8\x07\x00\x00j9\x07\x00\x00j:\x07\x00\x00j;\x07\x00\x00j<\x07\x00\x00j=\x07\x00\x00j>\x07\x00\x00j?\x07\x00\x00j@\x07\x00\x00jA\x07\x00\x00jB\x07\x00\x00jC\x07\x00\x00jD\x07\x00\x00jE\x07\x00\x00jF\x07\x00\x00jG\x07\x00\x00jH\x07\x00\x00jI\x07\x00\x00jJ\x07\x00\x00jK\x07\x00\x00jL\x07\x00\x00jM\x07\x00\x00jN\x07\x00\x00jO\x07\x00\x00jP\x07\x00\x00jQ\x07\x00\x00jR\x07\x00\x00jS\x07\x00\x00jT\x07\x00\x00jU\x07\x00\x00jV\x07\x00\x00jW\x07\x00\x00jX\x07\x00\x00jY\x07\x00\x00jZ\x07\x00\x00j[\x07\x00\x00e}\x94(j5\x08\x00\x00}\x94jY\x08\x00\x00]\x94(j[\x08\x00\x00j\\\x08\x00\x00ej[\x08\x00\x00j_\x08\x00\x00ja\x08\x00\x00\x85\x94R\x94(ja\x08\x00\x00)}\x94je\x08\x00\x00j[\x08\x00\x00sNt\x94bj\\\x08\x00\x00j_\x08\x00\x00ja\x08\x00\x00\x85\x94R\x94(ja\x08\x00\x00)}\x94je\x08\x00\x00j\\\x08\x00\x00sNt\x94bubjS\x08\x00\x00jl\x08\x00\x00)\x81\x94(j\\\x07\x00\x00j]\x07\x00\x00j^\x07\x00\x00j_\x07\x00\x00j`\x07\x00\x00ja\x07\x00\x00jb\x07\x00\x00jc\x07\x00\x00jd\x07\x00\x00je\x07\x00\x00jf\x07\x00\x00jg\x07\x00\x00jh\x07\x00\x00ji\x07\x00\x00jj\x07\x00\x00jk\x07\x00\x00jl\x07\x00\x00jm\x07\x00\x00jn\x07\x00\x00jo\x07\x00\x00jp\x07\x00\x00jq\x07\x00\x00jr\x07\x00\x00js\x07\x00\x00jt\x07\x00\x00ju\x07\x00\x00jv\x07\x00\x00jw\x07\x00\x00jx\x07\x00\x00jy\x07\x00\x00jz\x07\x00\x00j{\x07\x00\x00j|\x07\x00\x00j}\x07\x00\x00j~\x07\x00\x00j\x7f\x07\x00\x00j\x80\x07\x00\x00j\x81\x07\x00\x00j\x82\x07\x00\x00j\x83\x07\x00\x00j\x84\x07\x00\x00j\x85\x07\x00\x00j\x86\x07\x00\x00j\x87\x07\x00\x00j\x88\x07\x00\x00j\x89\x07\x00\x00j\x8a\x07\x00\x00j\x8b\x07\x00\x00j\x8c\x07\x00\x00j\x8d\x07\x00\x00j\x8e\x07\x00\x00j\x8f\x07\x00\x00j\x90\x07\x00\x00j\x91\x07\x00\x00j\x92\x07\x00\x00j\x93\x07\x00\x00j\x94\x07\x00\x00j\x95\x07\x00\x00j\x96\x07\x00\x00j\x97\x07\x00\x00j\x98\x07\x00\x00j\x99\x07\x00\x00j\x9a\x07\x00\x00j\x9b\x07\x00\x00j\x9c\x07\x00\x00j\x9d\x07\x00\x00j\x9e\x07\x00\x00j\x9f\x07\x00\x00j\xa0\x07\x00\x00j\xa1\x07\x00\x00j\xa2\x07\x00\x00j\xa3\x07\x00\x00e}\x94(j5\x08\x00\x00}\x94jY\x08\x00\x00]\x94(j[\x08\x00\x00j\\\x08\x00\x00ej[\x08\x00\x00j_\x08\x00\x00ja\x08\x00\x00\x85\x94R\x94(ja\x08\x00\x00)}\x94je\x08\x00\x00j[\x08\x00\x00sNt\x94bj\\\x08\x00\x00j_\x08\x00\x00ja\x08\x00\x00\x85\x94R\x94(ja\x08\x00\x00)}\x94je\x08\x00\x00j\\\x08\x00\x00sNt\x94bubjU\x08\x00\x00jl\x08\x00\x00)\x81\x94(j\xa4\x07\x00\x00j\xa5\x07\x00\x00j\xa6\x07\x00\x00j\xa7\x07\x00\x00j\xa8\x07\x00\x00j\xa9\x07\x00\x00j\xaa\x07\x00\x00j\xab\x07\x00\x00j\xac\x07\x00\x00j\xad\x07\x00\x00j\xae\x07\x00\x00j\xaf\x07\x00\x00j\xb0\x07\x00\x00j\xb1\x07\x00\x00j\xb2\x07\x00\x00j\xb3\x07\x00\x00j\xb4\x07\x00\x00j\xb5\x07\x00\x00j\xb6\x07\x00\x00j\xb7\x07\x00\x00j\xb8\x07\x00\x00j\xb9\x07\x00\x00j\xba\x07\x00\x00j\xbb\x07\x00\x00j\xbc\x07\x00\x00j\xbd\x07\x00\x00j\xbe\x07\x00\x00j\xbf\x07\x00\x00j\xc0\x07\x00\x00j\xc1\x07\x00\x00j\xc2\x07\x00\x00j\xc3\x07\x00\x00j\xc4\x07\x00\x00j\xc5\x07\x00\x00j\xc6\x07\x00\x00j\xc7\x07\x00\x00j\xc8\x07\x00\x00j\xc9\x07\x00\x00j\xca\x07\x00\x00j\xcb\x07\x00\x00j\xcc\x07\x00\x00j\xcd\x07\x00\x00j\xce\x07\x00\x00j\xcf\x07\x00\x00j\xd0\x07\x00\x00j\xd1\x07\x00\x00j\xd2\x07\x00\x00j\xd3\x07\x00\x00j\xd4\x07\x00\x00j\xd5\x07\x00\x00j\xd6\x07\x00\x00j\xd7\x07\x00\x00j\xd8\x07\x00\x00j\xd9\x07\x00\x00j\xda\x07\x00\x00j\xdb\x07\x00\x00j\xdc\x07\x00\x00j\xdd\x07\x00\x00j\xde\x07\x00\x00j\xdf\x07\x00\x00j\xe0\x07\x00\x00j\xe1\x07\x00\x00j\xe2\x07\x00\x00j\xe3\x07\x00\x00j\xe4\x07\x00\x00j\xe5\x07\x00\x00j\xe6\x07\x00\x00j\xe7\x07\x00\x00j\xe8\x07\x00\x00j\xe9\x07\x00\x00j\xea\x07\x00\x00j\xeb\x07\x00\x00e}\x94(j5\x08\x00\x00}\x94jY\x08\x00\x00]\x94(j[\x08\x00\x00j\\\x08\x00\x00ej[\x08\x00\x00j_\x08\x00\x00ja\x08\x00\x00\x85\x94R\x94(ja\x08\x00\x00)}\x94je\x08\x00\x00j[\x08\x00\x00sNt\x94bj\\\x08\x00\x00j_\x08\x00\x00ja\x08\x00\x00\x85\x94R\x94(ja\x08\x00\x00)}\x94je\x08\x00\x00j\\\x08\x00\x00sNt\x94bubjW\x08\x00\x00jl\x08\x00\x00)\x81\x94(j\xec\x07\x00\x00j\xed\x07\x00\x00j\xee\x07\x00\x00j\xef\x07\x00\x00j\xf0\x07\x00\x00j\xf1\x07\x00\x00j\xf2\x07\x00\x00j\xf3\x07\x00\x00j\xf4\x07\x00\x00j\xf5\x07\x00\x00j\xf6\x07\x00\x00j\xf7\x07\x00\x00j\xf8\x07\x00\x00j\xf9\x07\x00\x00j\xfa\x07\x00\x00j\xfb\x07\x00\x00j\xfc\x07\x00\x00j\xfd\x07\x00\x00j\xfe\x07\x00\x00j\xff\x07\x00\x00j\x00\x08\x00\x00j\x01\x08\x00\x00j\x02\x08\x00\x00j\x03\x08\x00\x00j\x04\x08\x00\x00j\x05\x08\x00\x00j\x06\x08\x00\x00j\x07\x08\x00\x00j\x08\x08\x00\x00j\t\x08\x00\x00j\n\x08\x00\x00j\x0b\x08\x00\x00j\x0c\x08\x00\x00j\r\x08\x00\x00j\x0e\x08\x00\x00j\x0f\x08\x00\x00j\x10\x08\x00\x00j\x11\x08\x00\x00j\x12\x08\x00\x00j\x13\x08\x00\x00j\x14\x08\x00\x00j\x15\x08\x00\x00j\x16\x08\x00\x00j\x17\x08\x00\x00j\x18\x08\x00\x00j\x19\x08\x00\x00j\x1a\x08\x00\x00j\x1b\x08\x00\x00j\x1c\x08\x00\x00j\x1d\x08\x00\x00j\x1e\x08\x00\x00j\x1f\x08\x00\x00j \x08\x00\x00j!\x08\x00\x00j"\x08\x00\x00j#\x08\x00\x00j$\x08\x00\x00j%\x08\x00\x00j&\x08\x00\x00j\'\x08\x00\x00j(\x08\x00\x00j)\x08\x00\x00j*\x08\x00\x00j+\x08\x00\x00j,\x08\x00\x00j-\x08\x00\x00j.\x08\x00\x00j/\x08\x00\x00j0\x08\x00\x00j1\x08\x00\x00j2\x08\x00\x00j3\x08\x00\x00e}\x94(j5\x08\x00\x00}\x94jY\x08\x00\x00]\x94(j[\x08\x00\x00j\\\x08\x00\x00ej[\x08\x00\x00j_\x08\x00\x00ja\x08\x00\x00\x85\x94R\x94(ja\x08\x00\x00)}\x94je\x08\x00\x00j[\x08\x00\x00sNt\x94bj\\\x08\x00\x00j_\x08\x00\x00ja\x08\x00\x00\x85\x94R\x94(ja\x08\x00\x00)}\x94je\x08\x00\x00j\\\x08\x00\x00sNt\x94bubub\x8c\x06output\x94h\x06\x8c\x0bOutputFiles\x94\x93\x94)\x81\x94(\x8cW/home/lmf/DANIEL/VIRAL_METAGENOMES/FIGURES_AND_TABLES/01_kmer_rarefraction_plot.tot.png\x94\x8cW/home/lmf/DANIEL/VIRAL_METAGENOMES/FIGURES_AND_TABLES/01_kmer_rarefraction_plot.tot.svg\x94\x8c^/home/lmf/DANIEL/VIRAL_METAGENOMES/FIGURES_AND_TABLES/01_kmer_rarefraction_plot_fitted.tot.png\x94\x8c^/home/lmf/DANIEL/VIRAL_METAGENOMES/FIGURES_AND_TABLES/01_kmer_rarefraction_plot_fitted.tot.svg\x94\x8cZ/home/lmf/DANIEL/VIRAL_METAGENOMES/FIGURES_AND_TABLES/01_kmer_rarefraction_fitted.tot.html\x94\x8c[/home/lmf/DANIEL/VIRAL_METAGENOMES/FIGURES_AND_TABLES/01_kmer_distribution_plot_pre.tot.png\x94\x8c[/home/lmf/DANIEL/VIRAL_METAGENOMES/FIGURES_AND_TABLES/01_kmer_distribution_plot_pre.tot.svg\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/FIGURES_AND_TABLES/01_kmer_distribution_plot_post.tot.png\x94\x8c\\/home/lmf/DANIEL/VIRAL_METAGENOMES/FIGURES_AND_TABLES/01_kmer_distribution_plot_post.tot.svg\x94\x8cV/home/lmf/DANIEL/VIRAL_METAGENOMES/FIGURES_AND_TABLES/01_post_qc_read_summary.tot.html\x94\x8cV/home/lmf/DANIEL/VIRAL_METAGENOMES/FIGURES_AND_TABLES/01_percentage_kept_reads.tot.png\x94\x8cV/home/lmf/DANIEL/VIRAL_METAGENOMES/FIGURES_AND_TABLES/01_percentage_kept_reads.tot.svg\x94\x8cT/home/lmf/DANIEL/VIRAL_METAGENOMES/FIGURES_AND_TABLES/01_percentage_kept_Mbp.tot.png\x94\x8cT/home/lmf/DANIEL/VIRAL_METAGENOMES/FIGURES_AND_TABLES/01_percentage_kept_Mbp.tot.svg\x94\x8cU/home/lmf/DANIEL/VIRAL_METAGENOMES/FIGURES_AND_TABLES/01_multistep_qc_report.tot.html\x94\x8cQ/home/lmf/DANIEL/VIRAL_METAGENOMES/FIGURES_AND_TABLES/01_qc_bystep_counts.tot.png\x94\x8cQ/home/lmf/DANIEL/VIRAL_METAGENOMES/FIGURES_AND_TABLES/01_qc_bystep_counts.tot.svg\x94\x8cU/home/lmf/DANIEL/VIRAL_METAGENOMES/FIGURES_AND_TABLES/01_qc_bystep_percentage.tot.png\x94\x8cU/home/lmf/DANIEL/VIRAL_METAGENOMES/FIGURES_AND_TABLES/01_qc_bystep_percentage.tot.svg\x94\x8cV/home/lmf/DANIEL/VIRAL_METAGENOMES/FIGURES_AND_TABLES/01_qc_read_counts_paired.tot.csv\x94\x8cS/home/lmf/DANIEL/VIRAL_METAGENOMES/FIGURES_AND_TABLES/01_superdedupper_PCR.tot.html\x94\x8cR/home/lmf/DANIEL/VIRAL_METAGENOMES/FIGURES_AND_TABLES/01_superdedupper_PCR.tot.png\x94\x8cR/home/lmf/DANIEL/VIRAL_METAGENOMES/FIGURES_AND_TABLES/01_superdedupper_PCR.tot.svg\x94e}\x94(j5\x08\x00\x00}\x94(\x8c\x08kmer_png\x94K\x00N\x86\x94\x8c\x08kmer_svg\x94K\x01N\x86\x94\x8c\x0ckmer_fit_png\x94K\x02N\x86\x94\x8c\x0ckmer_fit_svg\x94K\x03N\x86\x94\x8c\rkmer_fit_html\x94K\x04N\x86\x94\x8c\x11kmer_dist_pre_png\x94K\x05N\x86\x94\x8c\x11kmer_dist_pre_svg\x94K\x06N\x86\x94\x8c\x12kmer_dist_post_png\x94K\x07N\x86\x94\x8c\x12kmer_dist_post_svg\x94K\x08N\x86\x94\x8c\x0fqc_summary_html\x94K\tN\x86\x94\x8c\x19percentage_kept_reads_png\x94K\nN\x86\x94\x8c\x19percentage_kept_reads_svg\x94K\x0bN\x86\x94\x8c\x17percentage_kept_Mbp_png\x94K\x0cN\x86\x94\x8c\x17percentage_kept_Mbp_svg\x94K\rN\x86\x94\x8c\x12step_qc_reads_html\x94K\x0eN\x86\x94\x8c\x12steps_qc_reads_png\x94K\x0fN\x86\x94\x8c\x12steps_qc_reads_svg\x94K\x10N\x86\x94\x8c\x17steps_qc_percentage_png\x94K\x11N\x86\x94\x8c\x17steps_qc_percentage_svg\x94K\x12N\x86\x94\x8c\x10df_counts_paired\x94K\x13N\x86\x94\x8c\x13supperdedupper_html\x94K\x14N\x86\x94\x8c\x12supperdedupper_png\x94K\x15N\x86\x94\x8c\x12supperdedupper_svg\x94K\x16N\x86\x94ujY\x08\x00\x00]\x94(j[\x08\x00\x00j\\\x08\x00\x00ej[\x08\x00\x00j_\x08\x00\x00ja\x08\x00\x00\x85\x94R\x94(ja\x08\x00\x00)}\x94je\x08\x00\x00j[\x08\x00\x00sNt\x94bj\\\x08\x00\x00j_\x08\x00\x00ja\x08\x00\x00\x85\x94R\x94(ja\x08\x00\x00)}\x94je\x08\x00\x00j\\\x08\x00\x00sNt\x94bj>\t\x00\x00j%\t\x00\x00j@\t\x00\x00j&\t\x00\x00jB\t\x00\x00j\'\t\x00\x00jD\t\x00\x00j(\t\x00\x00jF\t\x00\x00j)\t\x00\x00jH\t\x00\x00j*\t\x00\x00jJ\t\x00\x00j+\t\x00\x00jL\t\x00\x00j,\t\x00\x00jN\t\x00\x00j-\t\x00\x00jP\t\x00\x00j.\t\x00\x00jR\t\x00\x00j/\t\x00\x00jT\t\x00\x00j0\t\x00\x00jV\t\x00\x00j1\t\x00\x00jX\t\x00\x00j2\t\x00\x00jZ\t\x00\x00j3\t\x00\x00j\\\t\x00\x00j4\t\x00\x00j^\t\x00\x00j5\t\x00\x00j`\t\x00\x00j6\t\x00\x00jb\t\x00\x00j7\t\x00\x00jd\t\x00\x00j8\t\x00\x00jf\t\x00\x00j9\t\x00\x00jh\t\x00\x00j:\t\x00\x00jj\t\x00\x00j;\t\x00\x00ub\x8c\x06params\x94h\x06\x8c\x06Params\x94\x93\x94)\x81\x94(\x8c"/home/lmf/DANIEL/VIRAL_METAGENOMES\x94\x8c0/home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA\x94]\x94(\x8c\x06B_C1_V\x94\x8c\x06B_C2_V\x94\x8c\x06B_C3_V\x94\x8c\x06B_C4_V\x94\x8c\tB_CIT1B_V\x94\x8c\tB_CIT1F_V\x94\x8c\tB_CIT2B_V\x94\x8c\tB_CIT2F_V\x94\x8c\tB_CIT3B_V\x94\x8c\tB_CIT3F_V\x94\x8c\tB_CIT4B_V\x94\x8c\tB_CIT4F_V\x94\x8c\tB_CNT1B_V\x94\x8c\tB_CNT1F_V\x94\x8c\tB_CNT2B_V\x94\x8c\tB_CNT2F_V\x94\x8c\tB_CNT3B_V\x94\x8c\tB_CNT3F_V\x94\x8c\tB_CNT4B_V\x94\x8c\tB_CNT4F_V\x94\x8c\tB_OIT1B_V\x94\x8c\tB_OIT1F_V\x94\x8c\tB_OIT2B_V\x94\x8c\tB_OIT2F_V\x94\x8c\tB_OIT3B_V\x94\x8c\tB_OIT3F_V\x94\x8c\tB_OIT4B_V\x94\x8c\tB_OIT4F_V\x94\x8c\tB_ORT1B_V\x94\x8c\tB_ORT1F_V\x94\x8c\tB_ORT2B_V\x94\x8c\tB_ORT2F_V\x94\x8c\tB_ORT3B_V\x94\x8c\tB_ORT3F_V\x94\x8c\tB_ORT4B_V\x94\x8c\tB_ORT4F_V\x94\x8c\x07RS_C1_V\x94\x8c\x07RS_C2_V\x94\x8c\x07RS_C3_V\x94\x8c\x07RS_C4_V\x94\x8c\nRS_CIT1B_V\x94\x8c\nRS_CIT1F_V\x94\x8c\nRS_CIT2B_V\x94\x8c\nRS_CIT2F_V\x94\x8c\nRS_CIT3B_V\x94\x8c\nRS_CIT3F_V\x94\x8c\nRS_CIT4B_V\x94\x8c\nRS_CIT4F_V\x94\x8c\nRS_CNT1B_V\x94\x8c\nRS_CNT1F_V\x94\x8c\nRS_CNT2B_V\x94\x8c\nRS_CNT2F_V\x94\x8c\nRS_CNT3B_V\x94\x8c\nRS_CNT3F_V\x94\x8c\nRS_CNT4B_V\x94\x8c\nRS_CNT4F_V\x94\x8c\nRS_OIT1B_V\x94\x8c\nRS_OIT1F_V\x94\x8c\nRS_OIT2B_V\x94\x8c\nRS_OIT2F_V\x94\x8c\nRS_OIT3B_V\x94\x8c\nRS_OIT3F_V\x94\x8c\nRS_OIT4B_V\x94\x8c\nRS_OIT4F_V\x94\x8c\nRS_ORT1B_V\x94\x8c\nRS_ORT1F_V\x94\x8c\nRS_ORT2B_V\x94\x8c\nRS_ORT2F_V\x94\x8c\nRS_ORT3B_V\x94\x8c\nRS_ORT3F_V\x94\x8c\nRS_ORT4B_V\x94\x8c\nRS_ORT4F_V\x94e\x8c\x02R1\x94\x8c\x02R2\x94\x8c./home/lmf/DANIEL/VIRAL_METAGENOMES/00_RAW_DATA\x94\x8c(/home/lmf/DANIEL/VIRAL_METAGENOMES/01_QC\x94e}\x94(j5\x08\x00\x00}\x94(\x8c\x0bresults_dir\x94K\x00N\x86\x94\x8c\tclean_dir\x94K\x01N\x86\x94\x8c\x07samples\x94K\x02N\x86\x94\x8c\x0bforward_tag\x94K\x03N\x86\x94\x8c\x0breverse_tag\x94K\x04N\x86\x94\x8c\x07raw_dir\x94K\x05N\x86\x94\x8c\x06qc_dir\x94K\x06N\x86\x94ujY\x08\x00\x00]\x94(j[\x08\x00\x00j\\\x08\x00\x00ej[\x08\x00\x00j_\x08\x00\x00ja\x08\x00\x00\x85\x94R\x94(ja\x08\x00\x00)}\x94je\x08\x00\x00j[\x08\x00\x00sNt\x94bj\\\x08\x00\x00j_\x08\x00\x00ja\x08\x00\x00\x85\x94R\x94(ja\x08\x00\x00)}\x94je\x08\x00\x00j\\\x08\x00\x00sNt\x94bj\xca\t\x00\x00jy\t\x00\x00j\xcc\t\x00\x00jz\t\x00\x00j\xce\t\x00\x00j{\t\x00\x00j\xd0\t\x00\x00j\xc4\t\x00\x00j\xd2\t\x00\x00j\xc5\t\x00\x00j\xd4\t\x00\x00j\xc6\t\x00\x00j\xd6\t\x00\x00j\xc7\t\x00\x00ub\x8c\twildcards\x94h\x06\x8c\tWildcards\x94\x93\x94)\x81\x94\x8c\x03tot\x94a}\x94(j5\x08\x00\x00}\x94\x8c\x08sampling\x94K\x00N\x86\x94sjY\x08\x00\x00]\x94(j[\x08\x00\x00j\\\x08\x00\x00ej[\x08\x00\x00j_\x08\x00\x00ja\x08\x00\x00\x85\x94R\x94(ja\x08\x00\x00)}\x94je\x08\x00\x00j[\x08\x00\x00sNt\x94bj\\\x08\x00\x00j_\x08\x00\x00ja\x08\x00\x00\x85\x94R\x94(ja\x08\x00\x00)}\x94je\x08\x00\x00j\\\x08\x00\x00sNt\x94b\x8c\x08sampling\x94j\xe5\t\x00\x00ub\x8c\x07threads\x94K\x01\x8c\tresources\x94h\x06\x8c\tResources\x94\x93\x94)\x81\x94(K\x01K\x01\x8c\x04/tmp\x94e}\x94(j5\x08\x00\x00}\x94(\x8c\x06_cores\x94K\x00N\x86\x94\x8c\x06_nodes\x94K\x01N\x86\x94\x8c\x06tmpdir\x94K\x02N\x86\x94ujY\x08\x00\x00]\x94(j[\x08\x00\x00j\\\x08\x00\x00ej[\x08\x00\x00j_\x08\x00\x00ja\x08\x00\x00\x85\x94R\x94(ja\x08\x00\x00)}\x94je\x08\x00\x00j[\x08\x00\x00sNt\x94bj\\\x08\x00\x00j_\x08\x00\x00ja\x08\x00\x00\x85\x94R\x94(ja\x08\x00\x00)}\x94je\x08\x00\x00j\\\x08\x00\x00sNt\x94bj\xfc\t\x00\x00K\x01j\xfe\t\x00\x00K\x01j\x00\n\x00\x00j\xf9\t\x00\x00ub\x8c\x03log\x94h\x06\x8c\x03Log\x94\x93\x94)\x81\x94\x8c</home/lmf/DANIEL/VIRAL_METAGENOMES/NOTEBOOKS/01_QC.tot.ipynb\x94a}\x94(j5\x08\x00\x00}\x94\x8c\x08notebook\x94K\x00N\x86\x94sjY\x08\x00\x00]\x94(j[\x08\x00\x00j\\\x08\x00\x00ej[\x08\x00\x00j_\x08\x00\x00ja\x08\x00\x00\x85\x94R\x94(ja\x08\x00\x00)}\x94je\x08\x00\x00j[\x08\x00\x00sNt\x94bj\\\x08\x00\x00j_\x08\x00\x00ja\x08\x00\x00\x85\x94R\x94(ja\x08\x00\x00)}\x94je\x08\x00\x00j\\\x08\x00\x00sNt\x94bj\x12\n\x00\x00j\x0f\n\x00\x00ub\x8c\x06config\x94}\x94(\x8c\tinput_dir\x94j\xc6\t\x00\x00\x8c\tkraken_db\x94\x8c\x1b/home/lmf/db/KRAKEN/kraken/\x94\x8c\rkrakenUniq_db\x94\x8c\x1e/home/lmf/db/KRAKEN/KrakenUniq\x94\x8c\necc_memory\x94M\x80>\x8c\x1cadditional_reference_contigs\x94\x8cE/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/reference_phages.fasta\x94\x8c\x0eassembly_stats\x94\x88\x8c\x0bsubsampling\x94\x88\x8c\x0fmin_votu_length\x94M\x10\'\x8c\x0crun_vcontact\x94\x88\x8c\x0bimgvr_blast\x94\x88\x8c\x08run_DRAM\x94\x88\x8c\x0bresults_dir\x94\x8c\x00\x94\x8c\nmetagenome\x94\x88\x8c\tmicrobial\x94\x89\x8c\x08sourmash\x94\x89\x8c\x0bkey_samples\x94\x8c\x14key_samples_list.csv\x94\x8c\x10operating_system\x94\x8c\x05linux\x94\x8c\x0bforward_tag\x94j\xc4\t\x00\x00\x8c\x0breverse_tag\x94j\xc5\t\x00\x00\x8c\x0cnanopore_tag\x94\x8c\x08nanopore\x94\x8c\x0fnanopore_pooled\x94\x89\x8c\x14nanopore_pooled_name\x94\x8c\x03raw\x94\x8c\x0elong_assembler\x94\x8c\x04canu\x94\x8c\x0bgenome_size\x94\x8c\x0320m\x94\x8c\x13trimmomatic_leading\x94\x8c\x0220\x94\x8c\x14trimmomatic_trailing\x94\x8c\x0220\x94\x8c\x17trimmomatic_window_size\x94\x8c\x014\x94\x8c\x1atrimmomatic_window_quality\x94\x8c\x0220\x94\x8c\x12trimmomatic_minlen\x94\x8c\x0250\x94\x8c\x10nanopore_quality\x94\x8c\x0210\x94\x8c\x0fnanopore_minlen\x94M\xe8\x03\x8c\x0fnanopore_maxlen\x94J\x80\x96\x98\x00\x8c\x0bsubassembly\x94\x89\x8c\tVirSorter\x94\x89\x8c\x0ecross_assembly\x94\x89\x8c\nlong_index\x94\x89\x8c\x16representative_contigs\x94j.\n\x00\x00\x8c\x08sra_list\x94j.\n\x00\x00\x8c\x07p_ident\x94\x8c\x0295\x94\x8c\x0bkmer_window\x94\x8c\x0525000\x94\x8c\x08min_norm\x94\x8c\x010\x94\x8c\x08max_norm\x94\x8c\x03100\x94\x8c\rmax_subsample\x94\x8c\x0850000000\x94\x8c\x07min_len\x94\x8c\x041000\x94\x8c\x07min_cov\x94\x8c\x012\x94\x8c\x11contaminants_list\x94j.\n\x00\x00\x8c\radapters_file\x94\x8c\x0badapters.fa\x94\x8c\x11ambiguous_mapping\x94\x8c\x03all\x94\x8c\x0ebasecalled_dir\x94\x8c\x10data/basecalled/\x94\x8c\x11microbial_spacers\x94j.\n\x00\x00\x8c\x13reference_databases\x94\x8c\x1eIMGVR GenBankViral RefSeqViral\x94\x8c\x08IMGVR_db\x94\x8c!/home/lmf/db/IMG_VR_2022-12-19_7/\x94\x8c\x0eRefSeqViral_db\x94\x8c6/home/lmf/db/RefSeqViral/RefSeq_viral_2024_09_03.fasta\x94\x8c\x0bpharokka_db\x94N\x8c\x08blast_db\x94\x8c\x1fdb/ncbi/NCBI_viral_proteins.faa\x94\x8c\x0cvirSorter_db\x94\x8c\x1bdb/VirSorter/virsorter-data\x94\x8c\x0ckraken_db_nt\x94\x8c\x17/home/lmf/db/KRAKEN/nt/\x94\x8c\x0fkraken_db_human\x94\x8c\x13db/kraken2_human_db\x94\x8c\x0ckraken_tools\x94\x8c\x11tools/KrakenTools\x94\x8c\x0bbracken_dir\x94\x8c\rtools/Bracken\x94\x8c\nweesam_dir\x94\x8c\x0ctools/weeSAM\x94\x8c\tcheckv_db\x94\x8c\x11db/checkv-db-v1.5\x94\x8c\tcheckm_db\x94\x8c\x0cdb/checkm-db\x94\x8c\x08iphop_db\x94\x8c\x0bdb/iphop_db\x94\x8c\rtaxmyphage_db\x94\x8c\x10db/taxmyphage_db\x94\x8c\x0csourmash_sig\x94\x8c7/home/lmf/db/SOURMASH/matrix_09_42_sourmash_k31.sig.zip\x94\x8c\x10sourmash_rocksdb\x94\x8c;/home/lmf/db/SOURMASH/matrix_09_42_sourmash_k31.sig.rocksdb\x94\x8c\x0csourmash_tax\x94\x8c9/home/lmf/db/SOURMASH/taxonomy/taxonomy_matrix_strain.csv\x94\x8c\x08canu_dir\x94\x8c\x1etools/canu-2.0/Linux-amd64/bin\x94\x8c\x12PhaGCN_newICTV_dir\x94\x8c\x14tools/PhaGCN_newICTV\x94\x8c\tquast_dir\x94\x8c\x11tools/quast-5.0.2\x94\x8c\rvirSorter_dir\x94\x8c\x0ftools/VirSorter\x94\x8c\x07WTP_dir\x94\x8c\ttools/WTP\x94\x8c\rvirFinder_dir\x94\x8c\x0ftools/VirFinder\x94\x8c\x0eclusterONE_dir\x94\x8c\x10tools/clusterONE\x94\x8c\x0cvcontact_dir\x94\x8c\x0ftools/vcontact2\x94\x8c\x1areference_genomes_vcontact\x94\x8c\x04None\x94\x8c\rtaxonomy_file\x94\x8c1db/vcontact2/formatting_taxonomy_affiliations.csv\x94\x8c\ngenomad_db\x94\x8c\rdb/genomad_db\x94\x8c\x07DRAM_db\x94\x8c\ndb/DRAM_db\x94\x8c\tgtdbtk_db\x94\x8c\ndb/GTDB-Tk\x94\x8c\nmmseqs_dir\x94\x8c\rtools/MMseqs2\x94\x8c\x08viga_dir\x94\x8c\ntools/viga\x94\x8c\tpiler_dir\x94\x8c\x11tools/pilercr1.06\x94\x8c\x07trf_dir\x94\x8c\ttools/TRF\x94\x8c\x0bvibrant_dir\x94\x8c\rtools/VIBRANT\x94\x8c\x0eviridic_folder\x94\x8c\x17tools/viridic_v1.0_r3.6\x94\x8c\x0fsra_toolkit_dir\x94\x8c tools/sratoolkit.2.10.0-ubuntu64\x94\x8c\x07ALE_dir\x94\x8c\ttools/ALE\x94\x8c\x08wish_dir\x94\x8c\ntools/WIsH\x94\x8c\nminced_dir\x94\x8c\x0ctools/minced\x94\x8c\x07dion_db\x94\x8c\x0cdb/dionSetDB\x94u\x8c\x04rule\x94\x8c\nQC_parsing\x94\x8c\x0fbench_iteration\x94N\x8c\tscriptdir\x94\x8c//home/lmf/apps/MOSAIC/mosaic/rules/../notebooks\x94ub.'); from snakemake.logging import logger; logger.printshellcmds = True; import os; os.chdir(r'/home/lmf/apps/MOSAIC/mosaic');
######## snakemake preamble end #########

# %% [markdown]
# # Quality Control

# %%
# import necessary modules
import pandas as pd
import seaborn as sns; sns.set()
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
from matplotlib.colors import LinearSegmentedColormap
from scipy.optimize import curve_fit
import json
import numpy as np

#------------------------------------------
# Create a list of colors
colors_rarefaction=sns.color_palette("colorblind", n_colors=len(list(snakemake.params.samples))+1)
# Create a LinearSegmentedColormap object
cmap1=LinearSegmentedColormap.from_list("my_colormap", sns.color_palette("colorblind", n_colors=5))


sns.set_style("ticks",{'axes.grid' : True})
sns.set_palette("colorblind")

plt.rcParams["axes.linewidth"] = 1.5
plt.rcParams["xtick.major.width"] = 1.5
plt.rcParams["ytick.major.width"] = 1.5
plt.rcParams["xtick.major.size"] = 8
plt.rcParams["ytick.major.size"] = 8
plt.rcParams["axes.titlepad"] = 20

plt.rcParams['svg.fonttype'] = 'none'
plt.rcParams["axes.titlesize"] = 30
plt.rcParams['axes.labelsize'] = 23.5
plt.rcParams['xtick.labelsize'] = 18
plt.rcParams['ytick.labelsize'] = 18
plt.rcParams['legend.fontsize'] = 18
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = ['Liberation Sans']
plt.rcParams['text.usetex'] = False

plt.rcParams['svg.fonttype'] = 'none'
plt.rcParams["savefig.dpi"]=300

# %%
clean_dir=snakemake.params.clean_dir
raw_dir=snakemake.params.raw_dir
qc_dir=snakemake.params.qc_dir

SAMPLE_PLOT_LIM_LEGEND=100
SAMPLE_PLOT_LIM=200

SAMPLES=list(snakemake.params.samples)
forward_tag="_" + str(snakemake.params.forward_tag)
reverse_tag="_" +str( snakemake.params.reverse_tag)

input_histograms=list(snakemake.input.histograms)
input_histograms_pre=list(snakemake.input.histogram_kmer_pre)
input_histograms_post=list(snakemake.input.histogram_kmer_post)
# input_peak_kmer=list(snakemake.input.peak_kmer)

input_histograms.sort()
input_histograms_pre.sort()
input_histograms_post.sort()


if len(input_histograms)>SAMPLE_PLOT_LIM:
   input_histograms=input_histograms[:SAMPLE_PLOT_LIM]

if len(input_histograms_pre)>SAMPLE_PLOT_LIM:
   input_histograms_pre=input_histograms_pre[:SAMPLE_PLOT_LIM]

if len(input_histograms_post)>SAMPLE_PLOT_LIM:
   input_histograms_post=input_histograms_post[:SAMPLE_PLOT_LIM]

illumina_preqc=snakemake.input.preqc_txt
illumina_postqc=snakemake.input.postqc_txt
#------------------------------------------
output_kmer_png=snakemake.output.kmer_png
output_kmer_svg=snakemake.output.kmer_svg
output_kmer_png_fitted=snakemake.output.kmer_fit_png
output_kmer_svg_fitted=snakemake.output.kmer_fit_svg
output_kmer_fit_html=snakemake.output.kmer_fit_html
output_kmer_dist_pre_png=snakemake.output.kmer_dist_pre_png
output_kmer_dist_pre_svg=snakemake.output.kmer_dist_pre_svg
output_kmer_dist_post_png=snakemake.output.kmer_dist_post_png
output_kmer_dist_post_svg=snakemake.output.kmer_dist_post_svg

output_qc_summary_html=snakemake.output.qc_summary_html
output_percentage_kept_reads_png=snakemake.output.percentage_kept_reads_png
output_percentage_kept_reads_svg=snakemake.output.percentage_kept_reads_svg
output_percentage_kept_Mbp_png=snakemake.output.percentage_kept_Mbp_png
output_percentage_kept_Mbp_svg=snakemake.output.percentage_kept_Mbp_svg
output_step_qc_reads_html=snakemake.output.step_qc_reads_html
output_steps_qc_reads_png=snakemake.output.steps_qc_reads_png
output_steps_qc_reads_svg=snakemake.output.steps_qc_reads_svg
output_steps_qc_percentage_png=snakemake.output.steps_qc_percentage_png
output_steps_qc_percentage_svg=snakemake.output.steps_qc_percentage_svg
output_df_counts_paired=snakemake.output.df_counts_paired
output_supperdedupper_html=snakemake.output.supperdedupper_html
output_supperdedupper_png=snakemake.output.supperdedupper_png
output_supperdedupper_svg=snakemake.output.supperdedupper_svg

# %% [markdown]
# ## KMER rarefraction

# %%
# set figure size and font scale for seaborn
plt.figure(figsize=(12, 12))

# Sort input_histograms and SAMPLES
input_histograms.sort()
SAMPLES.sort()

# Initialize variables
n = 1
read_max = 0

# Create a single plot
fig, ax = plt.subplots()

# Loop through each histogram in input_histograms
for h in input_histograms:
    # Read the histogram file as a pandas dataframe
    df = pd.read_csv(h, sep="\t", usecols=["#count", "first"])
    df.columns=["counts", "percent"]
    
    # Convert percent to percentage of missing kmers and counts to millions of reads
    df["percent"] = 100 - df["percent"]
    df["counts"] = df["counts"] / 1000000
    print(h)
    # Plot the data as a line plot
    sns.lineplot(x="counts", y="percent", data=df, err_style='band', color=colors_rarefaction[n], 
                 label=h.split("/")[-1].split("_kmer")[0], linewidth=0.5, ax=ax)

    # Add a vertical line at the x-value corresponding to the maximum count
    max_count = df["counts"].max()
    plt.axvline(max_count, 0, 1, linestyle="--", color=colors_rarefaction[n], alpha=0.3)
    read_max = max(read_max, max_count)

    # Increment n
    print(f"{100*n/len(input_histograms):.2f}" + " %", end='\r', flush=True)
    n += 1

# Set y- and x-axis limits, labels, and legend outside the loop
ax.set(ylim=(0, 110))
ax.set(xlim=(0, read_max * 1.2))
ax.set_xlabel("Read count (Million reads)")
ax.set_ylabel("Known k-mers (%)")
if len(SAMPLES) <= SAMPLE_PLOT_LIM_LEGEND:
    ax.legend(loc='center left', bbox_to_anchor=(1, 0.5), ncol=int(np.ceil(len(SAMPLES) / 25)))
else:
    ax.get_legend().set_visible(False)
    
# Save the figure as png and svg files
fig.savefig(output_kmer_png, format="png", bbox_inches="tight", transparent=True)
fig.savefig(output_kmer_svg, format="svg", bbox_inches="tight", transparent=True)

# Show the plot
plt.show()
# Out:
# /home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_C1_V_kmer_histogram.tot.csv
# /home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_C2_V_kmer_histogram.tot.csv
# /home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_C3_V_kmer_histogram.tot.csv
# /home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_C4_V_kmer_histogram.tot.csv
# 5.56 %
# /home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT1B_V_kmer_histogram.tot.csv
# /home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT1F_V_kmer_histogram.tot.csv
# /home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT2B_V_kmer_histogram.tot.csv
# /home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT2F_V_kmer_histogram.tot.csv
# /home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT3B_V_kmer_histogram.tot.csv
# /home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT3F_V_kmer_histogram.tot.csv
# /home/lmf/DANIEL/VIRAL_METAGENOMES/02_CLEAN_DATA/B_CIT4B_V_kmer_histogram.tot.csv
# ...

# %% [markdown]
# # KMER rarefraction log fit

# %%
# Set figure size and font scale for seaborn
plt.figure(figsize=(12, 12))

# Define the number of million reads to trim
cut_million_reads = 5
trim_reads = int(cut_million_reads * 40)
max_read_fitting = 80

# Initialize variables
read_max = 0
n = 1
samples = []
a_list = []
b_list = []
max_reads = []
slope_list = []
percent= []

# Define the logarithmic function used for fitting
def logFunc(x, a, b):
    return a + b * np.log(x)

# Create a single plot
fig, ax = plt.subplots()

# Loop through input histograms
for h in input_histograms:
    # Load the data from the current input histogram
    df = pd.read_csv(h, sep="\t", usecols=["#count", "first"])
    df.columns=["counts", "percent"]
    
    # Calculate the percentage of known k-mers and convert the counts to millions of reads
    df["percent"] = 100 - df["percent"]
    df["counts"] = df["counts"] / 1000000

    # Plot the original data
    sns.lineplot(x="counts", y="percent", data=df, err_style='band', color=colors_rarefaction[n], 
                 label=h.split("/")[-1].split("_kmer")[0], linewidth=0.5, alpha=0.8, ax=ax)

    # Keep track of the maximum read count
    read_max = max(read_max, df["counts"].max())

    # If there are enough data points, fit a logarithmic function to the tail of the data
    if len(df["counts"]) > trim_reads + 1:
        # Subsample pandas dataframe every half million reads
        subsample_rate_mreads = 0.1
        subsample_size = int(subsample_rate_mreads * 40)
        df_subsampled = df[trim_reads:].iloc[::subsample_size, :]
        if len(df_subsampled) > 10:
            # Fit the function to the tail of the data
            popt, _ = curve_fit(logFunc, df_subsampled["counts"], df_subsampled["percent"])

            # Plot the fitted function
            sns.lineplot(x=np.arange(cut_million_reads, max_read_fitting, 0.25), 
                         y=logFunc(np.arange(cut_million_reads, max_read_fitting, 0.25), *popt), 
                         color=colors_rarefaction[n], err_style='band', linewidth=2, alpha=0.2, 
                         label='_nolegend_', ax=ax)

            # Store the fitting parameters and other statistics
            samples.append(h.split("/")[-1].split("_kmer")[0])
            a_list.append(popt[0])
            b_list.append(popt[1])
            max_reads.append(df["counts"].max())
            reads_to_1 = (popt[0] / popt[1])
            slope_list.append(popt[1] / df["counts"].max())
            percent.append(df["percent"].max())

    # Add a vertical line to indicate the maximum read count
    plt.axvline(df["counts"].max(), 0, 1, linestyle="--", color=colors_rarefaction[n], alpha=0.4)

    # Increment the sample counter
    print(f"{100*n/len(input_histograms):.2f}" + " %", end='\r', flush=True)
    n += 1

# Set y- and x-axis limits, labels, and legend outside the loop
ax.set(ylim=(0, 110))
ax.set(xlim=(0, read_max * 1.5))
ax.set_xlabel("Read count (Million reads)")
ax.set_ylabel("Known k-mers (%)")
if len(SAMPLES) <= SAMPLE_PLOT_LIM_LEGEND:
    ax.legend(loc='center left', bbox_to_anchor=(1, 0.5), ncol=int(np.ceil(len(SAMPLES) / 25)))
else:
    ax.get_legend().set_visible(False)
    
# Save the figure as png and svg files
fig.savefig(output_kmer_png_fitted, format="png", bbox_inches="tight", transparent=True)
fig.savefig(output_kmer_svg_fitted, format="svg", bbox_inches="tight", transparent=True)

# Display the plot
plt.show()
# Out:
# 100.00 %

# %%
# create a new empty pandas DataFrame
stats_df=pd.DataFrame()

# add columns to the DataFrame using lists
stats_df["Sample"]=samples
stats_df["a"]=a_list
stats_df["b"]=b_list
stats_df["slope"]=slope_list
stats_df["M_reads"]=max_reads
stats_df["b_-_Mreads"]=stats_df["b"]-stats_df["M_reads"]
stats_df["percent"]=percent

# sort the DataFrame by "Sample" column, apply background color gradient to it, and render it as an HTML table
stats_df_out=stats_df.sort_values(by="Sample").style.background_gradient(cmap="RdYlGn").render()

# write the HTML table to a file
with open(output_kmer_fit_html,"w") as fp:
    fp.write(stats_df_out)

# sort the DataFrame by "Sample" column and apply background color gradient to it
stats_df.sort_values(by="Sample").style.background_gradient(cmap="RdYlGn")
# Out:
# <style  type="text/css" >
# #T_728c6ebc_ef86_11ef_98b5_b88303891ffcrow0_col1,#T_728c6ebc_ef86_11ef_98b5_b88303891ffcrow58_col1{
#             background-color:  #51b35e;
#             color:  #000000;
#         }#T_728c6ebc_ef86_11ef_98b5_b88303891ffcrow0_col2,#T_728c6ebc_ef86_11ef_98b5_b88303891ffcrow34_col2{
#             background-color:  #e65036;
#             color:  #000000;
#         }#T_728c6ebc_ef86_11ef_98b5_b88303891ffcrow0_col3,#T_728c6ebc_ef86_11ef_98b5_b88303891ffcrow21_col3,#T_728c6ebc_ef86_11ef_98b5_b88303891ffcrow25_col3,#T_728c6ebc_ef86_11ef_98b5_b88303891ffcrow34_col3{
#             background-color:  #feca79;
#             color:  #000000;
#         }#T_728c6ebc_ef86_11ef_98b5_b88303891ffcrow0_col4{
#             background-color:  #fdbd6d;
#             color:  #000000;
#         }#T_728c6ebc_ef86_11ef_98b5_b88303891ffcrow0_col5,#T_728c6ebc_ef86_11ef_98b5_b88303891ffcrow8_col1,#T_728c6ebc_ef86_11ef_98b5_b88303891ffcrow11_col5{
# ...

# %% [markdown]
# # Kmer count histogram (kmer size=31)

# %% [markdown]
# ## Pre normalization

# %%
# set figure size and font scale for seaborn
plt.figure(figsize=(12,12))

# Sort input_histograms and print the sorted list
input_histograms_pre.sort()

# Sort SAMPLES
SAMPLES.sort()

# Initialize n and read_max as 0
n=1

# Loop through each histogram in input_histograms
for h in input_histograms_pre:
    # Read the histogram file as a pandas dataframe
    df=pd.read_csv(h, sep="\t")
    
    # Rename columns 
    df.columns=["Depth", "Raw count", "Unique kmers"]

     # Plot the data as a line plot
    ax = sns.lineplot(x="Depth", y="Raw count", data=df[:],err_style='band',color=colors_rarefaction[n], label=h.split("/")[-1].split("_kmer")[0], linewidth=1)

    # Set y- and x-axis scale
    ax.set_xscale('log')
    ax.set_yscale('log')
    
    # Increment the sample counter
    print(f"{100*n/len(input_histograms):.2f}" + " %", end='\r', flush=True)
    n = n+1

# Set x- and y-axis labels and legend
ax.set_xlabel("Depth (31mer)")
ax.set_ylabel("Raw Count")
if len(SAMPLES) <= SAMPLE_PLOT_LIM_LEGEND:
    ax.legend(loc='center left', bbox_to_anchor=(1, 0.5), ncol=int(np.ceil(len(SAMPLES) / 25)))
else:
    ax.get_legend().set_visible(False)
# Save the figure as png and svg files
ax.figure.savefig(output_kmer_dist_pre_png, format="png", bbox_inches = "tight",transparent=True)
ax.figure.savefig(output_kmer_dist_pre_svg, format="svg", bbox_inches = "tight",transparent=True)

# Show the plot
plt.show()
# Out:
# 100.00 %

# %% [markdown]
# ## Post normalization (target=100x)

# %%
# set figure size and font scale for seaborn
plt.figure(figsize=(12,12))

# Sort input_histograms and print the sorted list
input_histograms_post.sort()

# Sort SAMPLES
SAMPLES.sort()

# Initialize n and read_max as 0
n=1

# Loop through each histogram in input_histograms
for h in input_histograms_post:
    # Read the histogram file as a pandas dataframe
    df=pd.read_csv(h, sep="\t")
    
    # Rename columns 
    df.columns=["Depth", "Raw count", "Unique kmers"]

     # Plot the data as a line plot
    ax = sns.lineplot(x="Depth", y="Raw count", data=df[:],err_style='band',color=colors_rarefaction[n], label=h.split("/")[-1].split("_kmer")[0], linewidth=1)

    # Set y- and x-axis scale
    ax.set_xscale('log')
    ax.set_yscale('log')
    
    # Increment the sample counter
    n = n+1

# Set x- and y-axis labels and legend
ax.set_xlabel("Depth (31mer)")
ax.set_ylabel("Raw Count")
if len(SAMPLES) <= SAMPLE_PLOT_LIM_LEGEND:
    ax.legend(loc='center left', bbox_to_anchor=(1, 0.5), ncol=int(np.ceil(len(SAMPLES) / 25)))
else:
    ax.get_legend().set_visible(False)
    
# Save the figure as png and svg files
ax.figure.savefig(output_kmer_dist_post_png, format="png", bbox_inches = "tight",transparent=True)
ax.figure.savefig(output_kmer_dist_post_svg, format="svg", bbox_inches = "tight",transparent=True)

# Show the plot
plt.show()

# %% [markdown]
# ## PreQC and PostQC FASTQC statistics

# %%
# load the pre- and post-illumina sequencing quality control data into pandas dataframes
preqc = pd.read_csv(illumina_preqc, sep="\t")
postqc = pd.read_csv(illumina_postqc, sep="\t")

# create a new dataframe with columns for Filename, average sequence length, and total sequences from the preqc dataframe
read_stats_df1 = preqc[["Filename","avg_sequence_length", "Total Sequences"]]

# calculate the total number of megabases for each file and add this as a new column to read_stats_df1
read_stats_df1["Mbp"] = read_stats_df1["avg_sequence_length"] * read_stats_df1["Total Sequences"] / 1000000

# remove the ".fastq" extension from the Filename column
read_stats_df1["Filename"] = read_stats_df1["Filename"].str.split(".fastq").str[0]

# rename the columns of read_stats_df1
read_stats_df1.columns = ["file_pre","length_pre", "number_pre", "Mbp_pre"]

# set the Filename column as the index of read_stats_df1
read_stats_df1 = read_stats_df1.set_index('file_pre')

# remove any whitespace from the index values of read_stats_df1
read_stats_df1.index = read_stats_df1.index.map("".join)

# create a new dataframe with columns for Filename, average sequence length, and total sequences from the postqc dataframe
read_stats_df2 = postqc[["Filename","avg_sequence_length", "Total Sequences"]]

# calculate the total number of megabases for each file and add this as a new column to read_stats_df2
read_stats_df2["Mbp"] = read_stats_df2["avg_sequence_length"] * read_stats_df2["Total Sequences"] / 1000000

# replace certain portions of the Filename column with standard suffixes (e.g. _forward -> _R1)
read_stats_df2["Filename"] = read_stats_df2["Filename"].str.replace("_forward", forward_tag)
read_stats_df2["Filename"] = read_stats_df2["Filename"].str.replace("_reverse", reverse_tag)
read_stats_df2["Filename"] = read_stats_df2["Filename"].str.replace("_unpaired", "_U")
read_stats_df2["Filename"] = read_stats_df2["Filename"].str.split("_paired").str[0]
read_stats_df2["Filename"] = read_stats_df2["Filename"].str.split("_clean").str[0]

# create a new column in read_stats_df2 for the sample name, based on the first part of the Filename (before the final underscore)
read_stats_df2["Sample"] = read_stats_df2["Filename"].str.rsplit("_",1).str[0]

# set the Filename column as the index of read_stats_df2
read_stats_df2 = read_stats_df2.set_index('Filename')

# rename the columns of read_stats_df2
read_stats_df2.columns=["length_post", "number_post", "Mbp_post", "sample"]

# merge read_stats_df1 and read_stats_df2 on their indices (i.e. Filename), keeping all rows from both dataframes
read_stats_df3 = read_stats_df1.merge(read_stats_df2, left_index=True, right_index=True, how="outer")

# replace any NaN (missing) values in read_stats_df3 with 0
read_stats_df3 = read_stats_df3.fillna(0)

# return the final merged dataframe
read_stats_df3
# Out:
# /tmp/ipykernel_102155/3596653270.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   read_stats_df1["Mbp"] = read_stats_df1["avg_sequence_length"] * read_stats_df1["Total Sequences"] / 1000000
# /tmp/ipykernel_102155/3596653270.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   read_stats_df1["Filename"] = read_stats_df1["Filename"].str.split(".fastq").str[0]
# /tmp/ipykernel_102155/3596653270.py:27: SettingWithCopyWarning:
# ...

# %%
# Pre quality control fastQC statistics
preqc
# Out:
#             Sample                Filename                File type  \
# 0        B_C1_V_R1      B_C1_V_R1.fastq.gz  Conventional base calls
# 1        B_C1_V_R2      B_C1_V_R2.fastq.gz  Conventional base calls
# 2        B_C2_V_R1      B_C2_V_R1.fastq.gz  Conventional base calls
# 3        B_C2_V_R2      B_C2_V_R2.fastq.gz  Conventional base calls
# 4        B_C3_V_R1      B_C3_V_R1.fastq.gz  Conventional base calls
# ..             ...                     ...                      ...
# 139  RS_ORT3F_V_R2  RS_ORT3F_V_R2.fastq.gz  Conventional base calls
# 140  RS_ORT4B_V_R1  RS_ORT4B_V_R1.fastq.gz  Conventional base calls
# 141  RS_ORT4B_V_R2  RS_ORT4B_V_R2.fastq.gz  Conventional base calls
# 142  RS_ORT4F_V_R1  RS_ORT4F_V_R1.fastq.gz  Conventional base calls
# 143  RS_ORT4F_V_R2  RS_ORT4F_V_R2.fastq.gz  Conventional base calls
#
#                   Encoding  Total Sequences  \
# 0    Sanger / Illumina 1.9       34153962.0
# 1    Sanger / Illumina 1.9       34153962.0
# ...

# %%
# Post quality control fastQC statistics
postqc
# Out:
#                                   Sample  \
# 0        B_C1_V_forward_paired_clean.tot
# 1        B_C1_V_reverse_paired_clean.tot
# 2              B_C1_V_unpaired_clean.tot
# 3        B_C2_V_forward_paired_clean.tot
# 4        B_C2_V_reverse_paired_clean.tot
# ..                                   ...
# 211  RS_ORT4B_V_reverse_paired_clean.tot
# 212        RS_ORT4B_V_unpaired_clean.tot
# 213  RS_ORT4F_V_forward_paired_clean.tot
# 214  RS_ORT4F_V_reverse_paired_clean.tot
# 215        RS_ORT4F_V_unpaired_clean.tot
#
#                                          Filename                File type  \
# 0        B_C1_V_forward_paired_clean.tot.fastq.gz  Conventional base calls
# 1        B_C1_V_reverse_paired_clean.tot.fastq.gz  Conventional base calls
# 2              B_C1_V_unpaired_clean.tot.fastq.gz  Conventional base calls
# 3        B_C2_V_forward_paired_clean.tot.fastq.gz  Conventional base calls
# 4        B_C2_V_reverse_paired_clean.tot.fastq.gz  Conventional base calls
# ...

# %%
# Group read statistics by sample
read_stats_df = read_stats_df3.groupby(["sample"]).sum()

# Calculate percentage of reads and Mbp kept
read_stats_df["%number_kept"] = (read_stats_df["number_post"] / read_stats_df["number_pre"] * 100).round(2)
read_stats_df["%Mbp_kept"] = (read_stats_df["Mbp_post"] / read_stats_df["Mbp_pre"] * 100).round(2)

# Calculate percentage of reads and Mbp removed
read_stats_df["%Mbp_removed"] = 100 - read_stats_df["%Mbp_kept"]
read_stats_df["%number_removed"] = 100 - read_stats_df["%number_kept"]

# sort the DataFrame by "Sample" column, apply background color gradient to it, and render it as an HTML table
read_stats_out=read_stats_df.drop(["length_pre", "length_post"], axis=1).reset_index().style.background_gradient(cmap="RdYlGn").render()

# write the HTML table to a file
with open(output_qc_summary_html,"w") as fp:
    fp.write(read_stats_out)
    
# Drop unnecessary columns and apply a gradient color scheme to the resulting DataFrame
read_stats_df.drop(["length_pre", "length_post"], axis=1).reset_index().style.background_gradient(cmap="RdYlGn")
# Out:
# <style  type="text/css" >
# #T_8a29dd4d_ef86_11ef_8ecf_b88303891ffcrow0_col1,#T_8a29dd4d_ef86_11ef_8ecf_b88303891ffcrow0_col2,#T_8a29dd4d_ef86_11ef_8ecf_b88303891ffcrow43_col1,#T_8a29dd4d_ef86_11ef_8ecf_b88303891ffcrow43_col2{
#             background-color:  #fdc171;
#             color:  #000000;
#         }#T_8a29dd4d_ef86_11ef_8ecf_b88303891ffcrow0_col3,#T_8a29dd4d_ef86_11ef_8ecf_b88303891ffcrow0_col4,#T_8a29dd4d_ef86_11ef_8ecf_b88303891ffcrow16_col4,#T_8a29dd4d_ef86_11ef_8ecf_b88303891ffcrow57_col1,#T_8a29dd4d_ef86_11ef_8ecf_b88303891ffcrow57_col2,#T_8a29dd4d_ef86_11ef_8ecf_b88303891ffcrow58_col8{
#             background-color:  #fdbf6f;
#             color:  #000000;
#         }#T_8a29dd4d_ef86_11ef_8ecf_b88303891ffcrow0_col5,#T_8a29dd4d_ef86_11ef_8ecf_b88303891ffcrow1_col6,#T_8a29dd4d_ef86_11ef_8ecf_b88303891ffcrow25_col5{
#             background-color:  #75c465;
#             color:  #000000;
# ...

# %% [markdown]
# ### Percentage of kept/removed reads

# %%
# Set figure size and font scale for seaborn
plt.figure(figsize=(12, 12))

# Define maximum number of samples per subplot
max_samples_per_subplot = 200

# Initialize n
n=1

# Calculate the number of rows of subplots needed
num_subplots = int(np.ceil(len(SAMPLES) / max_samples_per_subplot))

# Calculate the approximate number of samples per subplot
samples_per_subplot = int(np.ceil(len(SAMPLES) / num_subplots))

# Create subplots with fixed width for each subplot
fig, axs = plt.subplots(num_subplots, 1, figsize=(samples_per_subplot * 0.4, 12 * num_subplots), squeeze=False)

# Plot each subset of samples in separate subplots
for i in range(num_subplots):
    start_idx = i * samples_per_subplot
    end_idx = min((i + 1) * samples_per_subplot, len(SAMPLES))
    subset_df = read_stats_df.iloc[start_idx:end_idx]

    # Create a bar plot of the percentage of reads kept and removed for each sample
    ax = subset_df[["%number_kept", "%number_removed"]].plot(
        kind='bar', stacked=True, colormap=cmap1, width=0.8, edgecolor='none', ax=axs[i, 0]
    )

    # Add axis labels and a title to the plot
    ax.set_xlabel('Sample')
    ax.set_ylabel('Percentage of reads')
    ax.set_title(f'Percentage of kept reads (Samples {start_idx + 1} to {end_idx})')

    # Set the limits of the y-axis
    ax.set_ylim(0, 100)

    # Add a legend to the plot
    handles, labels = ax.get_legend_handles_labels()
    ax.legend(reversed(handles), reversed(labels), loc='center left', bbox_to_anchor=(1, 0.5))
    
    print(f"{100*n/(num_subplots):.2f}" + " %", end='\r', flush=True)

    n=n+1
# Adjust layout to prevent overlap
plt.tight_layout()

# Save the plot as PNG and SVG files
fig.savefig(output_percentage_kept_reads_png, format="png", bbox_inches="tight", transparent=True)
fig.savefig(output_percentage_kept_reads_svg, format="svg", bbox_inches="tight", transparent=True)

# Show the plot
plt.show()
# Out:
# 100.00 %

# %% [markdown]
# ### Percentage of kept/removed Mbp

# %%
# Initialize n
n=1

# Create subplots with fixed width for each subplot
fig, axs = plt.subplots(num_subplots, 1, figsize=(samples_per_subplot * 0.4, 12 * num_subplots), squeeze=False)

# Plot each subset of samples in separate subplots
for i in range(num_subplots):
    start_idx = i * samples_per_subplot
    end_idx = min((i + 1) * samples_per_subplot, len(SAMPLES))
    subset_df = read_stats_df.iloc[start_idx:end_idx]

    # Create a bar plot of the percentage of Mbp kept and removed for each sample
    ax = subset_df[["%Mbp_kept", "%Mbp_removed"]].plot(
        kind='bar', stacked=True, colormap=cmap1, width=0.8, edgecolor='none', ax=axs[i, 0]
    )

    # Add axis labels and a title to the plot
    ax.set_xlabel('Sample')
    ax.set_ylabel('Percentage of Mbp')
    ax.set_title(f'Percentage of kept Mbp (Samples {start_idx + 1} to {end_idx})', pad=20)

    # Set the limits of the y-axis
    ax.set_ylim(0, 100)

    # Add a legend to the plot
    handles, labels = ax.get_legend_handles_labels()
    ax.legend(reversed(handles), reversed(labels), loc='center left', bbox_to_anchor=(1, 0.5))

    print(f"{100*n/(num_subplots):.2f}" + " %", end='\r', flush=True)
    n=n+1


# Adjust layout to prevent overlap
plt.tight_layout()

# Save the plot as PNG and SVG files
fig.savefig(output_percentage_kept_Mbp_png, format="png", bbox_inches="tight", transparent=True)
fig.savefig(output_percentage_kept_Mbp_svg, format="svg", bbox_inches="tight", transparent=True)

# Show the plot
plt.show()
# Out:
# 100.00 %

# %% [markdown]
# ## Removed reads per QC step

# %%
# Initialize empty lists and variables
sample_l=[]
read_types=[]
raw=[]
trimmed=[]
duk=[]
euk=[]
norm=[]
reads=[]

# Initialize n
n=1

# Loop through each sample in read_stats_df and populate the lists with relevant information
for sample in (read_stats_df.index.to_list()):  
    # Add sample name and read type to lists
    sample_l.extend([sample]*3)
    read_types.extend(["R1", "R2", "U"])
    # Read in raw read counts for each read type and add to raw list
    raw.append(int(open(raw_dir + "/" + sample + forward_tag + "_read_count.txt" , 'r').readline().strip()))
    raw.append(int(open(raw_dir + "/" +  sample + reverse_tag + "_read_count.txt" , 'r').readline().strip()))
    raw.append(int(0))
    # Read in trimmed read counts for each read type and add to trimmed list
    trimmed.append(int(open(clean_dir + "/" + sample + "_forward_paired_read_count.txt" , 'r').readline().strip()))
    trimmed.append(int(open(clean_dir + "/" + sample + "_reverse_paired_read_count.txt" , 'r').readline().strip()))
    trimmed.append(int(open(clean_dir + "/" + sample + "_merged_unpaired.tot_read_count.txt" , 'r').readline().strip()))
    # Read in non-eukaryotic read counts for each read type and add to euk list
    euk.append(int(open(clean_dir + "/" + sample + "_forward_paired_noEuk.tot_read_count.txt" , 'r').readline().strip()))
    euk.append(int(open(clean_dir + "/" + sample + "_reverse_paired_noEuk.tot_read_count.txt" , 'r').readline().strip()))
    euk.append(int(open(clean_dir + "/" + sample + "_unpaired_noEuk.tot_read_count.txt" , 'r').readline().strip()))
    # Read in BBDuk-cleaned read counts for each read type and add to duk list
    duk.append(int(open(clean_dir + "/" + sample + "_forward_paired_clean.tot_read_count.txt" , 'r').readline().strip()))
    duk.append(int(open(clean_dir + "/" + sample + "_reverse_paired_clean.tot_read_count.txt" , 'r').readline().strip()))
    duk.append(int(open(clean_dir + "/" + sample + "_unpaired_clean.tot_read_count.txt" , 'r').readline().strip()))
    # Read in normalized read counts for each read type and add to norm list
    norm.append(int(open(clean_dir + "/" + sample + "_forward_paired_norm.tot_read_count.txt" , 'r').readline().strip()))
    norm.append(int(open(clean_dir + "/" + sample + "_reverse_paired_norm.tot_read_count.txt" , 'r').readline().strip()))
    norm.append(int(open(clean_dir + "/" + sample + "_unpaired_norm.tot_read_count.txt" , 'r').readline().strip()))


    print(f"{100*n/len(SAMPLES):.2f}" + " %", end='\r', flush=True)
    n=n+1

# Create an empty pandas DataFrame
df_counts = pd.DataFrame()

# Add columns to the DataFrame
df_counts["sample"] = sample_l
df_counts["type"] = read_types
df_counts["raw"] = raw
df_counts["trimmomatic"] = trimmed
df_counts["kraken"] = euk
df_counts["bbduk"] = duk
df_counts["norm"] = norm

# Calculate values for new columns and add them to the DataFrame
df_counts["raw_s"] = df_counts["raw"] / 1000000
df_counts["low_QC_reads_s"] = (df_counts["raw"] - df_counts["trimmomatic"]) / 1000000
df_counts["eukaryotic_reads_s"] = (df_counts["trimmomatic"] - df_counts["kraken"]) / 1000000
df_counts["bbduk_phix174_reads_s"] = (df_counts["kraken"] - df_counts["bbduk"]) / 1000000
df_counts["duplicate_reads_s"] = (df_counts["bbduk"] - df_counts["norm"]) / 1000000
df_counts["assembly_reads_s"] = df_counts["norm"] / 1000000

df_counts["low_QC_reads_p"] = df_counts["low_QC_reads_s"] / df_counts["raw_s"]
df_counts["eukaryotic_reads_p"] = df_counts["eukaryotic_reads_s"] / df_counts["raw_s"]
df_counts["bbduk_phix174_reads_p"] = df_counts["bbduk_phix174_reads_s"] / df_counts["raw_s"]
df_counts["duplicate_reads_p"] = df_counts["duplicate_reads_s"] / df_counts["raw_s"]
df_counts["assembly_reads_p"] = df_counts["assembly_reads_s"] / df_counts["raw_s"]

# Create a new column by concatenating two existing columns
df_counts["sample_long"] = df_counts["sample"] + "_" + df_counts["type"]

# Convert the DataFrame to an HTML table and write it to a file
df_counts.to_html(output_step_qc_reads_html)

# Display the final DataFrame
df_counts
# Out:
# 100.00 %
#          sample type       raw  trimmomatic    kraken     bbduk      norm  \
# 0        B_C1_V   R1  34153962     32371660  32096590  32096570  32093965
# 1        B_C1_V   R2  34153962     32371660  32096590  32096570  32093965
# 2        B_C1_V    U         0      1473894   1470232   1470230   1410101
# 3        B_C2_V   R1  35668640     33637768  33474881  33474872  33474320
# 4        B_C2_V   R2  35668640     33637768  33474881  33474872  33474320
# ..          ...  ...       ...          ...       ...       ...       ...
# 211  RS_ORT4B_V   R2  39520182     37832491  37347314  37347306  37345624
# 212  RS_ORT4B_V    U         0      1343510   1334960   1334960   1296705
# 213  RS_ORT4F_V   R1  52399385     50071751  49724020  49724009  49721464
# 214  RS_ORT4F_V   R2  52399385     50071751  49724020  49724009  49721464
# 215  RS_ORT4F_V    U         0      1891461   1886176   1886175   1789787
#
# ...

# %% [markdown]
# ### Number of kept/removed reads per QC step

# %%
# Initialize n
n=1

# Set figure size and font scale for seaborn
plt.figure(figsize=(12,12))

# Set figure width based on number of samples
fig_width = len(SAMPLES) * 0.4


# Define legend text and create colormap
legend_text = ["Used for assembly", "Duplicate (removed)", "phiX174 (user contaminants)", "Eukaryotic contamination", "Low quality"]

# Filter the dataframe to only include R1 reads
df_counts_paired = df_counts[df_counts["type"] == "R1"]

# Create subplots with fixed width for each subplot
fig, axs = plt.subplots(num_subplots, 1, figsize=(samples_per_subplot * 0.4, 12 * num_subplots), squeeze=False)

# Plot each subset of samples in separate subplots
for i in range(num_subplots):
    # print(i)
    start_idx = i * samples_per_subplot
    end_idx = min((i + 1) * samples_per_subplot, len(df_counts_paired))
    subset_df = df_counts_paired.iloc[start_idx:end_idx]

    # Plot the data
    ax = subset_df.plot(x="sample", y=["assembly_reads_s", "duplicate_reads_s", "bbduk_phix174_reads_s", "eukaryotic_reads_s", "low_QC_reads_s"],
                        kind="bar", stacked=True, colormap=cmap1, ax=axs[i, 0], width=0.8, edgecolor='none')

    # Add legend, axis labels and title to each subplot
    ax.set_xlabel('Sample')
    ax.set_ylabel('Million reads')
    ax.set_title(f'Sample Read Counts (Samples {start_idx + 1} to {end_idx})', pad=20)

    # Add legend to the subplot
    handles, labels = ax.get_legend_handles_labels()
    ax.legend(reversed(handles), reversed(legend_text), loc='center left', bbox_to_anchor=(1, 0.5))

    print(f"{100*n/(num_subplots):.2f}" + " %", end='\r', flush=True)
    n=n+1
    
# Adjust layout to prevent overlap
plt.tight_layout()

# Save the plot as PNG and SVG files
plt.savefig(output_steps_qc_reads_png, format="png", bbox_inches="tight", transparent=True)
plt.savefig(output_steps_qc_reads_svg, format="svg", bbox_inches="tight", transparent=True)

# Show the plot
plt.show()
# Out:
# 100.00 %

# %% [markdown]
# ### Percentage of kept/removed reads per QC step

# %%
# Initialize n
n=1

# Set figure size and font scale for seaborn
plt.figure(figsize=(12,12))

# Set figure width based on number of samples
fig_width = len(SAMPLES) * 0.4

# Create subplots with fixed width for each subplot
fig, axs = plt.subplots(num_subplots, 1, figsize=(samples_per_subplot * 0.4, 12 * num_subplots), squeeze=False)

# Plot each subset of samples in separate subplots
for i in range(num_subplots):
    start_idx = i * samples_per_subplot
    end_idx = min((i + 1) * samples_per_subplot, len(df_counts_paired))
    subset_df = df_counts_paired.iloc[start_idx:end_idx]

    # Plot the data
    ax = subset_df.plot(
        x="sample",
        y=["assembly_reads_p", "duplicate_reads_p", "bbduk_phix174_reads_p", "eukaryotic_reads_p", "low_QC_reads_p"],
        kind="bar", stacked=True, colormap=cmap1, ax=axs[i, 0], width=0.8, edgecolor='none'
    )

    # Add legend, axis labels and title to each subplot
    ax.set_xlabel('Sample')
    ax.set_ylabel('Proportion of raw reads')
    ax.set_title(f'Sample Proportion of Raw Reads (Samples {start_idx + 1} to {end_idx})', pad=20)

    # Add legend to the subplot
    handles, labels = ax.get_legend_handles_labels()
    ax.legend(reversed(handles), reversed(legend_text), loc='center left', bbox_to_anchor=(1, 0.5))

    print(f"{100*n/(num_subplots):.2f}" + " %", end='\r', flush=True)
    n=n+1

# Adjust layout to prevent overlap
plt.tight_layout()

# Save the plot as PNG and SVG files
plt.savefig(output_steps_qc_percentage_png, format="png", bbox_inches="tight", transparent=True)
plt.savefig(output_steps_qc_percentage_svg, format="svg", bbox_inches="tight", transparent=True)

# Show the plot
plt.show()
# Out:
# 100.00 %

# %%
df_counts_paired.to_csv(output_df_counts_paired)
df_counts_paired
# Out:
#          sample type       raw  trimmomatic    kraken     bbduk      norm  \
# 0        B_C1_V   R1  34153962     32371660  32096590  32096570  32093965
# 3        B_C2_V   R1  35668640     33637768  33474881  33474872  33474320
# 6        B_C3_V   R1  35729176     33722184  33461907  33461900  33458742
# 9        B_C4_V   R1  37619750     35478283  35311216  35311203  35310316
# 12    B_CIT1B_V   R1  52151603     50136761  49786325  49784689  49755056
# ..          ...  ...       ...          ...       ...       ...       ...
# 201  RS_ORT2F_V   R1  25474923     23259072  23132062  23132053  23131453
# 204  RS_ORT3B_V   R1  30231175     27911521  27729153  27729148  27728616
# 207  RS_ORT3F_V   R1  52528291     49485953  49158337  49158329  49156982
# 210  RS_ORT4B_V   R1  39520182     37832491  37347314  37347306  37345624
# 213  RS_ORT4F_V   R1  52399385     50071751  49724020  49724009  49721464
#
#          raw_s  low_QC_reads_s  eukaryotic_reads_s  bbduk_phix174_reads_s  \
# ...

# %% [markdown]
# ## Super Deduper PCR duplication statistics

# %%
# Set figure size and font scale for seaborn
plt.figure(figsize=(12, 12))

# Initialize variables
maxim = 0
percentages = []

# Create a single plot
fig, ax = plt.subplots()
n=1
# Loop through each sample
for sample in SAMPLES:
    # Load the JSON data from the file
    with open(qc_dir + "/" + sample + "_stats_pcr_duplicates.log") as f:
        data = json.load(f)
    
    # Extract the relevant data and calculate percentage of duplicates
    df = pd.DataFrame(data[0]["Fragment"]["duplicate_saturation"], columns=["reads", "dup"]) / 1000000
    percentages.append(df.iloc[-1]["dup"] * 100 / df.iloc[-1]["reads"])
    
    # Find the maximum value of "reads"
    max_temp = df["reads"].max()
    if max_temp > maxim:
        maxim = max_temp

    n=n+1
    print(f"{100*n/len(SAMPLES):.2f}" + " %", end='\r', flush=True)

    # Plot the data as a line plot using seaborn
    sns.lineplot(x="reads", y="dup", data=df, err_style='band', color=colors_rarefaction[len(percentages) - 1], 
                 label=sample, linewidth=1, alpha=0.8, ax=ax)

# Set the x and y limits of the plot
ax.set(ylim=(0, maxim))
ax.set(xlim=(0, maxim))

# Set the x and y labels of the plot
ax.set_xlabel("Million reads")
ax.set_ylabel("PCR duplicates (Million reads)")

# Add a legend to the plot
if len(SAMPLES) <= SAMPLE_PLOT_LIM_LEGEND:
    ax.legend(loc='center left', bbox_to_anchor=(1, 0.5), ncol=int(np.ceil(len(SAMPLES) / 25)))
else:
    ax.get_legend().set_visible(False)

plt.tight_layout()

# Save the plot as png and svg files
fig.savefig(output_supperdedupper_png, format="png", bbox_inches="tight", transparent=True)
fig.savefig(output_supperdedupper_svg, format="svg", bbox_inches="tight", transparent=True)

# Create a dataframe to store the percentage of duplicates for each sample
pcr_dup_df = pd.DataFrame({
    "sample": SAMPLES,
    "pcr_percent_duplicates": percentages
})

# Generate a styled HTML table of the dataframe and save it to a file
pcr_dup_df_out = pcr_dup_df.style.background_gradient(cmap="RdYlGn_r", vmin=0, vmax=100).render()
with open(output_supperdedupper_html, "w") as fp:
    fp.write(pcr_dup_df_out)
# Out:
# 101.39 %
# /tmp/ipykernel_102155/678203997.py:47: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()

# %%
# display the styled dataframe in the notebook
pcr_dup_df.style.background_gradient(cmap="RdYlGn_r", vmin=0, vmax=100)
# Out:
# <style  type="text/css" >
# #T_9fc5dc7b_ef86_11ef_bbdd_b88303891ffcrow0_col1,#T_9fc5dc7b_ef86_11ef_bbdd_b88303891ffcrow10_col1,#T_9fc5dc7b_ef86_11ef_bbdd_b88303891ffcrow20_col1{
#             background-color:  #7fc866;
#             color:  #000000;
#         }#T_9fc5dc7b_ef86_11ef_bbdd_b88303891ffcrow1_col1,#T_9fc5dc7b_ef86_11ef_bbdd_b88303891ffcrow7_col1,#T_9fc5dc7b_ef86_11ef_bbdd_b88303891ffcrow42_col1,#T_9fc5dc7b_ef86_11ef_bbdd_b88303891ffcrow49_col1,#T_9fc5dc7b_ef86_11ef_bbdd_b88303891ffcrow58_col1{
#             background-color:  #89cc67;
#             color:  #000000;
#         }#T_9fc5dc7b_ef86_11ef_bbdd_b88303891ffcrow2_col1,#T_9fc5dc7b_ef86_11ef_bbdd_b88303891ffcrow40_col1,#T_9fc5dc7b_ef86_11ef_bbdd_b88303891ffcrow61_col1{
#             background-color:  #7dc765;
#             color:  #000000;
# ...
